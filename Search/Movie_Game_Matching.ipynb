# %%
import json
import re
import numpy as np
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from collections import defaultdict

# %%
pattern = re.compile(r'[\w,.:\']+')

# %%
with open("../data/movie_data/movie_id_to_info.json") as f:
    movie_info = json.load(f) # dict of movie_id to all its information
dict_moviename_to_id = {movie_info[x]['name']:x for x in movie_info} 
# dict of movie name to movie id (original id like "0814255", "1017776-rocky")

# %%
movie_names = [movie_info[x]['name'] for x in movie_info] # all original movie names
movie_names_lower = [x.lower() for x in movie_names] # all movie names to the lowercase for further process
print(len(movie_names))
dict_moviename_to_idx = {x:i for i,x in enumerate(movie_names_lower)} # dict of movie name to index (integer)
dict_movieidx_to_id = {i:dict_moviename_to_id[movie_names[i]] for i in range(len(movie_names))}
# Out:
# 17712

# %%
# Testing the dicts and conversions
print(1, movie_names[1], dict_movieidx_to_id[1], sep=', ')
# Out:
# 1, Please Give, 0878835

# %%
movie_names_tokens = [re.findall(pattern, s) for s in movie_names_lower] # all movie names tokenized
movie_names_tokens = [list(set(s)) for s in movie_names_tokens] # deduplication

# %%
mvt_inv_index = defaultdict(list) # movie_names_tokens_inverted_index

for i in range(len(movie_names_tokens)):
    for term in movie_names_tokens[i]:
        if term not in ENGLISH_STOP_WORDS:
            mvt_inv_index[term].append(i)
            
mvt_token_list = list(mvt_inv_index.keys()) # list of all tokens occurring in the movie name
print(len(mvt_token_list))
# Out:
# 13889

# %% [markdown]
# ## Selecting the most similar movie names in the database based on what the user types in as the movie name:

# %%
def Extract_Backup_Movie(query, mvt_inv_index):
    """
    extract the indices of movie with at least one same word as the query
    query: name of a movie
    """
    ret = []
    qtokens = list(set(re.findall(pattern, query.lower())))
    for term in qtokens:
        if term in mvt_token_list:
            ret.extend(mvt_inv_index[term])
    return list(set(ret))

def Edit_Distance(query, mv_name):
    """
    return the edit distance between query and mv_name
    both are sorted alphabetically in terms of the tokens before computation
    """
    qtokens = list(set(sorted(re.findall(pattern, query.lower()))))
    mvtokens = list(set(sorted(re.findall(pattern, mv_name.lower()))))
    re_query = ''.join(qtokens)
    re_mv = ''.join(mvtokens)
    x = len(re_query)
    y = len(re_mv)
    
    mat = np.zeros((x+1, y+1))
    mat[0] = list(range(y+1))
    mat[:,0] = list(range(x+1))
    
    for i in range(1, x+1):
        for j in range(1, y+1):
            left = mat[i, j-1] + 1
            up = mat[i-1, j] + 1
            sub = mat[i-1, j-1] + (2 if re_query[i-1] != re_mv[j-1] else 0)
            arr = np.array([left, up, sub])
            mat[i, j] = np.min(arr)
    return mat[x, y]
            
def Most_Similar_Movies(query, mvt_inv_index=mvt_inv_index, movie_names=movie_names, k=5):
    """
    select the backup movies with at least one identical token
    return the kth movie (idx, score, mv_name) with smallest edit distance
    """
    backup_movie_idx = Extract_Backup_Movie(query, mvt_inv_index)
    scores = []
    for i in backup_movie_idx:
        score = Edit_Distance(query, movie_names[i])
        scores.append((i, score, movie_names[i]))
    scores.sort(key=lambda x:x[1])
    return scores[:k]

# %%
Edit_Distance('try it', 'one trial')
# Out:
# 7.0

# %%
Most_Similar_Movies("rescue hostage")
# Out:
# [(1464, 6.0, 'Hostage'),
#  (12438, 11.0, 'Rescue Dawn'),
#  (6734, 17.0, 'Free Willy 3: The Rescue'),
#  (11880, 19.0, 'Planes: Fire And Rescue'),
#  (3970, 20.0, 'Brave Little Toaster to the Rescue')]

# %% [markdown]
# ## Movie-Game Matching

# %%
with open("../data/steamData/80k_data/inv_game_genre.json") as f:
    game_genre_inv_idx = json.load(f)
with open("../data/steamData/80k_data/inv_game_tags.json") as f:
    game_tags_inv_idx = json.load(f)
with open("../data/movie_data/inv_movie_genre.json") as f:
    movie_genre_inv_idx = json.load(f)
with open("../data/steamData/80k_data/inv_game_num_players.json") as f:
    num_players_inv_idx = json.load(f)
with open("../data/movie_data/movie_desc_keywords.json") as f:
    movie_keywords = json.load(f)
with open("../data/reviews/inverse_keyword_phrases.json") as f:
    game_review_inv_idx = json.load(f)
for x in game_review_inv_idx:
    game_review_inv_idx[x] = [int(e) for e in game_review_inv_idx[x]]
    
with open("../data/steamData/80k_data/inv_game_desc_keywords.json") as f:
    game_desc_inv_idx = json.load(f)
with open("../data/steamData/80k_data/id_to_info.json") as f:
    game_info = json.load(f)
dict_game_id_to_name = {int(x):game_info[x]['name'] for x in game_info}
dict_game_id_to_rating = {int(x):game_info[x]['rating'] for x in game_info}
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-ef370470b4e8> in <module>
#      16 with open("../data/steamData/80k_data/inv_game_desc_keywords.json") as f:
#      17     game_desc_inv_idx = json.load(f)
# ---> 18 with open("../data/steamData/80k_data/id_to_info.json") as f:
#      19     game_info = json.load(f)
#      20 dict_game_id_to_name = {int(x):game_info[x]['name'] for x in game_info}
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/steamData/80k_data/id_to_info.json'

# %%
# combine the keywords from the description and review with deduplication
def Combine_Dict(dict1, dict2):
    newdict = dict1.copy()
    for key in dict2.keys():
        if key in newdict:
            newdict[key] = list(set(newdict[key]+dict2[key]))
        else:
            newdict[key] = [x for x in dict2[key]]
    return newdict

game_kw_inv_idx = Combine_Dict(game_review_inv_idx, game_desc_inv_idx) 
game_kw = list(game_kw_inv_idx.keys())

# %%
Game_genres = list(game_genre_inv_idx.keys())
Game_genres_extension = ['survival', 'fps', 'puzzle', 'party game', 'casual', 'wargame', 'tower defense']
all_game_genres = Game_genres + Game_genres_extension

# %%
Game_genres
# Out:
# ['mmo',
#  'strategy',
#  'action',
#  'indie',
#  'sports',
#  'party-game',
#  'role-playing',
#  'simulation',
#  'open-world',
#  'adventure',
#  'boardgame']

# %%
# mapping game id to the number of genres the game has
dict_game_genre_count = defaultdict(int)
for genre in all_game_genres:
    if genre in Game_genres:
        for entry in game_genre_inv_idx[genre]:
            dict_game_genre_count[entry] += 1
    else:
        for entry in game_tags_inv_idx[genre]:
            dict_game_genre_count[entry] += 1

# %%
# mapping game id to the number of keywords the game has (decription + review)
dict_game_kw_count = defaultdict(int)
for kw in game_kw_inv_idx:
    for entry in game_kw_inv_idx[kw]:
        dict_game_kw_count[entry] += 1

# %%
def Generic_Game_Filtering(players=None, genres=None, mv_idx=None, free_query=None, k=15):
    
    scores = defaultdict(int)
    # filtering based on the 'single','multi' button, or unspecified/both, filtering out the range
    if players == 'single':
        num_pool = num_players_inv_idx['single-player']
    # players == 'multi'
    elif players == 'multi':
        num_pool = num_players_inv_idx['multi-player']
    for entry in num_pool:
        num_pool = None
    # not selected
    
    # filtering based on selected genres, scored for each genre matching
    if genres:
        for genre in genres:
            if genre in Game_genres:
                genre_pool = game_genre_inv_idx[genre]
            # gere in extensions
            else:
                genre_pool = game_tags_inv_idx[genre]
            for entry in genre_pool:
                if (num_pool and entry in num_pool) or (not num_pool):
                    scores[entry] += 10 / dict_game_genre_count[entry]
    
    # filtering based on the exact movie name in the database, selected above
    # using the movie name + genre + keywords from the description as keywords
    # each keyword is scored 0.1
    if mv_idx:
        mv_id = dict_movieidx_to_id[mv_idx]
        mv_keywords = movie_keywords[mv_id]
        mv_name = movie_names_lower[mv_idx]
        mv_genre = movie_info[mv_id]['genre']

        mv_keywords += re.findall(pattern, mv_name)
        mv_keywords += [y for x in mv_genre for y in re.findall(pattern, x.lower()) ]
        mv_keywords = list(set(mv_keywords))

        for term in mv_keywords:
            if term in game_kw:
                for entry in game_kw_inv_idx[term]:
                    if (num_pool and entry in num_pool) or (not num_pool):
                        scores[entry] += 80 / dict_game_kw_count[entry]
    
    # filtering on free query, tokenized as keywords, each scored 0.5
    if free_query:
        qtokens = free_query.lower().split()
        for term in qtokens:
            if term in game_kw:
                for entry in game_kw_inv_idx[term]:
                    if (num_pool and entry in num_pool) or (not num_pool):
                        scores[entry] += 150 / dict_game_kw_count[entry]
                        
    # factoring in game rating(0-100)
    for x in scores:
         scores[x] += dict_game_id_to_rating[x] / 50
        
    scores_tuple_lst = [(num, dict_game_id_to_name[num], scores[num]) for num in scores]
    scores_tuple_lst.sort(key=lambda x:x[2])
    scores_tuple_lst.reverse()
    return scores_tuple_lst[:k]
    
# movie = "titanic"
Generic_Game_Filtering(players='single', genres=['action', 'role-playing'], mv_idx=12940,
                       free_query='forest monster')
# Out:
# [(627270, 'Injustice 2', 13.493121693121697),
#  (550080, 'VALKYRIE DRIVE -BHIKKHUNI-', 13.288627450980393),
#  (925750,
#   'Dead by Daylight - Shattered Bloodline Chapter',
#   12.916470588235294),
#  (353370, 'Steam Controller', 12.75),
#  (976310, 'Mortal Kombat11', 12.719540229885059),
#  (222940, 'THE KING OF FIGHTERS XIII STEAM EDITION', 12.650593607305934),
#  (311730, 'DEAD OR ALIVE 5 Last Round: Core Fighters', 12.483977900552487),
#  (228180, 'Action - Gameplay Recording and Streaming', 12.41868995633188),
#  (1167450, 'DAEMON X MACHINA', 11.987692307692308),
#  (1242753,
#   "Monster Hunter World: Iceborne - Pendant: Strollin' Paolumu",
#   11.98),
#  (222440, 'THE KING OF FIGHTERS 2002 UNLIMITED MATCH', 11.98),
#  (323130, 'Half-Life Soundtrack', 11.96),
#  (920566, "Resident Evil 2 - Claire Costume: 98'", 11.96),
#  (1223860, 'Smell of the Game (NEW GUILTY GEAR Promotion Music)', 11.96),
#  (1242759,
#   'Monster Hunter World: Iceborne - Pendant: Rainbow Balloons',
#   11.96)]

# %%
dict_moviename_to_idx
# Out:
# {'percy jackson & the olympians: the lightning thief': 0,
#  'please give': 1,
#  '10': 2,
#  '12 angry men (twelve angry men)': 3,
#  '20,000 leagues under the sea': 4,
#  '10,000 b.c.': 5,
#  'the 39 steps': 6,
#  '3:10 to yuma': 1966,
#  'charly (a heartbeat away)': 8,
#  'abraham lincoln': 9,
#  'dark water': 5178,
#  'the accused': 11,
#  'the lost city': 12,
#  'the breaking point': 13,
#  "adam's rib": 14,
#  'the bridge of san luis rey': 15,
#  'the prowler (cost of living )': 16,
#  'criminal': 4978,
#  'the adventures of mark twain': 18,
#  'deep blue': 19,
#  'the adventures of robin hood': 20,
#  'man hunt': 21,
#  'dead end': 5254,
#  'bandwagon': 23,
#  'whore': 24,
#  'tristan & isolde': 25,
#  'wild side': 26,
#  'a tale of two pizzas': 27,
#  'running scared': 706,
#  'going the distance': 271,
#  'ultraviolet': 30,
#  'home of the brave': 7832,
#  'arthur and the invisibles (arthur and the minimoys)': 32,
#  'malevolence': 33,
#  'eternal': 34,
#  'a farewell to arms': 6303,
#  'the narrow margin': 36,
#  'the matador': 181,
#  'smile': 38,
#  "the intruder (l'intrus)": 39,
#  'saint ralph': 40,
#  'the baxter': 41,
#  'oliver twist': 11305,
#  'the alamo': 2464,
#  'g': 44,
#  'alexander the great': 45,
#  'alfie': 2480,
#  'neverwas': 47,
#  'the second chance': 48,
#  'moonlight': 10577,
#  'aliens': 50,
#  'rise: blood hunter': 51,
#  'all about eve': 52,
#  'when do we eat?': 53,
#  'the mostly unfabulous social life of ethan green': 54,
#  'dirty': 55,
#  'stay alive': 56,
#  'all of me': 57,
#  'all quiet on the western front': 58,
#  'dreamland': 5753,
#  'independent lens': 60,
#  "all the king's men": 2544,
#  'street fight': 62,
#  'lost horizon': 9738,
#  'the motel': 64,
#  'once in a lifetime: the extraordinary story of the new york cosmos': 65,
#  'requiem': 66,
#  'gui si (silk)': 67,
#  'park': 68,
#  'the 4th dimension': 69,
#  'bon cop, bad cop': 70,
#  'amazing grace': 2609,
#  'the silence': 15805,
#  'cocaine cowboys': 73,
#  'gone': 7156,
#  'the situation': 75,
#  'snow blind': 76,
#  'four sheets to the wind': 77,
#  "the tiger's tail": 78,
#  "it's a boy girl thing": 79,
#  'slipstream': 80,
#  'delirious': 5374,
#  'interview': 82,
#  'american anthem': 83,
#  'the ten': 84,
#  'the happening': 85,
#  'molière': 86,
#  'straightheads (closure)': 87,
#  'borderland': 88,
#  'spiral': 13708,
#  'alexandra': 90,
#  'blood and tears: the arab-israeli conflict': 91,
#  'the cool school': 92,
#  'pathology': 93,
#  "disney's a christmas carol": 94,
#  'deep water': 95,
#  'road to victory': 96,
#  'beverly hills chihuahua': 97,
#  'fireflies in the garden': 98,
#  'the eye': 99,
#  'day of the dead': 393,
#  "my best friend's girl": 101,
#  'the burrowers': 102,
#  'the midnight meat train': 103,
#  'the lucky ones': 104,
#  'run fatboy run': 105,
#  'closing escrow': 106,
#  'whiteout': 107,
#  'randy and the mob': 108,
#  'black irish': 109,
#  'wild child': 110,
#  'powder blue': 111,
#  'king corn': 112,
#  "l' avocat de la terreur (terror's advocate)": 113,
#  'darfur now': 114,
#  'laaga chunari mein daag - journey of a woman': 115,
#  'rails & ties': 116,
#  'mr. untouchable': 117,
#  'house': 118,
#  'canvas': 119,
#  'skid row': 120,
#  'saawariya': 121,
#  'aaja nachle': 122,
#  'flawless': 6534,
#  'what happens in vegas': 124,
#  'appaloosa': 125,
#  'good': 126,
#  'the visitor': 15989,
#  'meet bill': 128,
#  'married life': 129,
#  'badland': 130,
#  'the oxford murders': 131,
#  'untraceable': 132,
#  'the informers': 133,
#  'meeting resistance': 134,
#  'the freshman': 135,
#  'guta-yubalja-deul (a bloody aria)': 136,
#  'kenny': 137,
#  'the rocker': 138,
#  'the perfect holiday': 139,
#  'la graine et le mulet (the secret of the grain) (couscous)': 140,
#  'land of the lost': 141,
#  '[rec]': 142,
#  'look': 143,
#  'and god created woman': 144,
#  'the box': 145,
#  'man in the chair': 146,
#  'undoing': 147,
#  'black water': 3676,
#  '21': 149,
#  "the duchess of langeais (ne touchez pas la hache)(don't touch the axe)": 150,
#  'ben x': 151,
#  'body of lies': 152,
#  'passengers': 11644,
#  'the grand': 154,
#  'the hammer': 155,
#  'shutter': 13284,
#  'priest': 157,
#  'the broken': 158,
#  'the escapist': 159,
#  'sugar': 160,
#  'quid pro quo': 161,
#  'red': 12341,
#  'the guitar': 163,
#  'the road': 15733,
#  'g-force': 165,
#  'the other man': 166,
#  'the duchess': 167,
#  'the women': 819,
#  'public enemies': 169,
#  'night and day (bam gua nat)': 170,
#  'julia': 171,
#  'angel and the badman': 172,
#  'fade to black': 173,
#  'angel heart': 174,
#  'old dogs': 175,
#  'surrogates': 176,
#  'the promotion': 177,
#  'notorious': 178,
#  'soul men': 179,
#  'igor': 180,
#  'the auteur': 182,
#  'the caller': 183,
#  'sin nombre': 184,
#  'das haus der schlafenden schönen (house of the sleeping beauties)': 185,
#  'the stone angel': 186,
#  'alvin and the chipmunks: the squeakquel': 187,
#  'un conte de noël (a christmas tale)': 188,
#  'the rebound': 189,
#  'ripple effect': 190,
#  '1,000 times good night': 191,
#  'harold': 192,
#  'push': 193,
#  'felon': 194,
#  'scar': 195,
#  'the unborn': 196,
#  'bitch slap': 197,
#  'forever strong': 198,
#  'chocolate': 199,
#  'fireproof': 200,
#  'dostana': 201,
#  'the garden': 15010,
#  'splinter': 1601,
#  'leaves of grass': 204,
#  'rab ne bana di jodi (a couple made by god) (a match made in heaven)': 205,
#  'the proposal': 206,
#  'gigantic': 207,
#  'fuel': 208,
#  'hush': 8032,
#  'anna karenina': 2791,
#  'orphan': 211,
#  "my sister's keeper": 212,
#  'the hangover': 213,
#  'the stepfather': 13867,
#  'okuribito (departures)': 215,
#  'boogie (summer holiday)': 216,
#  'prima ballerina': 217,
#  'season of the witch': 218,
#  'shuttle': 219,
#  'miss march': 220,
#  'an american affair': 221,
#  'grace': 222,
#  'endgame': 223,
#  'the red baron (der rote baron)': 224,
#  'the objective': 225,
#  'happy tears': 226,
#  'the missing person': 227,
#  'polanski (polanski unauthorized)': 228,
#  'mammoth (mammut)': 229,
#  'crude': 230,
#  'the messenger': 15466,
#  'lake mungo': 232,
#  'venkovský ucitel (the country teacher)': 233,
#  'the apartment': 234,
#  'chatham (the golden boys)': 235,
#  'the ape': 236,
#  'fame': 6267,
#  'outrage': 238,
#  'skin': 13377,
#  'helen': 1739,
#  'bakjwi (thirst)': 241,
#  'vengeance (fuk sau)': 242,
#  'new world order': 243,
#  "april fool's day": 244,
#  'blood: the last vampire': 245,
#  'shrink': 246,
#  'ong bak 2': 247,
#  'bananas!': 248,
#  'last ride': 249,
#  'tron legacy': 250,
#  'the canyon': 251,
#  'manson, my name is evil': 252,
#  'broken hill': 253,
#  'a beautiful life': 254,
#  'suck': 255,
#  'chloe': 256,
#  'armed and dangerous': 257,
#  'the hole': 258,
#  "nobody's perfect": 259,
#  'the good soldier': 260,
#  'high life': 7740,
#  'around the world in 80 days': 2914,
#  'the fall': 14412,
#  'the good heart': 264,
#  'wonderful world': 265,
#  'collapse': 266,
#  'three blind mice': 267,
#  'the last song': 268,
#  'babies': 269,
#  'lottery ticket': 270,
#  'life as we know it': 272,
#  'the final': 273,
#  'frozen': 6807,
#  'prodigal sons': 275,
#  'the ghost writer': 276,
#  'repo men': 277,
#  '7 days (les 7 jours du talion)': 278,
#  'daddy longlegs': 279,
#  'veer': 280,
#  "winter's bone": 281,
#  'the kids are all right': 282,
#  'lucky': 9859,
#  'high school': 284,
#  'stolen': 13908,
#  'the killing jar': 286,
#  'la mission': 287,
#  'predators': 288,
#  'stonewall uprising': 289,
#  'the oath': 15543,
#  'the wild hunt': 291,
#  'arthur': 2926,
#  'the lottery': 293,
#  'assault on precinct 13': 2963,
#  'asylum': 2971,
#  'attack of the 50 foot woman': 296,
#  'avenging angel': 297,
#  'the aviator': 3033,
#  'the awakening': 14538,
#  'babes in toyland': 10094,
#  'bad company': 3105,
#  'the bad news bears': 302,
#  'the bad seed': 303,
#  'bang the drum slowly': 304,
#  'battleground': 305,
#  'beauty and the beast (la belle et la bête)': 3322,
#  "the belles of st. trinian's": 307,
#  '1001 grams': 308,
#  'the best of times': 309,
#  'betrayed': 310,
#  'the big brawl (battle creek brawl)': 311,
#  'big business': 312,
#  'the big heat': 313,
#  'the big sleep': 315,
#  'billy budd': 316,
#  'the birds': 317,
#  'black christmas': 3640,
#  'the black hole': 319,
#  'the black pirate': 320,
#  'black rain': 321,
#  'black sunday': 3673,
#  'black widow': 323,
#  'blackmail': 324,
#  'blind date': 1842,
#  'blood and sand': 3745,
#  'blood feast': 327,
#  'der blaue engel (the blue angel)': 328,
#  'bluebeard': 329,
#  'the border': 330,
#  'born yesterday': 951,
#  'the boston strangler': 332,
#  'the bounty': 333,
#  'the boys from brazil': 334,
#  'brainstorm': 335,
#  'breakout': 336,
#  "brewster's millions": 337,
#  "brian's song": 338,
#  'brief encounter': 339,
#  'broken arrow': 1076,
#  'broken blossoms': 341,
#  'the brotherhood': 342,
#  'bug': 4124,
#  'burglar': 344,
#  'bus stop': 345,
#  'butch cassidy and the sundance kid': 346,
#  'bye bye birdie': 347,
#  'calamity jane': 348,
#  'camelot': 349,
#  'camille': 350,
#  'cape fear': 894,
#  'captain blood': 352,
#  'captains courageous': 353,
#  'carnival of souls': 354,
#  'carny': 355,
#  'carrie': 4329,
#  'casablanca': 357,
#  'casino royale': 4348,
#  'the cat and the canary': 359,
#  'cat on a hot tin roof': 360,
#  'cat people': 362,
#  'caught': 4388,
#  'the champ': 841,
#  'champion': 365,
#  'charade': 366,
#  "charlotte's web": 4462,
#  'the chase': 368,
#  'checking out': 4485,
#  'children of the corn': 1851,
#  'the chosen': 371,
#  'a christmas carol': 372,
#  'christmas in connecticut': 373,
#  'a christmas story': 374,
#  'cimarron': 375,
#  'cleopatra': 376,
#  'college': 1633,
#  'colors': 378,
#  'coma': 379,
#  'commando': 380,
#  'convoy': 381,
#  'countdown': 4911,
#  'the country girl': 383,
#  'cover girl': 384,
#  'creature from the black lagoon': 385,
#  'crossroads': 1376,
#  'cutting class': 387,
#  'damn yankees': 388,
#  'dangerous': 389,
#  'dangerous liaisons': 5134,
#  'the dark mirror': 391,
#  'darling': 5188,
#  'the day the earth stood still': 5221,
#  'days of wine and roses': 395,
#  'dead heat': 396,
#  'dead reckoning': 397,
#  'death in venice': 398,
#  'death of a salesman': 399,
#  'dèmoni (demons)': 400,
#  'the desperate hours': 401,
#  'devil doll': 402,
#  'dillinger': 403,
#  'dinner at eight': 404,
#  'distant thunder': 405,
#  'doctor zhivago': 406,
#  'dodge city': 407,
#  'dolls': 408,
#  'dr. jekyll and mr. hyde': 409,
#  'how the grinch stole christmas': 410,
#  'dracula': 413,
#  'dragnet': 414,
#  'the dream team': 415,
#  'dressed to kill': 416,
#  'duel': 417,
#  'dune': 418,
#  'the eagle has landed': 419,
#  'east of eden': 420,
#  'easy money': 421,
#  'eaten alive': 422,
#  'edipo re (oedipus rex)': 423,
#  'the elephant man': 424,
#  'the enforcer': 426,
#  'escape from new york': 427,
#  'exodus': 428,
#  'eyewitness': 429,
#  'fahrenheit 451': 430,
#  'the fan': 1114,
#  'fandango': 432,
#  'far from the madding crowd': 6296,
#  'farewell, my lovely': 434,
#  'fatal attraction': 435,
#  'father of the bride': 901,
#  'fire and ice': 437,
#  'flash gordon': 438,
#  'flashback': 439,
#  'flesh & blood (flesh+blood) (the rose and the sword)': 440,
#  'the flight of the phoenix': 441,
#  'flipper': 1089,
#  'the fly': 444,
#  'flying tigers': 445,
#  'footloose': 6596,
#  'the four feathers': 6660,
#  'frantic': 448,
#  'freaky friday': 6710,
#  'fright night': 6775,
#  'from here to eternity': 451,
#  'frosty the snowman': 452,
#  'the fugitive': 975,
#  'fun with dick and jane': 6827,
#  'funny farm': 455,
#  'the fury': 456,
#  'galaxy of terror (mindwarp: an infinity of terror) (planet of horrors) (quest)': 457,
#  'gallipoli': 458,
#  'the gambler': 15006,
#  'game of death': 6861,
#  'the general': 1231,
#  'the getaway': 988,
#  'girls! girls! girls!': 463,
#  'gloria': 7067,
#  'glory': 465,
#  'go west': 466,
#  'gone in 60 seconds': 467,
#  'the goodbye girl': 468,
#  'goodbye, mr. chips': 839,
#  'the great gatsby': 15071,
#  'the great race': 471,
#  'the green berets': 472,
#  'grizzly': 473,
#  'the group': 474,
#  "gulliver's travels": 7363,
#  'the gunfighter': 476,
#  'gung ho': 477,
#  'gypsy': 962,
#  'hairspray': 7405,
#  'halloween': 7418,
#  'hamlet': 7429,
#  'the hand': 482,
#  'hard times': 483,
#  'hardcore': 484,
#  'the harder they fall': 485,
#  'the haunting': 1246,
#  'hawaii': 487,
#  'heat': 1065,
#  'heaven': 7608,
#  'heaven can wait': 7609,
#  'heidi': 491,
#  'the hidden fortress (kakushi-toride no san-akunin)': 492,
#  'the hills have eyes': 7761,
#  'the hindenburg': 494,
#  'the hit': 495,
#  'a hole in the head': 496,
#  'hot pursuit': 5655,
#  '100 bloody acres': 498,
#  '100 girls': 499,
#  '100 streets': 500,
#  'the hound of the baskervilles': 502,
#  "house (ding dong, you're dead)": 503,
#  'house of wax': 7942,
#  'house on haunted hill': 1266,
#  'hud': 506,
#  'the human factor': 507,
#  'the hunchback of notre dame': 1117,
#  'the hunter': 15193,
#  'hustle': 511,
#  'i, the jury': 512,
#  'imitation of life': 1186,
#  'the importance of being earnest': 8242,
#  'impulse': 515,
#  'in cold blood': 516,
#  'the incubus': 517,
#  'indiscreet': 518,
#  'the informer': 519,
#  'inherit the wind': 520,
#  'intolerance': 521,
#  'invaders from mars': 523,
#  'invasion of the body snatchers': 525,
#  'the invisible man': 15243,
#  'the island': 527,
#  'the island of dr. moreau': 1103,
#  'islands in the stream': 529,
#  'it': 8501,
#  "it's alive": 531,
#  'ivanhoe': 532,
#  'jack and the beanstalk': 533,
#  'jack frost': 1242,
#  'jamaica inn': 535,
#  'jason and the argonauts': 536,
#  'the jazz singer': 538,
#  'jesus christ superstar': 539,
#  'johnny belinda': 540,
#  'judex': 541,
#  'julius caesar': 543,
#  'jungle book': 544,
#  'kansas': 545,
#  'kickboxer': 546,
#  'kid galahad': 912,
#  'the killer elite': 548,
#  'the king and i': 1230,
#  'king kong': 9014,
#  'the king of comedy': 552,
#  'king of kings': 553,
#  "king solomon's mines": 554,
#  'the lady vanishes': 555,
#  'the ladykillers': 9196,
#  'laura': 557,
#  'legend': 9366,
#  'les miserables': 1193,
#  'the letter': 560,
#  'lilies of the field': 561,
#  'the lion in winter': 562,
#  'the little drummer boy': 563,
#  'little lord fauntleroy': 564,
#  'the little princess': 565,
#  'a little romance': 566,
#  'the little shop of horrors': 567,
#  'little shop of horrors': 568,
#  'little women': 9604,
#  'lock up': 571,
#  'lolita': 1216,
#  "long day's journey into night": 573,
#  'the long, hot summer': 574,
#  'the longest yard': 9682,
#  'look back in anger': 576,
#  'the lost patrol': 577,
#  'the love bug': 578,
#  'lovesick': 9843,
#  'lust for life': 580,
#  'm': 581,
#  'madame x': 582,
#  'made in heaven': 583,
#  'the magic flute (trollflöjten)': 584,
#  'the magnificent ambersons': 585,
#  'the magnificent seven': 15435,
#  'the main event': 15436,
#  'the maltese falcon': 588,
#  'a man for all seasons': 589,
#  'the manchurian candidate': 10045,
#  'the manhattan project': 591,
#  'manhunter': 592,
#  'mannequin': 593,
#  'the mark of zorro': 1190,
#  'marty': 595,
#  'masquerade': 10167,
#  'the mechanic': 10245,
#  'the men': 598,
#  'meteor': 599,
#  'metropolis': 600,
#  "a midsummer night's dream": 2167,
#  'mighty joe young': 1213,
#  'the miracle worker': 603,
#  'missing in action': 604,
#  'the mission': 605,
#  'mister roberts': 606,
#  'moby dick': 607,
#  'monkey business': 609,
#  'moonraker': 610,
#  'morning glory': 10593,
#  'moulin rouge': 612,
#  'mr. & mrs. smith': 10655,
#  'mrs. soffel': 614,
#  'the mummy': 15497,
#  'murder!': 617,
#  'the music man': 618,
#  'mutiny on the bounty': 620,
#  'my man godfrey': 621,
#  'mysterious island': 622,
#  'near dark': 623,
#  'neighbors': 10959,
#  'next of kin': 625,
#  'nicholas and alexandra': 626,
#  'night and day': 627,
#  'a night at the opera': 628,
#  'night of the living dead': 11059,
#  'a night to remember': 630,
#  'nighthawks': 631,
#  "no man's land": 11117,
#  'no mercy': 633,
#  'no way out': 1167,
#  'the nutty professor': 635,
#  'obsession': 636,
#  'the odd couple': 637,
#  'odd man out': 638,
#  'the odessa file': 639,
#  'the omen': 11314,
#  'on the beach': 641,
#  'on the town': 642,
#  'only when i laugh': 643,
#  'our town': 644,
#  'out of the dark': 11494,
#  'the out-of-towners': 15573,
#  'the parent trap': 1195,
#  'the party': 15598,
#  'pennies from heaven': 649,
#  'peter pan': 1434,
#  'the phantom of the opera': 11785,
#  'phantom of the opera': 11786,
#  'the picture of dorian gray': 653,
#  'the pink panther': 11847,
#  'piranha': 655,
#  'the pirates of penzance': 656,
#  'pit and the pendulum (the pit and the pendulum)': 657,
#  'planet of the apes': 1355,
#  'point blank': 11921,
#  'pollyanna': 660,
#  'poltergeist': 11949,
#  'popeye': 662,
#  'the poseidon adventure': 663,
#  'posse': 954,
#  'the postman always rings twice': 666,
#  'power': 667,
#  'pride and prejudice': 1503,
#  'the prince and the pauper': 669,
#  'the prisoner of zenda': 670,
#  'the prisoner': 671,
#  'the producers': 12080,
#  'project x': 12089,
#  'prom night': 12091,
#  'promised land': 12094,
#  'prophecy': 676,
#  'the protector': 677,
#  'the prowler': 678,
#  'the public enemy': 679,
#  'pulse': 12127,
#  'quo vadis?': 681,
#  'a raisin in the sun': 682,
#  'raw deal': 1047,
#  "the razor's edge": 685,
#  'rear window': 686,
#  'reckless': 687,
#  'red dawn': 12350,
#  'red heat': 689,
#  'the red shoes': 690,
#  'red sonja': 691,
#  'monanieba (repentance)': 692,
#  'return to oz': 693,
#  'revenge': 12490,
#  'rich and famous': 695,
#  'risky business': 696,
#  'road house': 697,
#  'robin hood': 12616,
#  'robocop': 1704,
#  "rock 'n' roll high school": 700,
#  'rocky': 701,
#  'the roman spring of mrs. stone': 702,
#  'romeo and juliet': 12684,
#  'rudolph the red-nosed reindeer': 704,
#  'runaway': 705,
#  'sabotage': 12788,
#  'sabrina': 1068,
#  'sahara': 1476,
#  'samson and delilah': 710,
#  'scanners': 711,
#  'scarecrow': 712,
#  'scarface': 12918,
#  'scrooge': 714,
#  'the sea hawk': 715,
#  'second sight': 716,
#  'blind terror (see no evil)': 717,
#  'separate tables': 718,
#  'shadow of a doubt': 719,
#  'shaft': 13140,
#  'the shaggy dog': 13144,
#  'shakedown': 722,
#  'shall we dance': 13151,
#  'the shooting': 724,
#  'short circuit': 725,
#  'a shot in the dark': 726,
#  'show boat': 727,
#  'silent night, deadly night': 728,
#  'the silent partner': 729,
#  'silver streak': 730,
#  'simon': 731,
#  'sinbad the sailor': 732,
#  'skin deep': 733,
#  'sleeping beauty': 13416,
#  'something to sing about': 735,
#  'sorcerer': 736,
#  'sparkle': 13657,
#  'spartacus': 738,
#  'splash': 739,
#  'spring break': 740,
#  'the squeeze': 15848,
#  "the st. valentine's day massacre": 742,
#  'stagecoach': 743,
#  'stage fright': 13760,
#  'stakeout': 745,
#  'a star is born': 2221,
#  '101 dalmatians': 1125,
#  "101 dalmatians ii: patch's london adventure": 750,
#  'the sting': 751,
#  'the stranger': 752,
#  'a streetcar named desire': 753,
#  'suddenly': 754,
#  'summer school': 755,
#  'the sundowners': 756,
#  'the sunshine boys': 757,
#  'suspect': 758,
#  'suspicion': 759,
#  'svengali': 760,
#  'sweet bird of youth': 761,
#  'swing time': 762,
#  'swiss family robinson': 763,
#  'a tale of two cities': 764,
#  'the taming of the shrew': 765,
#  'target': 766,
#  'tarzan, the ape man': 767,
#  'tempest': 768,
#  'the ten commandments': 770,
#  'tales of terror': 771,
#  'that championship season': 772,
#  'them!': 773,
#  'shivers (they came from within) (the parasite murders)': 774,
#  'they drive by night': 775,
#  'thief': 776,
#  'the thing from another world': 777,
#  'the thing': 15900,
#  'thirst': 779,
#  'this gun for hire': 780,
#  'three amigos!': 781,
#  'tre fratelli (three brothers)': 782,
#  'the three musketeers': 15907,
#  'the time machine': 1379,
#  'tommy': 786,
#  'the toolbox murders': 787,
#  'top secret!': 788,
#  'i corpi presentano tracce di violenza carnale (torso) (bodies bear traces of carnal violence)': 789,
#  'touch of evil': 790,
#  'tough guys': 791,
#  'treasure island': 16467,
#  'le procès (the trial)': 794,
#  'the trip': 15937,
#  "twelve o'clock high": 796,
#  'twins': 797,
#  'uncommon valor': 798,
#  'the undefeated': 15963,
#  'unfaithfully yours': 800,
#  'the unforgiven': 801,
#  'valley girl': 16816,
#  'venom': 16855,
#  'vice versa': 804,
#  'victory': 805,
#  'village of the damned': 1040,
#  'walking tall': 17008,
#  'the warriors': 808,
#  'water': 17067,
#  "we're no angels": 810,
#  'weird science': 811,
#  'when a stranger calls': 17221,
#  'where the boys are': 813,
#  'white christmas': 814,
#  'willard': 17395,
#  "winchester '73": 816,
#  'witness': 817,
#  "a woman's face": 818,
#  'the wrong man': 820,
#  'wuthering heights': 17554,
#  'year of the dragon': 822,
#  'the yearling': 823,
#  'yours, mine and ours': 824,
#  'blue steel': 825,
#  'where the heart is': 1282,
#  'the guardian': 15094,
#  'mystery train': 828,
#  'revolution': 829,
#  'henry v': 830,
#  'kiss of death': 831,
#  'conquest': 832,
#  'alice in wonderland': 1859,
#  'my blue heaven': 834,
#  'state fair': 835,
#  'dick tracy': 836,
#  'bombshell (blonde bombshell)': 837,
#  'navy seals': 838,
#  '102 dalmatians': 840,
#  'narrow margin': 842,
#  'red dust': 843,
#  'desperate hours': 844,
#  'ghost': 845,
#  'memphis belle': 846,
#  'faust': 6352,
#  'gun crazy (deadly is the female)': 848,
#  'the jungle book': 15265,
#  'the long goodbye': 850,
#  'houdini': 851,
#  'avalon': 852,
#  'the rookie': 1380,
#  'the long walk home': 854,
#  'anastasia': 1170,
#  'jane eyre': 8602,
#  'the pit and the pendulum': 857,
#  'goodfellas': 858,
#  'after hours': 859,
#  'white fang': 860,
#  'boy meets girl (1984)': 861,
#  'mata hari': 862,
#  'alice': 2486,
#  'hidden agenda': 864,
#  'the connection': 14756,
#  'the entertainer': 866,
#  'sorry, wrong number': 867,
#  'awakenings': 868,
#  'diabolique (les diaboliques)': 869,
#  'true colors': 870,
#  'switch': 14170,
#  'the field': 872,
#  'oscar': 873,
#  'night nurse': 874,
#  'fury': 6841,
#  'possessed': 876,
#  'born to kill': 877,
#  'toy soldiers': 878,
#  'come and see (idi i smotri)': 879,
#  'the miracle': 880,
#  'hot shots!': 881,
#  'dogfight': 882,
#  'the hitman': 883,
#  "teacher's pet": 14286,
#  'shattered': 885,
#  'the doctor': 887,
#  'paradise': 11591,
#  'the commitments': 889,
#  'frankie & johnny': 890,
#  'deceived': 891,
#  'the star': 15851,
#  'poison': 893,
#  'homo faber (voyager)': 895,
#  'my girl': 896,
#  'jfk': 897,
#  'the man in the moon': 898,
#  'the prize': 899,
#  'the train': 900,
#  'rush': 12767,
#  'medicine man': 903,
#  'platinum blonde': 904,
#  'the uninvited': 16730,
#  'the italian job': 8524,
#  'beethoven': 907,
#  'tacones lejanos (high heels)': 908,
#  'the babe': 909,
#  'the cutting edge': 910,
#  'gladiator': 7052,
#  'deep cover': 913,
#  'all i want for christmas': 914,
#  'class act': 915,
#  'edward ii': 916,
#  'a midnight clear': 917,
#  'boomerang': 918,
#  'rapid fire': 919,
#  'live wire': 920,
#  'of mice and men': 1191,
#  'body parts': 922,
#  'cool world': 923,
#  'singles': 924,
#  'the naked city': 925,
#  'conquest of space': 926,
#  'wind': 927,
#  'the last of the mohicans': 928,
#  'consenting adults': 929,
#  'husbands and wives': 930,
#  'hero': 7704,
#  'ned kelly (ned kelly, outlaw)': 932,
#  'hallelujah': 933,
#  'the sea wolf': 934,
#  'forever young': 935,
#  'matinee': 936,
#  'unforgiven': 937,
#  'leap of faith': 938,
#  'malcolm x': 939,
#  'love on the run': 940,
#  'scent of a woman': 941,
#  'nowhere to run': 942,
#  'sniper': 943,
#  'the vanishing': 15975,
#  'the crush': 945,
#  'boiling point': 946,
#  'indian summer': 947,
#  'alive': 948,
#  'point of no return (the assassin)': 949,
#  "brother's keeper": 1392,
#  'stalker': 952,
#  'the browning version': 1014,
#  'made in america': 9926,
#  'cliffhanger': 956,
#  'frankenstein': 6693,
#  'the firm': 958,
#  'the black scorpion': 959,
#  'the lodger: a story of the london fog': 960,
#  'equinox': 961,
#  'wide sargasso sea': 963,
#  'the secret garden': 15773,
#  'strictly ballroom': 965,
#  'calendar girl': 966,
#  'savage messiah': 967,
#  'deadfall': 5277,
#  'much ado about nothing': 10706,
#  'airborne': 970,
#  'gettysburg': 971,
#  'fatal instinct': 972,
#  'high noon': 973,
#  'a home of our own': 974,
#  'fearless': 976,
#  "trauma (dario argento's trauma)": 977,
#  'cool runnings': 978,
#  'the skin game': 979,
#  'the man who loved women': 980,
#  'impact': 981,
#  'into the west': 982,
#  'scared stiff': 985,
#  'gunmen': 986,
#  'dangerous game': 987,
#  'angels in the outfield': 989,
#  'heaven & earth': 990,
#  'snow white and the seven dwarfs': 991,
#  'sugar hill': 992,
#  'thumbelina': 993,
#  'the young americans': 994,
#  'alice (neco z alenky)': 995,
#  'the last man on earth': 996,
#  "sherman's march": 997,
#  'bad girls': 998,
#  'dream lover': 999,
#  'black beauty': 1000,
#  'the circus': 1001,
#  'the kid': 15271,
#  'wyatt earp': 1003,
#  'betty': 1004,
#  'blown away': 1005,
#  'the mask': 1006,
#  'wolf': 17464,
#  'orlacs hände (the hands of orlac)': 1008,
#  'the shadow': 1009,
#  'it could happen to you': 1010,
#  'milk money': 1012,
#  'barcelona': 1013,
#  'only you': 1015,
#  'the specialist': 1016,
#  'titanic': 16297,
#  'beloved': 3406,
#  "rudyard kipling's the jungle book": 1019,
#  'the life and times of allen ginsberg': 1020,
#  'junior': 1021,
#  'street fighter': 1022,
#  'shallow grave': 1024,
#  'three colors: red (trois couleurs: rouge)': 1026,
#  'true crime': 1217,
#  "l'enfer": 1028,
#  "nobody's fool": 11141,
#  'the wild bunch': 1030,
#  'the quick and the dead': 1031,
#  'top dog': 1032,
#  'man of the house': 10022,
#  'born to be wild': 3902,
#  'hideaway': 1035,
#  'the babysitter': 14542,
#  'the old dark house': 1037,
#  'she': 1038,
#  'school for scoundrels': 12940,
#  'a little princess': 1041,
#  'mad love': 9909,
#  'bad boys': 3102,
#  'smoke': 1044,
#  'pocahontas': 1045,
#  'contraband': 4860,
#  ...}
