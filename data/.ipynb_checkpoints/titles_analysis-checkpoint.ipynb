# %%
import nltk
import os
import pandas as pd
import numpy as np
import json
import re

# %%
MOVIE_DATA = 'movies_metadata.csv'

# %%
with open(MOVIE_DATA, 'r') as f:
    movie_data_df = pd.read_csv(f)
    movie_titles = sorted(list(filter(lambda x: not pd.isnull(x), movie_data_df['original_title'])))

# %%
STEAM_DATA = os.path.join('steam_data', 'steam_data.csv')
AVAILABLE_GAMES = os.path.join('steamData', '80k_data', 'available_games.json')

# %%
available_game_ids = json.load(open(AVAILABLE_GAMES, 'r'))

# %%
with open(STEAM_DATA, 'r') as f:
    steam_data_df = pd.read_csv(f)
    fn = lambda x: x.url.split('/')[4]
    steam_data_df['app_id'] = steam_data_df.apply(fn, axis=1)

# %%
steam_data_df.columns
# Out:
# Index(['url', 'name', 'categories', 'img_url', 'user_reviews', 'all_reviews',
#        'date', 'developer', 'publisher', 'price', 'pegi', 'pegi_url',
#        'app_id'],
#       dtype='object')

# %%
game_name_to_app_id = dict()

for _, row in steam_data_df.iterrows():
    if type(row['name']) is str:
        try:
            game_name_to_app_id[row['name'].lower()] = int(row['app_id'])
        except ValueError:
            print(row['name'].lower(), row['app_id'])
# Out:
# - ?snr=1_7_7_230_150_2516

# %%
movie_name_to_id = dict()

for _, row in movie_data_df.iterrows():
    if type(row['original_title']) is str:
        try:
            movie_name_to_id[row['original_title'].lower()] = int(row['id'])
        except ValueError:
            print(row['original_title'].lower(), row['id'])
# Out:
# [{'iso_639_1': 'en', 'name': 'english'}] 1997-08-20
# [{'iso_639_1': 'ja', 'name': '日本語'}] 2012-09-29
# [{'iso_639_1': 'en', 'name': 'english'}] 2014-01-01

# %%
all_ids = set(steam_data_df['app_id'])
available_game_ids_set = set(map(str, available_game_ids))
steam_data_df_filtered = steam_data_df[steam_data_df['app_id'].isin(available_game_ids_set)]

# %%
steam_titles = list(sorted(set(steam_data_df_filtered['name'])))

# %%
movie_titles_set = set(map(lambda x: x.lower(), movie_titles))
steam_titles_set = set(map(lambda x: x.lower(), steam_titles))

# %%
same_title = {"same_titles": list(movie_titles_set.intersection(steam_titles_set))}
json.dump(same_title, open('./steamData/80k_data/movie_steam_same_titles.json', 'w+'), indent=4)

# %%
from difflib import SequenceMatcher
import time


movie_titles_list = sorted(list(movie_titles_set))
steam_titles_list = sorted(list(steam_titles_set))
title_sim_mat = np.zeros((len(movie_titles_list), len(steam_titles_list)))

start = time.time()
for i in range(len(movie_titles_list)):
    for j in range(len(steam_titles_list)):
        title_sim_mat[i,j] = SequenceMatcher(None, movie_titles_list[i], steam_titles_list[j]).ratio()
    cur_time = time.time()
    if (i % 1000 == 0):
        print(f'i = {i}')
        print(f'passed: {cur_time - start}')
# Out:
# i = 0
# passed: 0.1836872100830078
# i = 1000
# passed: 114.2695631980896
# i = 2000
# passed: 240.26640009880066
# i = 3000
# passed: 364.1208062171936
# i = 4000
# passed: 480.85472893714905
# i = 5000
# passed: 593.6970031261444
# i = 6000
# passed: 708.4435241222382
# i = 7000
# passed: 829.6288802623749
# i = 8000
# passed: 945.6394441127777
# i = 9000
# passed: 1063.9253451824188
# i = 10000
# passed: 1183.2306759357452
# i = 11000
# passed: 1300.1368520259857
# i = 12000
# passed: 1413.9015040397644
# i = 13000
# passed: 1528.693011045456
# i = 14000
# passed: 1648.5834851264954
# i = 15000
# passed: 1788.696878194809
# i = 16000
# passed: 1939.2748379707336
# i = 17000
# passed: 2054.988209247589
# i = 18000
# passed: 2181.014726161957
# i = 19000
# passed: 2306.0671360492706
# i = 20000
# passed: 2425.86403298378
# i = 21000
# passed: 2539.348191022873
# i = 22000
# passed: 2656.6945102214813
# i = 23000
# passed: 2776.734001159668
# i = 24000
# passed: 2891.2364790439606
# i = 25000
# passed: 3008.751808166504
# i = 26000
# passed: 3121.37815117836
# i = 27000
# passed: 3235.1492931842804
# i = 28000
# passed: 3351.7226481437683
# i = 29000
# passed: 3465.0547273159027
# i = 30000
# passed: 3575.34729719162
# i = 31000
# passed: 3700.0415301322937
# i = 32000
# passed: 3823.9275510311127
# i = 33000
# passed: 3950.17725110054
# i = 34000
# passed: 4082.061816215515
# i = 35000
# passed: 4210.005607128143
# i = 36000
# passed: 4336.656915903091
# i = 37000
# passed: 4457.7508590221405
# i = 38000
# passed: 4578.8206379413605
# i = 39000
# passed: 4707.14368891716
# i = 40000
# passed: 4826.184693098068
# i = 41000
# passed: 4909.14910531044
# i = 42000
# passed: 4959.997607946396
# i = 43000
# passed: 5003.575423955917

# %%
np.savetxt('./steamData/80k_data/movie_game_title_similarity_2.csv', title_sim_mat, delimiter=',')
# title_sim_mat = pd.DataFrame(title_sim_mat, columns = steam_titles_list, index = movie_titles_list)

# %%
title_sim_mat_df = pd.DataFrame(title_sim_mat, columns = steam_titles_list, index = movie_titles_list)
title_sim_mat_df.to_csv('./steamData/80k_data/movie_game_title_similarity_1.csv')

# %%
# from collections import Counter

# count = dict(Counter(list(map(lambda x: x.lower(), steam_titles))))
# print(sorted(list(count.values())))
len(available_game_ids), len(all_ids)
# Out:
# (2736, 68864)

# %%
title_top_100_similar_map = dict()

count = 0
for i, row in title_sim_mat_df.iterrows():
    top_100_sorted_idx = list(np.argsort(row)[::-1][:100])
#     print(i)
    if i not in movie_name_to_id.keys():
        continue 
    mov_id = str(movie_name_to_id[i])
    title_top_100_similar_map[mov_id] = []
    for idx in top_100_sorted_idx:
        title_top_100_similar_map[mov_id].append([game_name_to_app_id[steam_titles_list[idx]], row[idx]])
    count += 1
    if count % 1000 == 0:
        print (count)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000

# %%
json.dump(title_top_100_similar_map, open('./steamData/80k_data/movie_game_title_similarity.json', 'w+'))
# steam_data_df.loc[steam_data_df['name'].lower() == 'among us']
# len(set(movie_data_df.loc['']['original_title']))
# title_sim_mat_df.to_pickle('./steamData/80k_data/movie_game_title_similarity_1.pkl', compression='zip')
# import pickle

# with open('./steamData/80k_data/movie_game_title_similarity_1.pkl', 'wb') as output_file:
#     pickle.dump(title_sim_mat_df, output_file)

# %% [markdown]
# ## V2

# %%
movie_path = '/Users/susan/Development/cs4300/cs4300sp2020-cw887-qh75-rz92-yc687-yl698/data/movies_metadata.csv'


with open(movie_path, 'r') as f:
    movie_data_df = pd.read_csv(f)
    movie_titles = sorted(list(filter(lambda x: not pd.isnull(x), movie_data_df['original_title'])))

# %%
movie_data_df.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...  ...
#
#   release_date      revenue runtime  \
# 0   1995-10-30  373554033.0    81.0
# 1   1995-12-15  262797249.0   104.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                      tagline      title  video vote_average  \
# 0                                        NaN  Toy Story  False          7.7
# 1  Roll the dice and unleash the excitement!    Jumanji  False          6.9
#
#   vote_count
# 0     5415.0
# 1     2413.0
#
# [2 rows x 24 columns]

# %%
movie_data_df[movie_data_df['imdb_id'] == 'tt0113326']
# Out:
#      adult belongs_to_collection   budget  \
# 110  False                   NaN  7500000
#
#                                                 genres homepage     id  \
# 110  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...      NaN  33542
#
#        imdb_id original_language original_title  \
# 110  tt0113326                cn            紅番區
#
#                                               overview  ... release_date  \
# 110  Keong comes from Hong Kong to visit New York f...  ...   1995-01-30
#
#         revenue runtime                                   spoken_languages  \
# 110  32392047.0    91.0  [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'i...
#
#        status                          tagline                title  video  \
# 110  Released  No Fear. No Stuntman. No Equal.  Rumble in the Bronx  False
#
#     vote_average vote_count
# 110          6.5      245.0
#
# [1 rows x 24 columns]

# %%
import re
"".join(filter(str.isalpha, "!!!s我们"))
# Out:
# 's我们'

# %%
en_movies = movie_data_df[movie_data_df['original_language'] == 'en']

# %%
unique_en_movies = en_movies.drop_duplicates()

# %%
len(unique_en_movies)
# Out:
# 32262

# %%
len(set(unique_en_movies['id']))
# Out:
# 32251

# %%
len(set(unique_en_movies['original_title']))
# Out:
# 30493

# %%
# stopwords = [v[0] for v in my_stop_words]

# %%
def get_filtered_mov_name(row):
    name = row['original_title']
    if type(name) is not str or pd.isnull(name) or name == '0':
        return ""
    name = re.sub('\W+',' ', name.lower())
    text_tokens = nltk.tokenize.word_tokenize(name)
    tokens_without_sw = [word for word in text_tokens if not word in my_stop_words]
    filtered_name  = (" ").join(tokens_without_sw)
    return filtered_name

# %%
get_filtered_mov_name({"original_title": 'the lego movie'})
# Out:
# 'lego'

# %%
movie_data_df['filtered_name'] = movie_data_df.apply(lambda x: get_filtered_mov_name(x), axis=1)

# %%
movie_data_df_en = movie_data_df[movie_data_df['original_language'] == 'en']

# %%
movie_data_df_en_filtered_name = movie_data_df_en[{'id', 'filtered_name', 'original_title', 'imdb_id'}]

# %%
movie_title_filtered_df = os.path.join('movie_data', 'movie_title_filtered_df_3.csv')

movie_data_df_en_filtered_name.to_csv(open(movie_title_filtered_df, 'w+'))

# %%
movie_data_df_en_filtered_name[movie_data_df_en_filtered_name['original_title'] == 'The Lego Movie']
# Out:
#            id    imdb_id  original_title filtered_name
# 22718  137106  tt1490017  The Lego Movie          lego

# %%
# movie_title_id_map = dict()
# movie_id_title_map = dict()

# for _, row in movie_data_df_en_filtered_name.iterrows():
#     title = row['filtered_name']
#     mov_id = row['imdb_id']
#     if not pd.isnull(mov_id) and mov_id != '0':
#         mov_id = str(mov_id)
#     else: 
#         continue
#     if title not in movie_title_id_map.keys():
#         movie_title_id_map[title] = set()
#     movie_title_id_map[title].add(mov_id)
#     if mov_id not in movie_id_title_map.keys():
#         movie_id_title_map[mov_id] = set()
#     movie_id_title_map[mov_id].add(title)

# %%
# for k, v in movie_id_title_map.items():
#     if len(v) > 1:
#         print(f'{k} maps many titles')
#         print(v)
#     movie_id_title_map[k] = list(v)

# %%
# for k, v in movie_title_id_map.items():
#     movie_title_id_map[k] = list(v)
#     if len(v) > 1:
#         print(f'{k} maps many ids')
#         print(movie_title_id_map[k])

# %%
# mov_id_to_title = os.path.join('movie_data', 'movie_id_to_title_v2.json')
# mov_title_to_id = os.path.join('movie_data', 'movie_title_to_id_v2.json')

# %%
# json.dump(movie_title_id_map, open(mov_title_to_id, 'w+'), indent=4)
# json.dump(movie_id_title_map, open(mov_id_to_title, 'w+'), indent=4)

# %% [markdown]
# ## High Frequency Word Analysis

# %%
from sklearn.feature_extraction.text import CountVectorizer
titles = list(set(movie_data_df_en_filtered_name['original_title']))

# %%
def get_top_n_words(corpus, n=None):
    """
    List the top n words in a vocabulary according to occurrence in a text corpus.
    
    get_top_n_words(["I love Python", "Python is a language programming", "Hello world", "I love the world"]) -> 
    [('python', 2),
     ('world', 2),
     ('love', 2),
     ('hello', 1),
     ('is', 1),
     ('programming', 1),
     ('the', 1),
     ('language', 1)]
    """
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)
#     print(len(words_freq))
    if not n:
        return words_freq
    return words_freq[:n]

# %%
top_freq_token = get_top_n_words(titles)

# %%
top_freq_token_list = [val[0] for val in top_freq_token]

# %%
tagged_top_freq_token_list = nltk.pos_tag(top_freq_token_list)

# %%
tagged_top_freq_token_list
# Out:
# [('the', 'DT'),
#  ('of', 'IN'),
#  ('in', 'IN'),
#  ('and', 'CC'),
#  ('to', 'TO'),
#  ('man', 'NN'),
#  ('for', 'IN'),
#  ('on', 'IN'),
#  ('love', 'NN'),
#  ('story', 'NN'),
#  ('my', 'PRP$'),
#  ('you', 'PRP'),
#  ('night', 'NN'),
#  ('me', 'PRP'),
#  ('from', 'IN'),
#  ('life', 'NN'),
#  ('with', 'IN'),
#  ('at', 'IN'),
#  ('it', 'PRP'),
#  ('last', 'JJ'),
#  ('dead', 'JJ'),
#  ('is', 'VBZ'),
#  ('girl', 'JJ'),
#  ('american', 'JJ'),
#  ('one', 'CD'),
#  ('movie', 'NN'),
#  ('christmas', 'NN'),
#  ('all', 'DT'),
#  ('la', 'FW'),
#  ('world', 'NN'),
#  ('time', 'NN'),
#  ('ii', 'JJ'),
#  ('house', 'NN'),
#  ('day', 'NN'),
#  ('big', 'JJ'),
#  ('black', 'JJ'),
#  ('no', 'DT'),
#  ('little', 'JJ'),
#  ('up', 'RP'),
#  ('dark', 'JJ'),
#  ('death', 'NN'),
#  ('an', 'DT'),
#  ('new', 'JJ'),
#  ('out', 'RP'),
#  ('that', 'IN'),
#  ('blood', 'NN'),
#  ('who', 'WP'),
#  ('men', 'NNS'),
#  ('war', 'NN'),
#  ('lost', 'VBD'),
#  ('de', 'JJ'),
#  ('live', 'JJ'),
#  ('city', 'NN'),
#  ('king', 'NN'),
#  ('high', 'JJ'),
#  ('white', 'JJ'),
#  ('mr', 'NN'),
#  ('back', 'RB'),
#  ('girls', 'VBZ'),
#  ('we', 'PRP'),
#  ('wild', 'VBP'),
#  ('good', 'JJ'),
#  ('blue', 'NN'),
#  ('by', 'IN'),
#  ('this', 'DT'),
#  ('secret', 'JJ'),
#  ('woman', 'NN'),
#  ('two', 'CD'),
#  ('red', 'JJ'),
#  ('days', 'NNS'),
#  ('don', 'RB'),
#  ('great', 'JJ'),
#  ('what', 'WP'),
#  ('lady', 'VBZ'),
#  ('your', 'PRP$'),
#  ('home', 'NN'),
#  ('boy', 'NN'),
#  ('street', 'NN'),
#  ('bad', 'JJ'),
#  ('heart', 'NN'),
#  ('down', 'RP'),
#  ('way', 'NN'),
#  ('boys', 'IN'),
#  ('how', 'WRB'),
#  ('devil', 'JJ'),
#  ('die', 'NN'),
#  ('not', 'RB'),
#  ('be', 'VB'),
#  ('america', 'JJ'),
#  ('go', 'VB'),
#  ('road', 'NN'),
#  ('murder', 'NN'),
#  ('star', 'NN'),
#  ('people', 'NNS'),
#  ('summer', 'NN'),
#  ('three', 'CD'),
#  ('return', 'NN'),
#  ('about', 'IN'),
#  ('hell', 'NN'),
#  ('moon', 'NN'),
#  ('iii', 'NN'),
#  ('dog', 'NN'),
#  ('kill', 'NN'),
#  ('first', 'RB'),
#  ('young', 'JJ'),
#  ('le', 'NN'),
#  ('island', 'VB'),
#  ('part', 'NN'),
#  ('killer', 'NN'),
#  ('like', 'IN'),
#  ('god', 'JJ'),
#  ('legend', 'VBP'),
#  ('evil', 'NNS'),
#  ('sea', 'NN'),
#  ('year', 'NN'),
#  ('game', 'NN'),
#  ('when', 'WRB'),
#  ('monster', 'NN'),
#  ('space', 'NN'),
#  ('fire', 'NN'),
#  ('town', 'NN'),
#  ('never', 'RB'),
#  ('are', 'VBP'),
#  ('living', 'VBG'),
#  ('get', 'VB'),
#  ('kiss', 'JJ'),
#  ('long', 'JJ'),
#  ('rock', 'NN'),
#  ('women', 'NNS'),
#  ('baby', 'VBP'),
#  ('end', 'JJ'),
#  ('land', 'NN'),
#  ('york', 'NN'),
#  ('beyond', 'IN'),
#  ('family', 'NN'),
#  ('party', 'NN'),
#  ('earth', 'NN'),
#  ('vs', 'JJ'),
#  ('charlie', 'NN'),
#  ('dream', 'NN'),
#  ('after', 'IN'),
#  ('son', 'NN'),
#  ('do', 'VBP'),
#  ('can', 'MD'),
#  ('ghost', 'VB'),
#  ('kid', 'VB'),
#  ('before', 'IN'),
#  ('final', 'JJ'),
#  ('adventures', 'NNS'),
#  ('her', 'PRP$'),
#  ('dr', 'NN'),
#  ('hollywood', 'NN'),
#  ('case', 'NN'),
#  ('they', 'PRP'),
#  ('river', 'VBP'),
#  ('perfect', 'VBP'),
#  ('here', 'RB'),
#  ('west', 'VBP'),
#  ('song', 'JJ'),
#  ('she', 'PRP'),
#  ('room', 'NN'),
#  ('under', 'IN'),
#  ('our', 'PRP$'),
#  ('run', 'NN'),
#  ('el', 'RB'),
#  ('journey', 'NN'),
#  ('terror', 'NN'),
#  ('or', 'CC'),
#  ('best', 'JJS'),
#  ('jack', 'NN'),
#  ('let', 'NN'),
#  ('heaven', 'PRP'),
#  ('green', 'JJ'),
#  ('school', 'NN'),
#  ('gun', 'NN'),
#  ('true', 'JJ'),
#  ('am', 'VBP'),
#  ('fear', 'JJ'),
#  ('film', 'NN'),
#  ('just', 'RB'),
#  ('sex', 'NN'),
#  ('magic', 'JJ'),
#  ('adventure', 'NN'),
#  ('ice', 'NN'),
#  ('john', 'NN'),
#  ('tale', 'NN'),
#  ('park', 'NN'),
#  ('us', 'PRP'),
#  ('angels', 'VBP'),
#  ('di', 'JJ'),
#  ('wedding', 'NN'),
#  ('country', 'NN'),
#  ('too', 'RB'),
#  ('seven', 'CD'),
#  ('planet', 'JJ'),
#  ('hot', 'JJ'),
#  ('midnight', 'NN'),
#  ('five', 'CD'),
#  ('miss', 'NN'),
#  ('over', 'IN'),
#  ('queen', 'JJ'),
#  ('come', 'JJ'),
#  ('sun', 'NN'),
#  ('as', 'IN'),
#  ('dawn', 'NN'),
#  ('happy', 'JJ'),
#  ('four', 'CD'),
#  ('dance', 'NN'),
#  ('rise', 'NN'),
#  ('comedy', 'NN'),
#  ('children', 'NNS'),
#  ('goes', 'VBZ'),
#  ('hard', 'JJ'),
#  ('where', 'WRB'),
#  ('was', 'VBD'),
#  ('his', 'PRP$'),
#  ('lives', 'NNS'),
#  ('money', 'NN'),
#  ('joe', 'NN'),
#  ('now', 'RB'),
#  ('meet', 'VBZ'),
#  ('water', 'NN'),
#  ('angel', 'NN'),
#  ('sky', 'NN'),
#  ('crazy', 'JJ'),
#  ('old', 'JJ'),
#  ('cat', 'NN'),
#  ('mystery', 'NN'),
#  ('battle', 'NN'),
#  ('club', 'NN'),
#  ('paris', 'NN'),
#  ('doctor', 'NN'),
#  ('again', 'RB'),
#  ('fall', 'RB'),
#  ('re', 'VB'),
#  ('there', 'RB'),
#  ('beautiful', 'JJ'),
#  ('hero', 'NN'),
#  ('bride', 'NN'),
#  ('into', 'IN'),
#  ('sweet', 'JJ'),
#  ('mad', 'JJ'),
#  ('take', 'NN'),
#  ('vampire', 'NN'),
#  ('tom', 'JJ'),
#  ('thing', 'NN'),
#  ('special', 'JJ'),
#  ('next', 'JJ'),
#  ('bill', 'NN'),
#  ('george', 'VB'),
#  ('other', 'JJ'),
#  ('edge', 'JJ'),
#  ('eyes', 'NNS'),
#  ('deadly', 'RB'),
#  ('iron', 'VBP'),
#  ('deep', 'JJ'),
#  ('dirty', 'NN'),
#  ('light', 'JJ'),
#  ('truth', 'NN'),
#  ('years', 'NNS'),
#  ('brothers', 'VBZ'),
#  ('santa', 'JJ'),
#  ('les', 'NNS'),
#  ('alien', 'RB'),
#  ('without', 'IN'),
#  ('killing', 'VBG'),
#  ('strange', 'JJ'),
#  ('batman', 'JJ'),
#  ('side', 'NN'),
#  ('flight', 'NN'),
#  ('harry', 'NN'),
#  ('gold', 'NN'),
#  ('another', 'DT'),
#  ('ride', 'NN'),
#  ('revenge', 'NN'),
#  ('paradise', 'NN'),
#  ('blues', 'NNS'),
#  ('play', 'VBP'),
#  ('beach', 'JJ'),
#  ('dreams', 'NNS'),
#  ('human', 'VBP'),
#  ('behind', 'IN'),
#  ('il', 'NN'),
#  ('inside', 'IN'),
#  ('london', 'RB'),
#  ('dangerous', 'JJ'),
#  ('wars', 'NNS'),
#  ('only', 'RB'),
#  ('call', 'VBP'),
#  ('tales', 'NNS'),
#  ('book', 'NN'),
#  ('snow', 'VBP'),
#  ('princess', 'JJ'),
#  ('north', 'RB'),
#  ('train', 'VBP'),
#  ('hill', 'JJ'),
#  ('lake', 'VBP'),
#  ('shadow', 'JJ'),
#  ('stone', 'NN'),
#  ('if', 'IN'),
#  ('kids', 'NNS'),
#  ('eye', 'NN'),
#  ('captain', 'VBP'),
#  ('things', 'NNS'),
#  ('mountain', 'NN'),
#  ('holiday', 'RB'),
#  ('daughter', 'JJ'),
#  ('stranger', 'NN'),
#  ('private', 'JJ'),
#  ('body', 'NN'),
#  ('will', 'MD'),
#  ('away', 'RB'),
#  ('zero', 'CD'),
#  ('prince', 'NN'),
#  ('once', 'RB'),
#  ('free', 'JJ'),
#  ('massacre', 'NN'),
#  ('walk', 'NN'),
#  ('barbie', 'NN'),
#  ('face', 'NN'),
#  ('escape', 'NN'),
#  ('age', 'NN'),
#  ('dragon', 'NN'),
#  ('lucky', 'JJ'),
#  ('brown', 'JJ'),
#  ('doo', 'JJ'),
#  ('art', 'NN'),
#  ('music', 'NN'),
#  ('air', 'NN'),
#  ('louis', 'VBZ'),
#  ('child', 'JJ'),
#  ('power', 'NN'),
#  ('line', 'NN'),
#  ('wolf', 'NN'),
#  ('so', 'IN'),
#  ('justice', 'NN'),
#  ('show', 'NN'),
#  ('scooby', 'NN'),
#  ('nightmare', 'NN'),
#  ('father', 'NN'),
#  ('camp', 'NN'),
#  ('darkness', 'NN'),
#  ('cop', 'NN'),
#  ('un', 'JJ'),
#  ('johnny', 'NN'),
#  ('nothing', 'NN'),
#  ('off', 'IN'),
#  ('beast', 'NN'),
#  ('double', 'JJ'),
#  ('born', 'JJ'),
#  ('friends', 'NNS'),
#  ('texas', 'JJ'),
#  ('glory', 'NN'),
#  ('spy', 'NN'),
#  ('point', 'NN'),
#  ('mind', 'NN'),
#  ('10', 'CD'),
#  ('history', 'NN'),
#  ('curse', 'NN'),
#  ('mrs', 'NN'),
#  ('trouble', 'NN'),
#  ('broadway', 'RB'),
#  ('forever', 'RB'),
#  ('force', 'NN'),
#  ('guy', 'NN'),
#  ('witch', 'NN'),
#  ('place', 'NN'),
#  ('wife', 'NN'),
#  ('small', 'JJ'),
#  ('stand', 'VBP'),
#  ('something', 'NN'),
#  ('invisible', 'JJ'),
#  ('super', 'JJ'),
#  ('hotel', 'NN'),
#  ('mary', 'NN'),
#  ('zombie', 'NN'),
#  ('made', 'VBD'),
#  ('machine', 'NN'),
#  ('naked', 'JJ'),
#  ('alone', 'RB'),
#  ('project', 'NN'),
#  ('dracula', 'NN'),
#  ('perry', 'NN'),
#  ('why', 'WRB'),
#  ('going', 'VBG'),
#  ('were', 'VBD'),
#  ('valley', 'JJ'),
#  ('hearts', 'NNS'),
#  ('shadows', 'VBZ'),
#  ('13', 'CD'),
#  ('silent', 'JJ'),
#  ('times', 'NNS'),
#  ('jungle', 'VBP'),
#  ('came', 'VBD'),
#  ('horse', 'NN'),
#  ('kind', 'NN'),
#  ('shot', 'NN'),
#  ('flesh', 'JJ'),
#  ('hunter', 'NN'),
#  ('cold', 'VBD'),
#  ('diary', 'JJ'),
#  ('secrets', 'NNS'),
#  ('second', 'JJ'),
#  ('mars', 'NNS'),
#  ('henry', 'VBP'),
#  ('master', 'NN'),
#  ('wrong', 'JJ'),
#  ('mother', 'NN'),
#  ('soldier', 'NN'),
#  ('comes', 'VBZ'),
#  ('tomorrow', 'NN'),
#  ('know', 'JJ'),
#  ('dogs', 'NNS'),
#  ('fight', 'VBD'),
#  ('bridge', 'NN'),
#  ('frankenstein', 'RB'),
#  ('11', 'CD'),
#  ('shark', 'JJ'),
#  ('fury', 'NN'),
#  ('stars', 'NNS'),
#  ('jones', 'VBZ'),
#  ('brother', 'RB'),
#  ('attack', 'JJ'),
#  ('cry', 'NN'),
#  ('rising', 'VBG'),
#  ('winter', 'NN'),
#  ('jim', 'NN'),
#  ('work', 'NN'),
#  ('mason', 'NN'),
#  ('see', 'VBP'),
#  ('horror', 'NN'),
#  ('david', 'VB'),
#  ('hour', 'NN'),
#  ('tell', 'NN'),
#  ('million', 'CD'),
#  ('en', 'NN'),
#  ('business', 'NN'),
#  ('nation', 'NN'),
#  ('affair', 'NN'),
#  ('band', 'NN'),
#  ('rose', 'VBD'),
#  ('wind', 'JJ'),
#  ('grace', 'NN'),
#  ('faces', 'VBZ'),
#  ('make', 'VBP'),
#  ('head', 'NN'),
#  ('state', 'NN'),
#  ('michael', 'NN'),
#  ('he', 'PRP'),
#  ('billy', 'RB'),
#  ('making', 'VBG'),
#  ('still', 'RB'),
#  ('du', 'VB'),
#  ('haunted', 'JJ'),
#  ('soul', 'NN'),
#  ('race', 'NN'),
#  ('iv', 'NN'),
#  ('frank', 'JJ'),
#  ('league', 'NN'),
#  ('very', 'RB'),
#  ('zombies', 'VBZ'),
#  ('cool', 'NN'),
#  ('gone', 'VBN'),
#  ('golden', 'JJ'),
#  ('real', 'JJ'),
#  ('st', 'NN'),
#  ('wall', 'NN'),
#  ('breaking', 'VBG'),
#  ('jimmy', 'NN'),
#  ('ninja', 'NNS'),
#  ('have', 'VBP'),
#  ('trip', 'NN'),
#  ('broken', 'VBN'),
#  ('miracle', 'NN'),
#  ('chan', 'NN'),
#  ('beauty', 'NN'),
#  ('being', 'VBG'),
#  ('eddie', 'JJ'),
#  ('desert', 'NN'),
#  ('flying', 'VBG'),
#  ('six', 'CD'),
#  ('most', 'JJS'),
#  ('law', 'NN'),
#  ('vengeance', 'NN'),
#  ('central', 'JJ'),
#  ('funny', 'JJ'),
#  ('12', 'CD'),
#  ('brain', 'NN'),
#  ('friday', 'JJ'),
#  ('fast', 'JJ'),
#  ('alice', 'NN'),
#  ('welcome', 'NN'),
#  ('tarzan', 'NN'),
#  ('stop', 'VB'),
#  ('ll', 'NN'),
#  ('more', 'RBR'),
#  ('alive', 'JJ'),
#  ('teenage', 'NN'),
#  ('james', 'NNS'),
#  ('company', 'NN'),
#  ('phantom', 'NN'),
#  ('daddy', 'NN'),
#  ('manhattan', 'NN'),
#  ('stories', 'NNS'),
#  ('pink', 'VBP'),
#  ('sister', 'JJ'),
#  ('los', 'JJ'),
#  ('search', 'NN'),
#  ('top', 'JJ'),
#  ('mission', 'NN'),
#  ('hours', 'NNS'),
#  ('carry', 'VBP'),
#  ('del', 'JJ'),
#  ('kings', 'NNS'),
#  ('name', 'NN'),
#  ('look', 'VBP'),
#  ('sound', 'JJ'),
#  ('pretty', 'RB'),
#  ('voyage', 'JJ'),
#  ('national', 'JJ'),
#  ('confessions', 'NNS'),
#  ('superman', 'VBP'),
#  ('brooklyn', 'NN'),
#  ('veggietales', 'NNS'),
#  ('than', 'IN'),
#  ('mine', 'JJ'),
#  ('sam', 'JJ'),
#  ('hand', 'NN'),
#  ('quest', 'JJS'),
#  ('some', 'DT'),
#  ('married', 'VBD'),
#  ('ever', 'RB'),
#  ('happened', 'VBN'),
#  ('hall', 'NN'),
#  ('heat', 'NN'),
#  ('everything', 'NN'),
#  ('better', 'RBR'),
#  ('across', 'IN'),
#  ('thief', 'JJ'),
#  ('greatest', 'JJS'),
#  ('door', 'NN'),
#  ('rain', 'NN'),
#  ('season', 'NN'),
#  ('but', 'CC'),
#  ('express', 'RB'),
#  ('right', 'JJ'),
#  ('break', 'NN'),
#  ('robin', 'JJ'),
#  ('glass', 'NN'),
#  ('garden', 'NN'),
#  ('heroes', 'NNS'),
#  ('lord', 'VBD'),
#  ('enemy', 'RB'),
#  ('sleep', 'JJ'),
#  ('fu', 'NN'),
#  ('ten', 'NN'),
#  ('strangers', 'NNS'),
#  ('guys', 'VBP'),
#  ('holmes', 'NNS'),
#  ('talk', 'VB'),
#  ('giant', 'JJ'),
#  ('hills', 'NNS'),
#  ('games', 'NNS'),
#  ('san', 'JJ'),
#  ('richard', 'JJ'),
#  ('spirit', 'NN'),
#  ('bird', 'NN'),
#  ('freedom', 'NN'),
#  ('called', 'VBN'),
#  ('crime', 'NN'),
#  ('lies', 'VBZ'),
#  ('jane', 'NN'),
#  ('et', 'NN'),
#  ('chance', 'NN'),
#  ('got', 'VBD'),
#  ('weekend', 'NN'),
#  ('must', 'MD'),
#  ('lonely', 'RB'),
#  ('bloody', 'VB'),
#  ('bang', 'NN'),
#  ('missing', 'VBG'),
#  ('upon', 'NN'),
#  ('may', 'MD'),
#  ('far', 'RB'),
#  ('code', 'VB'),
#  ('romance', 'NN'),
#  ('easy', 'JJ'),
#  ('dear', 'JJ'),
#  ('own', 'JJ'),
#  ('tall', 'JJ'),
#  ('nights', 'NNS'),
#  ('trail', 'VBP'),
#  ('straight', 'JJ'),
#  ('burning', 'VBG'),
#  ('knight', 'NN'),
#  ('max', 'NN'),
#  ('dust', 'NN'),
#  ('south', 'JJ'),
#  ('ghosts', 'NNS'),
#  ('kingdom', 'VBP'),
#  ('tree', 'JJ'),
#  ('class', 'NN'),
#  ('hunt', 'NN'),
#  ('storm', 'NN'),
#  ('lovers', 'NNS'),
#  ('skin', 'VBP'),
#  ('action', 'NN'),
#  ('warrior', 'NN'),
#  ('through', 'IN'),
#  ('portrait', 'NN'),
#  ('act', 'NN'),
#  ('wish', 'NN'),
#  ('could', 'MD'),
#  ('3d', 'VB'),
#  ('musical', 'JJ'),
#  ('between', 'IN'),
#  ('change', 'NN'),
#  ('wives', 'NNS'),
#  ('blonde', 'VBP'),
#  ('zone', 'NN'),
#  ('halloween', 'NN'),
#  ('open', 'JJ'),
#  ('spring', 'NN'),
#  ('chasing', 'VBG'),
#  ('gay', 'JJ'),
#  ('amazing', 'JJ'),
#  ('apocalypse', 'NN'),
#  ('always', 'RB'),
#  ('number', 'NN'),
#  ('gang', 'JJ'),
#  ('drive', 'VBP'),
#  ('them', 'PRP'),
#  ('goodbye', 'JJ'),
#  ('morning', 'NN'),
#  ('eve', 'NN'),
#  ('circus', 'NN'),
#  ('date', 'NN'),
#  ('within', 'IN'),
#  ('hood', 'NN'),
#  ('sleeping', 'VBG'),
#  ('lion', 'NN'),
#  ('running', 'VBG'),
#  ('guns', 'NNS'),
#  ('eagle', 'VBP'),
#  ('honor', 'JJ'),
#  ('full', 'JJ'),
#  ('half', 'NN'),
#  ('takes', 'VBZ'),
#  ('team', 'NN'),
#  ('paul', 'NN'),
#  ('sunday', 'NN'),
#  ('pirates', 'VBZ'),
#  ('army', 'JJ'),
#  ('williams', 'NNS'),
#  ('tour', 'VBP'),
#  ('looking', 'VBG'),
#  ('castle', 'NN'),
#  ('dancing', 'VBG'),
#  ('getting', 'VBG'),
#  ('treasure', 'NN'),
#  ('fever', 'NN'),
#  ('vegas', 'NN'),
#  ('blind', 'IN'),
#  ('werewolf', 'JJ'),
#  ('legacy', 'NN'),
#  ('want', 'VBP'),
#  ('almost', 'RB'),
#  ('100', 'CD'),
#  ('future', 'JJ'),
#  ('chronicles', 'NNS'),
#  ('mickey', 'JJ'),
#  ('bullet', 'NN'),
#  ('sword', 'NN'),
#  ('gods', 'NNS'),
#  ('coming', 'VBG'),
#  ('smith', 'JJ'),
#  ('nine', 'CD'),
#  ('untold', 'JJ'),
#  ('against', 'IN'),
#  ('sherlock', 'NN'),
#  ('walking', 'VBG'),
#  ('minutes', 'NNS'),
#  ('cross', 'VBP'),
#  ('blade', 'NN'),
#  ('murders', 'NNS'),
#  ('50', 'CD'),
#  ('bear', 'NN'),
#  ('late', 'JJ'),
#  ('monsters', 'NNS'),
#  ('jesus', 'VBP'),
#  ('theroux', 'JJ'),
#  ('bob', 'NN'),
#  ('dick', 'JJ'),
#  ('picture', 'NN'),
#  ('fat', 'JJ'),
#  ('tiger', 'NN'),
#  ('bunny', 'NN'),
#  ('mask', 'NN'),
#  ('passion', 'NN'),
#  ('madness', 'NN'),
#  ('presents', 'NNS'),
#  ('china', 'VBP'),
#  ('eat', 'JJ'),
#  ('hate', 'JJ'),
#  ('price', 'NN'),
#  ('short', 'RB'),
#  ('did', 'VBD'),
#  ('teen', 'JJ'),
#  ('ring', 'NN'),
#  ('vacation', 'NN'),
#  ('shoes', 'NNS'),
#  ('lights', 'NNS'),
#  ('steel', 'NN'),
#  ('pride', 'NN'),
#  ('falls', 'VBZ'),
#  ('grave', 'VBP'),
#  ('ha', 'NN'),
#  ('jerry', 'NN'),
#  ('agent', 'NN'),
#  ('mike', 'NN'),
#  ('des', 'VBZ'),
#  ('turn', 'VBP'),
#  ('mummy', 'JJ'),
#  ('shoot', 'JJ'),
#  ('beneath', 'NN'),
#  ('jesse', 'NN'),
#  ('east', 'JJ'),
#  ('cut', 'NN'),
#  ('car', 'NN'),
#  ('job', 'NN'),
#  ('kevin', 'NN'),
#  ('sisters', 'NNS'),
#  ('box', 'VBP'),
#  ('circle', 'NN'),
#  ('eight', 'CD'),
#  ('hands', 'NNS'),
#  ('30', 'CD'),
#  ('thousand', 'NN'),
#  ('has', 'VBZ'),
#  ('waiting', 'VBG'),
#  ('silver', 'RB'),
#  ('rage', 'NN'),
#  ('lee', 'JJ'),
#  ('county', 'NN'),
#  ('trap', 'NN'),
#  ('unknown', 'JJ'),
#  ('dying', 'VBG'),
#  ('touch', 'JJ'),
#  ('mom', 'NN'),
#  ('academy', 'NN'),
#  ('empire', 'NN'),
#  ('jeff', 'NN'),
#  ('grand', 'JJ'),
#  ('sing', 'VBG'),
#  ('around', 'IN'),
#  ('rescue', 'NN'),
#  ('killers', 'NNS'),
#  ('satan', 'VBP'),
#  ('creek', 'JJ'),
#  ('third', 'JJ'),
#  ('fish', 'JJ'),
#  ('carol', 'NN'),
#  ('nick', 'JJ'),
#  ('returns', 'NNS'),
#  ('thunder', 'VB'),
#  ('bright', 'JJ'),
#  ('saw', 'NN'),
#  ('van', 'NN'),
#  ('lightning', 'VBG'),
#  ('moving', 'VBG'),
#  ('follow', 'JJ'),
#  ('generation', 'NN'),
#  ('letter', 'NN'),
#  ('dragons', 'NNS'),
#  ('incredible', 'JJ'),
#  ('oh', 'JJ'),
#  ('movies', 'NNS'),
#  ('united', 'VBD'),
#  ('left', 'VBD'),
#  ('prime', 'JJ'),
#  ('their', 'PRP$'),
#  ('lane', 'NN'),
#  ('animal', 'NN'),
#  ('past', 'IN'),
#  ('trek', 'NN'),
#  ('jackson', 'NN'),
#  ('rules', 'NNS'),
#  ('wanted', 'VBD'),
#  ('butterfly', 'NN'),
#  ('moonlight', 'JJ'),
#  ('streets', 'NNS'),
#  ('falling', 'VBG'),
#  ('detective', 'JJ'),
#  ('friend', 'NN'),
#  ('below', 'IN'),
#  ('worlds', 'NNS'),
#  ('words', 'NNS'),
#  ('forest', 'VBP'),
#  ('rush', 'NN'),
#  ('sin', 'NN'),
#  ('bachelor', 'NN'),
#  ('sunshine', 'NN'),
#  ('holy', 'JJ'),
#  ('honey', 'NN'),
#  ('president', 'NN'),
#  ('silence', 'NN'),
#  ('mighty', 'NN'),
#  ('meets', 'NNS'),
#  ('pete', 'VBP'),
#  ('sarah', 'JJ'),
#  ('roll', 'NN'),
#  ('adam', 'NN'),
#  ('johnson', 'NN'),
#  ('say', 'VBP'),
#  ('smart', 'JJ'),
#  ('remember', 'VB'),
#  ('happiness', 'JJ'),
#  ('brave', 'VB'),
#  ('dollar', 'NN'),
#  ('beat', 'VB'),
#  ('luck', 'JJ'),
#  ('experiment', 'JJ'),
#  ('radio', 'NN'),
#  ('outer', 'NN'),
#  ('bobby', 'NN'),
#  ('burn', 'NN'),
#  ('bell', 'NN'),
#  ('danger', 'NN'),
#  ('cowboy', 'NN'),
#  ('al', 'NN'),
#  ('nowhere', 'RB'),
#  ('finding', 'VBG'),
#  ('twilight', 'JJ'),
#  ('loves', 'NNS'),
#  ('valentine', 'VBP'),
#  ('among', 'IN'),
#  ('rio', 'NN'),
#  ('angry', 'JJ'),
#  ('mile', 'NN'),
#  ('fool', 'NN'),
#  ('police', 'NN'),
#  ('incident', 'NN'),
#  ('forbidden', 'NN'),
#  ('mark', 'NN'),
#  ('highway', 'NN'),
#  ('shanghai', 'NN'),
#  ('alley', 'JJ'),
#  ('redemption', 'NN'),
#  ('lie', 'NN'),
#  ('fun', 'NN'),
#  ('rabbit', 'NN'),
#  ('farm', 'NN'),
#  ('invasion', 'NN'),
#  ('magnificent', 'NN'),
#  ('da', 'JJ'),
#  ('step', 'NN'),
#  ('sunset', 'VBN'),
#  ('hello', 'JJ'),
#  ('souls', 'NNS'),
#  ('joy', 'VBP'),
#  ('las', 'NNS'),
#  ('martin', 'FW'),
#  ('plan', 'NN'),
#  ('demon', 'VBZ'),
#  ('saint', 'JJ'),
#  ('genius', 'NN'),
#  ('shock', 'NN'),
#  ('royal', 'NN'),
#  ('babylon', 'NN'),
#  ('bye', 'VBD'),
#  ('food', 'NN'),
#  ('think', 'VBP'),
#  ('need', 'NN'),
#  ('wicked', 'VBD'),
#  ('scared', 'JJ'),
#  ('states', 'NNS'),
#  ('diamond', 'VBP'),
#  ('exit', 'NN'),
#  ('citizen', 'NN'),
#  ('saving', 'VBG'),
#  ('ground', 'NN'),
#  ('hope', 'VBP'),
#  ('evening', 'VBG'),
#  ('bank', 'NN'),
#  ('wake', 'NN'),
#  ('taking', 'VBG'),
#  ('peter', 'NN'),
#  ('target', 'NN'),
#  ('roast', 'JJ'),
#  ('seduction', 'NN'),
#  ('rainbow', 'NN'),
#  ('conspiracy', 'NN'),
#  ('killed', 'VBD'),
#  ('gray', 'JJ'),
#  ('wonderful', 'JJ'),
#  ('000', 'CD'),
#  ('universe', 'JJ'),
#  ('catch', 'NN'),
#  ('darling', 'VBG'),
#  ('underground', 'JJ'),
#  ('13th', 'CD'),
#  ('operation', 'NN'),
#  ('inferno', 'NN'),
#  ('safe', 'JJ'),
#  ('revolution', 'NN'),
#  ('beginning', 'VBG'),
#  ('belle', 'JJ'),
#  ('carlin', 'NN'),
#  ('doll', 'NN'),
#  ('merry', 'NN'),
#  ('bears', 'VBZ'),
#  ('runner', 'VBP'),
#  ('chapter', 'NN'),
#  ('him', 'PRP'),
#  ('dinner', 'VBP'),
#  ('fly', 'JJ'),
#  ('bruce', 'NN'),
#  ('monkey', 'NN'),
#  ('em', 'NN'),
#  ('soldiers', 'NNS'),
#  ('cinema', 'VBP'),
#  ('spider', 'JJ'),
#  ('century', 'NN'),
#  ('passage', 'NN'),
#  ('above', 'IN'),
#  ('arthur', 'NN'),
#  ('siege', 'NN'),
#  ('tower', 'NN'),
#  ('honeymoon', 'NN'),
#  ('wolves', 'NNS'),
#  ('molly', 'RB'),
#  ('kung', 'VBP'),
#  ('annie', 'RB'),
#  ('met', 'VBN'),
#  ('modern', 'JJ'),
#  ('marriage', 'NN'),
#  ('lisa', 'NN'),
#  ('dad', 'NN'),
#  ('uncle', 'NN'),
#  ('reunion', 'NN'),
#  ('breakfast', 'NN'),
#  ('command', 'NN'),
#  ('dave', 'VBP'),
#  ('liberty', 'NN'),
#  ('rocky', 'NN'),
#  ('africa', 'NN'),
#  ('color', 'NN'),
#  ('fighting', 'VBG'),
#  ('kelly', 'RB'),
#  ('saints', 'NNS'),
#  ('beer', 'NN'),
#  ('lone', 'NN'),
#  ('inc', 'NN'),
#  ('damned', 'VBD'),
#  ('robert', 'JJ'),
#  ('sharpe', 'NN'),
#  ('sealed', 'VBD'),
#  ('lovely', 'RB'),
#  ('hit', 'VBN'),
#  ('candy', 'NN'),
#  ('lego', 'NN'),
#  ('together', 'RB'),
#  ('21', 'CD'),
#  ('tomb', 'NN'),
#  ('emperor', 'NN'),
#  ('begins', 'VBZ'),
#  ('fantastic', 'JJ'),
#  ('savage', 'NN'),
#  ('knights', 'NNS'),
#  ('saturday', 'VBP'),
#  ('rich', 'JJ'),
#  ('hollow', 'NN'),
#  ('gift', 'NN'),
#  ('wilderness', 'NN'),
#  ('laugh', 'IN'),
#  ('raiders', 'NNS'),
#  ('parade', 'VBP'),
#  ('ernest', 'JJS'),
#  ('forgotten', 'JJ'),
#  ('cinderella', 'NN'),
#  ('chicago', 'NN'),
#  ('witness', 'NN'),
#  ('thin', 'JJ'),
#  ('paper', 'NN'),
#  ('bikini', 'NN'),
#  ('puppet', 'NN'),
#  ('claus', 'NN'),
#  ('lampoon', 'NN'),
#  ('20', 'CD'),
#  ('2000', 'CD'),
#  ('list', 'NN'),
#  ('nobody', 'NN'),
#  ('hart', 'VBZ'),
#  ('normal', 'JJ'),
#  ('went', 'VBD'),
#  ('bay', 'JJ'),
#  ('scenes', 'NNS'),
#  ('anything', 'NN'),
#  ('ladies', 'VBZ'),
#  ('courage', 'VBP'),
#  ...]

# %%
top_50_words = [t[0] for t in tagged_top_freq_token_list[:50]]
print(top_50_words)
# Out:
# ['the', 'of', 'in', 'and', 'to', 'man', 'for', 'on', 'love', 'story', 'my', 'you', 'night', 'me', 'from', 'life', 'with', 'at', 'it', 'last', 'dead', 'is', 'girl', 'american', 'one', 'movie', 'christmas', 'all', 'la', 'world', 'time', 'ii', 'house', 'day', 'big', 'black', 'no', 'little', 'up', 'dark', 'death', 'an', 'new', 'out', 'that', 'blood', 'who', 'men', 'war', 'lost']

# %%
my_stop_words = [val[0] for val in tagged_top_freq_token_list[0:400]]

# %%
my_stop_words = []

for v in tagged_top_freq_token_list[:300]:
    if v[1] in ['DT', 'IN', 'TO', 'CC', 'WP', 'VBZ', 'FW', 'PRP', 'PRP$']  or v[0] in ['be', 'is', 'de', 'ii', 'iii', 'iv', 'vi', 'ix'] or v[0] in top_50_words:
        my_stop_words.append(v)
print(my_stop_words)
print(len(my_stop_words))
# Out:
# [('the', 'DT'), ('of', 'IN'), ('in', 'IN'), ('and', 'CC'), ('to', 'TO'), ('man', 'NN'), ('for', 'IN'), ('on', 'IN'), ('love', 'NN'), ('story', 'NN'), ('my', 'PRP$'), ('you', 'PRP'), ('night', 'NN'), ('me', 'PRP'), ('from', 'IN'), ('life', 'NN'), ('with', 'IN'), ('at', 'IN'), ('it', 'PRP'), ('last', 'JJ'), ('dead', 'JJ'), ('is', 'VBZ'), ('girl', 'JJ'), ('american', 'JJ'), ('one', 'CD'), ('movie', 'NN'), ('christmas', 'NN'), ('all', 'DT'), ('la', 'FW'), ('world', 'NN'), ('time', 'NN'), ('ii', 'JJ'), ('house', 'NN'), ('day', 'NN'), ('big', 'JJ'), ('black', 'JJ'), ('no', 'DT'), ('little', 'JJ'), ('up', 'RP'), ('dark', 'JJ'), ('death', 'NN'), ('an', 'DT'), ('new', 'JJ'), ('out', 'RP'), ('that', 'IN'), ('blood', 'NN'), ('who', 'WP'), ('men', 'NNS'), ('war', 'NN'), ('lost', 'VBD'), ('de', 'JJ'), ('girls', 'VBZ'), ('we', 'PRP'), ('by', 'IN'), ('this', 'DT'), ('what', 'WP'), ('lady', 'VBZ'), ('your', 'PRP$'), ('boys', 'IN'), ('be', 'VB'), ('about', 'IN'), ('iii', 'NN'), ('like', 'IN'), ('beyond', 'IN'), ('after', 'IN'), ('before', 'IN'), ('her', 'PRP$'), ('they', 'PRP'), ('she', 'PRP'), ('under', 'IN'), ('our', 'PRP$'), ('or', 'CC'), ('heaven', 'PRP'), ('us', 'PRP'), ('over', 'IN'), ('as', 'IN'), ('goes', 'VBZ'), ('his', 'PRP$'), ('meet', 'VBZ'), ('into', 'IN'), ('brothers', 'VBZ'), ('without', 'IN'), ('another', 'DT'), ('behind', 'IN'), ('inside', 'IN'), ('if', 'IN')]
# 86

# %%
# my_stop_words2 = []

# for v in nltk.pos_tag(stopwords.words()):
#     if v[1] in ['DT', 'IN', 'TO', 'CC', 'WP', 'VBZ',  'PRP', 'PRP$']  or v[0] in ['be', 'is', 'de', 'ii', 'iii', 'iv', 'vi', 'ix']:
#         my_stop_words2.append(v)
# print(my_stop_words2)
# print(len(my_stop_words2))

# %%
# stop_words = ['the', 'of', 'in', 'and', 'la', 'to', 'de', 'le', 'on', 'for', 'my', 'you', 'les', 'me', ]

# %%
# nltk_words = list(nltk.corpus.stopwords.words('english'))

# %%
# nltk_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# # get filtered names
# from nltk.corpus import stopwords

# mov_id_to_filtered_title = dict()
# count = 0
# for mov_id, names in movie_id_title_map.items():
#     count += 1
#     if count % 1000 == 0:
#         print (count)
#     mov_id_to_filtered_title[mov_id] = []
#     for name in names:
#         text_tokens = nltk.tokenize.word_tokenize(name)
#         tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]
#         filtered_name = (" ").join(tokens_without_sw)
#         mov_id_to_filtered_title[mov_id].append(filtered_name)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000

# %%
mov_id_to_filtered_title
# Out:
# {'tt0114709': ['toy story'],
#  'tt0113497': ['jumanji'],
#  'tt0113228': ['grumpier old'],
#  'tt0114885': ['waiting exhale'],
#  'tt0113041': ['father bride part'],
#  'tt0113277': ['heat'],
#  'tt0114319': ['sabrina'],
#  'tt0112302': ['tom huck'],
#  'tt0114576': ['sudden death'],
#  'tt0113189': ['goldeneye'],
#  'tt0112346': ['american president'],
#  'tt0112896': ['dracula dead loving'],
#  'tt0112453': ['balto'],
#  'tt0113987': ['nixon'],
#  'tt0112760': ['cutthroat island'],
#  'tt0112641': ['casino'],
#  'tt0114388': ['sense sensibility'],
#  'tt0113101': ['four rooms'],
#  'tt0112281': ['ace ventura nature calls'],
#  'tt0113845': ['money train'],
#  'tt0113161': ['get shorty'],
#  'tt0112722': ['copycat'],
#  'tt0112401': ['assassins'],
#  'tt0114168': ['powder'],
#  'tt0113627': ['leaving vegas'],
#  'tt0114057': ['othello'],
#  'tt0114011': [''],
#  'tt0114117': ['persuasion'],
#  'tt0112682': ['cité enfants perdus'],
#  'tt0115012': ['摇啊摇 摇到外婆桥'],
#  'tt0112792': ['dangerous minds'],
#  'tt0114746': ['twelve monkeys'],
#  'tt0114952': ['guillaumet ailes courage'],
#  'tt0112431': ['babe'],
#  'tt0112637': ['carrington'],
#  'tt0112818': ['dead walking'],
#  'tt0112286': ['across time'],
#  'tt0113442': ['takes two'],
#  'tt0112697': ['clueless'],
#  'tt0112749': ['cry beloved country'],
#  'tt0114279': ['richard iii'],
#  'tt0112819': ['dead presidents'],
#  'tt0114272': ['restoration'],
#  'tt0113855': ['mortal kombat'],
#  'tt0114681': [''],
#  'tt0113347': ['make american quilt'],
#  'tt0114369': ['se7en'],
#  'tt0114148': ['pocahontas'],
#  'tt0114916': ['night falling'],
#  'tt0114814': ['usual suspects'],
#  'tt0109950': ['guardian angel'],
#  'tt0113819': ['mighty aphrodite'],
#  'tt0110299': ['lamerica'],
#  'tt0112499': ['big green'],
#  'tt0113158': ['georgia'],
#  'tt0113541': ['kids round table'],
#  'tt0113321': ['home holidays'],
#  'tt0110877': ['postino'],
#  'tt0112714': ['confessionnal'],
#  'tt0113419': ['indian cupboard'],
#  'tt0116260': ['eye eye'],
#  'tt0113862': ['mr holland opus'],
#  'tt0116126': ['menace south central drinking juice hood'],
#  'tt0118002': ['two'],
#  'tt0115683': ['bio dome'],
#  'tt0116839': ['lawnmower 2 beyond cyberspace'],
#  'tt0114753': ['two bits'],
#  'tt0113149': ['gazon maudit'],
#  'tt0113118': ['friday'],
#  'tt0116367': ['dusk dawn'],
#  'tt0113010': ['fair game'],
#  'tt0113537': ['kicking screaming'],
#  'tt0113828': ['misérables'],
#  'tt0115644': ['bed roses'],
#  'tt0115676': ['big bully'],
#  'tt0114367': ['screamers'],
#  'tt0113973': ['nico icon'],
#  'tt0112744': ['crossing guard'],
#  'tt0116731': ['juror'],
#  'tt0112445': ['بادکنک سفید'],
#  'tt0114660': ['things denver dead'],
#  'tt0112379': ['antonia'],
#  'tt0114039': ['upon time colored'],
#  'tt0113612': ['last summer hamptons'],
#  'tt0112365': ['angels insects'],
#  'tt0118158': ['white squall'],
#  'tt0116151': ['dunston checks'],
#  'tt0115697': ['black sheep'],
#  'tt0113972': ['nick time'],
#  'tt0113490': ['journey august king'],
#  'tt0117002': ['mary reilly'],
#  'tt0114825': ['vampire brooklyn'],
#  'tt0115639': ['beautiful girls'],
#  'tt0115759': ['broken arrow'],
#  'tt0113403': ['midwinter'],
#  'tt0113247': ['haine'],
#  'tt0111173': ['shopping'],
#  'tt0113283': ['heidi fleiss hollywood madam'],
#  'tt0115907': ['city hall'],
#  'tt0115734': ['bottle rocket'],
#  'tt0117102': ['mr wrong'],
#  'tt0118040': ['unforgettable'],
#  'tt0116483': ['happy gilmore'],
#  'tt0112579': ['bridges madison county'],
#  'tt0110251': ['liebt'],
#  'tt0117110': ['muppet treasure island'],
#  'tt0112646': ['catwalk'],
#  'tt0113276': ['headless body topless bar'],
#  'tt0112573': ['braveheart'],
#  'tt0075314': ['taxi driver'],
#  'tt0113326': ['紅番區'],
#  'tt0115645': [''],
#  'tt0113774': ['margaret museum'],
#  'tt0112556': ['bonheur pré'],
#  'tt0112373': ['anne frank remembered'],
#  'tt0115033': ['young poisoner handbook'],
#  'tt0116606': ['lucy fell'],
#  'tt0114536': ['steal big steal little'],
#  'tt0117427': ['race sun'],
#  'tt0106473': ['boys st vincent'],
#  'tt0103859': ['boomerang'],
#  'tt0109424': ['重慶森林'],
#  'tt0114808': ['uomo stelle'],
#  'tt0116324': ['flirting disaster'],
#  'tt0110647': ['neverending story iii'],
#  'tt0111055': ['صمت القصور'],
#  'tt0110217': ['jupiter wife'],
#  'tt0114131': ['pie sky'],
#  'tt0112364': ['angela'],
#  'tt0113107': ['frankie starlight'],
#  'tt0113451': ['jade'],
#  'tt0114015': ['nueba yol'],
#  'tt0114500': ['sonic outlaws'],
#  'tt0116130': ['periscope'],
#  'tt0113125': ['journals jean seberg'],
#  'tt0113756': ['year'],
#  'tt0113952': ['neon bible'],
#  'tt0114618': ['target'],
#  'tt0118055': ['close personal'],
#  'tt0115685': ['birdcage'],
#  'tt0113200': ['gospa'],
#  'tt0112585': ['brothers mcmullen'],
#  'tt0112442': ['bad boys'],
#  'tt0112342': ['amazing panda adventure'],
#  'tt0112461': ['basketball diaries'],
#  'tt0112427': ['awfully big adventure'],
#  'tt0109093': ['amateur'],
#  'tt0112384': ['apollo 13'],
#  'tt0114287': ['rob roy'],
#  'tt0112288': ['addiction'],
#  'tt0112462': ['batman forever'],
#  'tt0061395': ['belle jour'],
#  'tt0112495': ['beyond rangoon'],
#  'tt0112541': ['blue'],
#  'tt0109370': ['canadian bacon'],
#  'tt0112642': ['casper'],
#  'tt0112688': ['clockers'],
#  'tt0112715': ['congo'],
#  'tt0112740': ['crimson tide'],
#  'tt0109508': ['crumb'],
#  'tt0112851': ['desperado'],
#  'tt0112857': ['devil blue dress'],
#  'tt0112864': ['hard vengeance'],
#  'tt0112887': ['doom generation'],
#  'tt0113044': ['feast july'],
#  'tt0113071': ['first knight'],
#  'tt0113114': ['free willy 2 adventure home'],
#  'tt0113243': ['hackers'],
#  'tt0113464': ['jeffrey'],
#  'tt0113481': ['johnny mnemonic'],
#  'tt0113492': ['judge dredd'],
#  'tt0113500': ['jury duty'],
#  'tt0113540': ['kids'],
#  'tt0113677': ['living oblivion'],
#  'tt0113690': ['lord illusions'],
#  'tt0107447': ['love human remains'],
#  'tt0113729': ['mad love'],
#  'tt0113749': ['mallrats'],
#  'tt0113820': ['mighty morphin power rangers movie'],
#  'tt0113851': ['moonlight valentino'],
#  'tt0110604': ['mute witness'],
#  'tt0110620': ['nadja'],
#  'tt0113957': ['net'],
#  'tt0113986': ['nine months'],
#  'tt0114095': ['party girl'],
#  'tt0114194': ['prophecy'],
#  'tt0114241': ['reckless'],
#  'tt0114323': ['safe'],
#  'tt0114345': ['scarlet letter'],
#  'tt0114435': ['show'],
#  'tt0114436': ['showgirls'],
#  'tt0114478': ['smoke'],
#  'tt0114496': ['something talk'],
#  'tt0114508': ['species'],
#  'tt0114534': ['stars fell henrietta'],
#  'tt0114558': ['strange days'],
#  'tt0058450': ['parapluies cherbourg'],
#  'tt0114666': ['tie binds'],
#  'tt0114663': ['three wishes'],
#  'tt0114702': ['total eclipse'],
#  'tt0114682': ['foo thanks everything julie newmar'],
#  'tt0114781': ['siege 2 dark territory'],
#  'tt0114798': ['unstrung heroes'],
#  'tt0114805': ['unzipped'],
#  'tt0114887': ['walk clouds'],
#  'tt0114898': ['waterworld'],
#  'tt0114928': ['white burden'],
#  'tt0114938': ['wild bill'],
#  'tt0109340': ['browning version'],
#  'tt0112602': ['bushwhacked'],
#  'tt0111579': ['утомлённые солнцем'],
#  'tt0110882': ['rain'],
#  'tt0112471': ['sunrise'],
#  'tt0112508': ['billy madison'],
#  'tt0112438': ['babysitter'],
#  'tt0112571': ['boys side'],
#  'tt0112757': ['cure'],
#  'tt0112643': ['castle freak'],
#  'tt0112679': ['circle friends'],
#  'tt0109445': ['clerks'],
#  'tt0112883': ['juan demarco'],
#  'tt0109635': ['disclosure'],
#  'tt0112899': ['dream'],
#  'tt0109676': ['drop zone'],
#  'tt0112854': ['destiny turns radio'],
#  'tt0109579': ['death maiden'],
#  'tt0109642': ['dolores claiborne'],
#  'tt0109686': ['dumb dumber'],
#  'tt0111797': ['飲食男女'],
#  'tt0109759': ['exotica'],
#  'tt0109758': ['exit'],
#  'tt0109707': ['wood'],
#  'tt0113117': ['french kiss'],
#  'tt0113097': ['forget paris'],
#  'tt0113028': ['far home adventures yellow'],
#  'tt0113198': ['goofy movie'],
#  'tt0113303': ['hideaway'],
#  'tt0113089': ['fluke'],
#  'tt0109771': ['farinelli'],
#  'tt0113199': ['gordy'],
#  'tt0113234': ['gumby movie'],
#  'tt0109906': ['glass shield'],
#  'tt0110057': ['hoop dreams'],
#  'tt0110005': ['heavenly creatures'],
#  'tt0110066': ['houseguest'],
#  'tt0110116': ['immortal beloved'],
#  'tt0110006': ['heavyweights'],
#  'tt0113360': ['hunted'],
#  'tt0110099': ['q'],
#  'tt0110148': ['interview vampire'],
#  'tt0113463': ['jefferson paris'],
#  'tt0110189': ['jerky boys'],
#  'tt0110216': ['junior'],
#  'tt0113501': ['cause'],
#  'tt0113538': ['kid king arthur court'],
#  'tt0113552': ['kiss death'],
#  'tt0076759': ['star wars'],
#  'tt0110367': ['little women'],
#  'tt0113670': ['little princess'],
#  'tt0110296': ['ladybird ladybird'],
#  'tt0109731': ['enfer'],
#  'tt0103994': ['agua chocolate'],
#  'tt0110322': ['legends fall'],
#  'tt0110443': ['major payne'],
#  'tt0110365': ['little odessa'],
#  'tt0107566': ['vida loca'],
#  'tt0110391': ['love affair'],
#  'tt0113691': ['losing isaiah'],
#  'tt0110428': ['madness king george'],
#  'tt0109836': ['frankenstein'],
#  'tt0113755': ['house'],
#  'tt0110538': ['mixed nuts'],
#  'tt0110516': ['milk money'],
#  'tt0110527': ['miracle 34th street'],
#  'tt0113808': ['miami rhapsody'],
#  'tt0113896': ['family'],
#  'tt0113870': ['murder first'],
#  'tt0110684': ['nobody fool'],
#  'tt0110638': [''],
#  'tt0113967': ['new jersey drive'],
#  'tt0117169': ['new york cop'],
#  'tt0106402': ['beyond bedlam'],
#  'tt0113948': ['nemesis 2 nebula'],
#  'tt0110671': ['nina takes lover'],
#  'tt0110632': ['natural born killers'],
#  'tt0110737': [''],
#  'tt0110729': ['warriors'],
#  'tt0114151': ['poison ivy lily'],
#  'tt0114069': ['outbreak'],
#  'tt0110413': ['léon'],
#  'tt0114113': ['perez family'],
#  'tt0114210': ['pyromaniac love story'],
#  'tt0110912': ['pulp fiction'],
#  'tt0114084': ['panther'],
#  'tt0105652': ['pushing hands'],
#  'tt0110889': ['priest'],
#  'tt0110932': ['quiz show'],
#  'tt0114129': ['picture bride'],
#  'tt0110963': ['reine margot'],
#  'tt0114214': ['quick dead'],
#  'tt0114296': ['roommates'],
#  'tt0110907': ['prêt porter'],
#  'tt0111495': ['trois couleurs rouge'],
#  'tt0108394': ['trois couleurs bleu'],
#  'tt0111507': ['trois couleurs blanc'],
#  'tt0110769': ['pao shuang deng'],
#  'tt0114268': ['rent kid'],
#  'tt0110965': ['relative fear'],
#  'tt0114571': ['stuart saves family'],
#  'tt0111333': ['swan princess'],
#  'tt0111112': ['secret roan inish'],
#  'tt0111255': ['specialist'],
#  'tt0111282': ['stargate'],
#  'tt0111070': ['santa clause'],
#  'tt0111161': ['shawshank redemption'],
#  'tt0111149': ['shallow grave'],
#  'tt0108260': ['suture'],
#  'tt0106966': ['fresa chocolate'],
#  'tt0114594': ['swimming sharks'],
#  'tt0111309': ['sum us'],
#  'tt0113936': ['senior trip'],
#  'tt0110081': ['活着'],
#  'tt0114614': ['tank girl'],
#  'tt0114608': ['tales crypt demon knight'],
#  'tt0111280': ['star trek generations'],
#  'tt0114609': ['tales hood'],
#  'tt0111454': ['tom viv'],
#  'tt0114852': ['village damned'],
#  'tt0114694': ['tommy boy'],
#  'tt0111590': ['vanya 42nd street'],
#  'tt0114788': ['underneath'],
#  'tt0114888': ['walking dead'],
#  'tt0108550': ['eating gilbert grape'],
#  'tt0114857': ['virtuosity'],
#  'tt0114924': ['sleeping'],
#  'tt0111667': [''],
#  'tt0109655': ['double happiness'],
#  'tt0110598': ['muriel wedding'],
#  'tt0112435': ['baby sitters club'],
#  'tt0109040': ['ace ventura detective'],
#  'tt0109045': ['adventures priscilla queen desert'],
#  'tt0106339': ['backbeat'],
#  'tt0104779': ['bitter moon'],
#  'tt0109348': ['bullets broadway'],
#  'tt0109444': ['clear present danger'],
#  'tt0109446': ['client'],
#  'tt0109484': ['corrina corrina'],
#  'tt0109504': ['crooklyn'],
#  'tt0109506': ['crow'],
#  'tt0109450': ['cobb'],
#  'tt0109813': ['flintstones'],
#  'tt0109830': ['forrest gump'],
#  'tt0109831': ['four weddings funeral'],
#  'tt0113305': ['higher learning'],
#  'tt0110091': ['like like'],
#  'tt0110093': ['love trouble'],
#  'tt0110167': ['could happen'],
#  'tt0110213': ['jungle book'],
#  'tt0107472': ['macht bilder leni riefenstahl'],
#  'tt0110357': ['lion king'],
#  'tt0107426': ['little buddha'],
#  'tt0111686': ['new nightmare'],
#  'tt0110475': ['mask'],
#  'tt0110478': ['maverick'],
#  'tt0110588': ['mrs parker vicious circle'],
#  'tt0110622': ['naked gun 33⅓ final insult'],
#  'tt0110771': ['paper'],
#  'tt0110950': ['reality bites'],
#  'tt0105226': ['red rock west'],
#  'tt0110989': ['ri hie ri'],
#  'tt0111054': ['safe passage'],
#  'tt0110997': ['river wild'],
#  'tt0111257': ['speed'],
#  'tt0111256': ['speechless'],
#  'tt0111438': ['timecop'],
#  'tt0111503': ['true lies'],
#  'tt0111693': ['loves woman'],
#  'tt0111742': ['wolf'],
#  'tt0111756': ['wyatt earp'],
#  'tt0112443': ['bad company'],
#  'tt0110455': ['importance'],
#  'tt0111048': ['f w'],
#  'tt0110399': ['low dirty shame'],
#  'tt0112570': ['boys life three stories love lust liberation'],
#  'tt0109454': ['colonel chabert'],
#  'tt0059170': ['faster pussycat kill kill'],
#  'tt0110186': ['jason lyric'],
#  'tt0108069': ['secret adventures tom thumb'],
#  'tt0111301': ['street fighter'],
#  'tt0112702': ['coldblooded'],
#  'tt0112849': ['desert winds'],
#  'tt0113014': ['fall time'],
#  'tt0113043': ['fear'],
#  'tt0113104': ['frank ollie'],
#  'tt0113173': ['girl cadillac'],
#  'tt0113319': ['homage'],
#  'tt0113827': ['mirage'],
#  'tt0114047': ['open season'],
#  'tt0112889': ['crímenes'],
#  'tt0109339': ['brother minister assassination malcolm x'],
#  'tt0110027': ['highlander iii sorcerer'],
#  'tt0109785': ['federal hill'],
#  'tt0113409': ['mouth madness'],
#  'tt0109021': ['8 seconds'],
#  'tt0109035': ['rim'],
#  'tt0106220': ['addams family values'],
#  'tt0111804': ['martin lawrence crazy'],
#  'tt0106226': ['age innocence'],
#  'tt0109068': ['airheads'],
#  'tt0109067': ['air'],
#  'tt0106292': ['another stakeout'],
#  'tt0109198': ['bad girls'],
#  'tt0109219': ['barcelona'],
#  'tt0106379': ['human'],
#  'tt0106400': ['beverly hillbillies'],
#  'tt0109254': ['beverly hills cop iii'],
#  'tt0109279': ['black beauty'],
#  'tt0109297': ['blink'],
#  'tt0109303': ['blown away'],
#  'tt0109305': ['blue chips'],
#  'tt0109306': ['blue sky'],
#  'tt0106452': ['body snatchers'],
#  'tt0106471': ['boxing helena'],
#  'tt0106489': ['bronx'],
#  'tt0109361': ['cabin boy'],
#  'tt0106505': ['calendar girl'],
#  'tt0106519': ['carlito way'],
#  'tt0109439': ['city slickers legend curly gold'],
#  'tt0109443': ['clean slate'],
#  'tt0106582': ['cliffhanger'],
#  'tt0106598': ['coneheads'],
#  'tt0109456': ['color night'],
#  'tt0109480': ['cops robbersons'],
#  'tt0109493': ['cowboy way'],
#  'tt0106660': ['dangerous game'],
#  'tt0106673': ['dave'],
#  'tt0106677': ['dazed confused'],
#  'tt0106697': ['demolition'],
#  'tt0109729': ['endless summer 2'],
#  'tt0106834': ['even cowgirls get blues'],
#  'tt0106873': ['fatal instinct'],
#  'tt0106332': ['霸王别姬'],
#  'tt0109783': ['favor'],
#  'tt0106881': ['fearless'],
#  'tt0106880': ['fear black'],
#  'tt0111732': ['honors'],
#  'tt0106926': ['flesh bone'],
#  'tt0111712': ['widows peak'],
#  'tt0106941': ['love money'],
#  'tt0106918': ['firm'],
#  'tt0106965': ['free willy'],
#  'tt0109842': ['fresh'],
#  'tt0106977': ['fugitive'],
#  'tt0107004': ['geronimo american legend'],
#  'tt0109890': ['getaway'],
#  'tt0109891': ['getting even dad'],
#  'tt0109913': ['go fish'],
#  'tt0109920': ['good africa'],
#  'tt0107057': ['guilty'],
#  'tt0107076': ['hard target'],
#  'tt0107096': ['heaven earth'],
#  'tt0107144': ['hot shots part deux'],
#  'tt0113674': ['live nude girls'],
#  'tt0112966': ['englishman went hill came mountain'],
#  'tt0107151': ['house spirits'],
#  'tt0110064': ['house party 3'],
#  'tt0110074': ['hudsucker proxy'],
#  'tt0110097': ['anything'],
#  'tt0110123': ['army'],
#  'tt0107206': ['line fire'],
#  'tt0107207': ['father'],
#  'tt0110137': ['inkwell'],
#  'tt0108551': ['love got'],
#  'tt0110197': ['jimmy hollywood'],
#  'tt0107286': ['judgment night'],
#  'tt0107290': ['jurassic park'],
#  'tt0107302': ['kalifornia'],
#  'tt0110265': ['killing zoe'],
#  'tt0107322': ['king hill'],
#  'tt0110305': ['lassie'],
#  'tt0107362': ['last action hero'],
#  'tt0107413': ['life mikey'],
#  'tt0110353': ['lightning jack'],
#  'tt0107468': ['butterfly'],
#  'tt0107478': ['made america'],
#  'tt0107497': ['malice'],
#  'tt0107501': ['without'],
#  'tt0107507': ['manhattan murder mystery'],
#  'tt0107554': ['menace society'],
#  'tt0116253': ['executive decision'],
#  'tt0074102': ['愛のコリーダ'],
#  'tt0111689': ['happened'],
#  'tt0107616': ['much ado nothing'],
#  'tt0107611': ['mr jones'],
#  'tt0107613': ['mr wonderful'],
#  'tt0107614': ['mrs doubtfire'],
#  'tt0107653': ['naked'],
#  'tt0110657': ['next karate kid'],
#  'tt0110649': ['new age'],
#  'tt0110678': ['escape'],
#  'tt0110687': ['north'],
#  'tt0107756': ['orlando'],
#  'tt0107808': ['perfect world'],
#  'tt0107818': ['philadelphia'],
#  'tt0107822': ['piano'],
#  'tt0107840': ['poetic justice'],
#  'tt0107889': ['program'],
#  'tt0111003': ['puppet masters'],
#  'tt0110939': ['radioland murders'],
#  'tt0110955': ['ref'],
#  'tt0107943': ['remains day'],
#  'tt0110971': ['renaissance'],
#  'tt0107969': ['rising sun'],
#  'tt0111001': ['road wellville'],
#  'tt0107978': ['robocop 3'],
#  'tt0107977': ['robin hood tights'],
#  'tt0107983': ['romeo bleeding'],
#  'tt0105275': ['romper stomper'],
#  'tt0108000': ['ruby paradise'],
#  'tt0108002': ['rudy'],
#  'tt0108026': ['saint fort washington'],
#  'tt0105032': ['nuits fauves'],
#  'tt0108052': ['schindler list'],
#  'tt0111094': ['scout'],
#  'tt0108065': ['searching bobby fischer'],
#  'tt0111102': ['second best'],
#  'tt0108071': ['secret garden'],
#  'tt0111127': ['serial mom'],
#  'tt0111143': ['shadow'],
#  'tt0108101': ['shadowlands'],
#  'tt0108122': ['short cuts'],
#  'tt0111194': ['simple twist fate'],
#  'tt0111201': ['sirens'],
#  'tt0108149': ['six degrees separation'],
#  'tt0108160': ['sleepless seattle'],
#  'tt0108162': ['sliver'],
#  'tt0083658': ['blade runner'],
#  'tt0108186': ['law'],
#  'tt0108174': ['married axe murderer'],
#  'tt0108238': ['striking distance'],
#  'tt0089256': ['harem'],
#  'tt0108255': ['super mario bros'],
#  'tt0111323': ['surviving game'],
#  'tt0111400': ['terminal velocity'],
#  'tt0108328': ['thirty two short films glenn gould'],
#  'tt0111418': ['threesome'],
#  'tt0107688': ['nightmare christmas'],
#  'tt0108333': ['three musketeers'],
#  'tt0108358': ['tombstone'],
#  'tt0111488': ['trial jury'],
#  'tt0108399': ['true romance'],
#  'tt0108515': ['room'],
#  'tt0110763': ['pagemaster'],
#  'tt0107779': ['paris france'],
#  'tt0109226': ['beans egypt maine'],
#  'tt0110259': ['killer'],
#  'tt0114906': ['welcome dollhouse'],
#  'tt0107002': ['germinal'],
#  'tt0109403': ['chasers'],
#  'tt0104029': ['cronos'],
#  'tt0110623': ['naked new york'],
#  'tt0107315': ['kika'],
#  'tt0106408': ['bhaji beach'],
#  'tt0110363': ['little big league'],
#  'tt0107349': ['kådisbellan'],
#  'tt0111709': ['wide eyed legless'],
#  'tt0109828': ['foreign student'],
#  'tt0107225': ['speriamo cavo'],
#  'tt0111252': ['spanking monkey'],
#  'tt0110366': ['little rascals'],
#  'tt0106878': ['mode'],
#  'tt0109120': ['andre'],
#  'tt0108059': ['scorta'],
#  'tt0110892': ['princess caraboo'],
#  'tt0112651': ['celluloid closet'],
#  'tt0107642': ['métisse'],
#  'tt0109382': ['caro diario'],
#  'tt0106678': ['habla'],
#  'tt0112572': ['brady bunch movie'],
#  'tt0099785': ['home alone'],
#  'tt0099653': ['ghost'],
#  'tt0103639': ['aladdin'],
#  'tt0103064': ['terminator 2 judgment day'],
#  'tt0099348': ['dances wolves'],
#  'tt0114706': ['tough deadly'],
#  'tt0096895': ['batman'],
#  'tt0102926': ['silence lambs'],
#  'tt0029583': ['snow white seven dwarfs'],
#  'tt0101414': ['beauty beast'],
#  'tt0032910': ['pinocchio'],
#  'tt0100405': ['pretty woman'],
#  'tt0110719': ['окно париж'],
#  'tt0065214': ['wild bunch'],
#  'tt0110395': ['love 45'],
#  'tt0111752': ['wooden bride'],
#  'tt0109934': ['great day harlem'],
#  'tt0112606': ['bye bye love'],
#  'tt0117247': ['fine day'],
#  'tt0112625': ['candyman farewell flesh'],
#  'tt0106537': ['century'],
#  'tt0116282': ['fargo'],
#  'tt0116552': ['homeward bound lost san francisco'],
#  'tt0082509': ['heavy metal'],
#  'tt0116514': ['hellraiser bloodline'],
#  'tt0117283': ['pallbearer'],
#  'tt0116684': ['jane eyre'],
#  'tt0110374': ['loaded'],
#  'tt0070506': ['pane cioccolata'],
#  'tt0065421': ['aristocats'],
#  'tt0113083': ['flor secreto'],
#  'tt0118001': ['two much'],
#  'tt0116165': [''],
#  'tt0102855': ['schrei stein'],
#  'tt0107471': ['saison préférée'],
#  'tt0113839': ['modern affair'],
#  'tt0112712': ['condition red'],
#  'tt0090665': ['asfour stah'],
#  'tt0117891': ['thin line love hate'],
#  'tt0113613': ['last supper'],
#  'tt0117381': ['primal fear'],
#  'tt0114305': ['rude'],
#  'tt0115837': ['carried away'],
#  'tt0115509': ['dogs go heaven 2'],
#  'tt0114671': ['land freedom'],
#  'tt0112844': ['denise calls'],
#  'tt0114658': ['theodore rex'],
#  'tt0116275': ['family thing'],
#  'tt0113122': ['frisk'],
#  'tt0117608': ['sgt bilko'],
#  'tt0113448': ['jack sarah'],
#  'tt0116414': ['girl 6'],
#  'tt0116095': ['diabolique'],
#  'tt0111543': ['indien'],
#  'tt0117517': ['roula dunkle geheimnisse'],
#  'tt0117312': ['peanuts bank zahlt'],
#  'tt0116485': ['happy weekend'],
#  'tt0113947': ['nelly monsieur arnaud'],
#  'tt0115956': ['courage fire'],
#  'tt0117060': ['mission impossible'],
#  'tt0109028': ['á köldum klaka'],
#  'tt0117071': ['moll flanders'],
#  'tt0117788': ['superweib'],
#  'tt0112257': ['삼공일 삼공이'],
#  'tt0116136': ['dragonheart'],
#  'tt0118026': ['weint'],
#  'tt0117117': ['mother courage'],
#  'tt0116168': ['eddie'],
#  'tt0111787': ['yankee zulu'],
#  'tt0112509': ['billy holiday'],
#  'tt0054189': ['plein soleil'],
#  'tt0115591': ['august'],
#  'tt0116683': ['james giant peach'],
#  'tt0116287': ['fear'],
#  'tt0116768': ['kids hall brain candy'],
#  'tt0116269': ['faithful'],
#  'tt0114787': ['podzemlje'],
#  'tt0113720': ['lust fägring stor'],
#  'tt0112536': ['bloodsport'],
#  'tt0048473': ['পথ র প চ ল'],
#  'tt0052572': ['অপ র স স র'],
#  'tt0117128': ['mystery science theater 3000 movie'],
#  'tt0114616': ['tarantella'],
#  'tt0117705': ['space jam'],
#  'tt0062711': ['barbarella'],
#  'tt0110061': ['hostile intentions'],
#  'tt0140614': ['bite'],
#  'tt0108181': ['folks call sling blade'],
#  'tt0114307': ['run country'],
#  'tt0058898': ['alphaville étrange aventure lemmy caution'],
#  'tt0082206': ['coup torchon'],
#  'tt0111430': ['tigrero film never made'],
#  'tt0107727': ['oeil vichy'],
#  'tt0081759': ['windows'],
#  'tt0113443': ['party'],
#  'tt0109491': ['country life'],
#  'tt0114048': ['operation dumbo drop'],
#  'tt0111613': ['versprechen'],
#  'tt0117104': ['mrs winterbourne'],
#  'tt0117688': ['solo'],
#  'tt0109751': ['etz hadomim tafus'],
#  'tt0117774': ['substitute'],
#  'tt0114736': ['true crime'],
#  'tt0112604': ['butterfly kiss'],
#  'tt0116289': ['feeling minnesota'],
#  'tt0109593': ['delta venus'],
#  'tt0103095': ['cross rubicon'],
#  'tt0112368': ['angus'],
#  'tt0104046': ['daens'],
#  'tt0062952': ['faces'],
#  'tt0115742': ['boys'],
#  'tt0117420': ['quest'],
#  'tt0115951': ['cosi'],
#  'tt0117784': ['sunset park'],
#  'tt0117107': ['mulholland falls'],
#  'tt0117979': ['truth cats dogs'],
#  'tt0095776': ['oliver company'],
#  'tt0115851': ['celtic pride'],
#  'tt0116322': ['flipper'],
#  'tt0109374': ['captives'],
#  'tt0110712': ['love shadows'],
#  'tt0112817': ['dead'],
#  'tt0113362': ['hussard toit'],
#  'tt0073778': ['switchblade sisters'],
#  'tt0112546': ['boca boca'],
#  'tt0108500': ['visiteurs'],
#  'tt0117108': ['multiplicity'],
#  'tt0113270': ['haunted world edward wood jr'],
#  'tt0333373': ['due amici'],
#  'tt0115963': ['craft'],
#  'tt0116448': ['great white hype'],
#  'tt0116827': ['last dance'],
#  'tt0114894': ['stories mother never told us'],
#  'tt0112701': ['cold comfort farm'],
#  'tt0113429': ['institute benjamenta dream people call human life'],
#  'tt0116508': ['heaven prisoners'],
#  'tt0117260': ['original gangstas'],
#  'tt0117500': ['rock'],
#  'tt0116405': ['getting away murder'],
#  'tt0109592': ['dellamorte dellamore'],
#  'tt0117998': ['twister'],
#  'tt0115624': ['barb wire'],
#  'tt0113145': ['garçu'],
#  'tt0116559': ['honigmond'],
#  'tt0113568': ['ghost shell'],
#  'tt0117894': ['thinner'],
#  'tt0117723': ['spy hard'],
#  'tt0112586': ['brothers trouble'],
#  'tt0112691': ['close shave'],
#  'tt0040366': ['force evil'],
#  'tt0117768': ['stupids'],
#  'tt0115571': ['arrival'],
#  'tt0031612': [''],
#  'tt0057012': ['dr strangelove learned stop worrying love bomb'],
#  'tt0103926': ['careful'],
#  'tt0105737': ['vermont lovers'],
#  'tt0113849': ['month lake'],
#  'tt0113188': ['gold diggers secret bear mountain'],
#  'tt0042644': [''],
#  'tt0109381': ['carmen miranda bananas business'],
#  'tt0109688': ['東邪西毒'],
#  'tt0104606': ['khomreh'],
#  'tt0110480': ['maya lin strong clear vision'],
#  'tt0108211': ['stalingrad'],
#  'tt0117331': ['phantom'],
#  'tt0117765': ['striptease'],
#  'tt0116833': ['last high kings'],
#  'tt0113280': ['heavy'],
#  'tt0116669': ['jack'],
#  'tt0116594': ['shot andy warhol'],
#  'tt0113211': ['grass harp'],
#  'tt0114494': ['tuđa amerika'],
#  'tt0094265': ['vie belle'],
#  'tt0105201': ['quartier mozart'],
#  'tt0070820': ['touki bouki'],
#  'tt0084898': ['wend kuuni'],
#  'tt0063715': ['histoires extraordinaires'],
#  'tt0109191': ['babyfever'],
#  'tt0114122': ['pharaoh army'],
#  'tt0117951': ['trainspotting'],
#  'tt0118523': [''],
#  'tt0116629': ['independence day'],
#  'tt0117737': ['stealing beauty'],
#  'tt0116277': ['fan'],
#  'tt0116583': ['hunchback dame'],
#  'tt0115798': ['cable guy'],
#  'tt0116778': ['kingpin'],
#  'tt0116213': ['eraser'],
#  'tt0113147': ['gate heavenly peace'],
#  'tt0117218': ['nutty professor'],
#  'tt0100990': ['peor todas'],
#  'tt0111546': ['inoubliable'],
#  'tt0093199': ['hol hol'],
#  'tt0106810': ['compagnie antonin artaud'],
#  'tt0111180': ['sibak'],
#  'tt0111237': ['somebody love'],
#  'tt0072362': ['natural thing'],
#  'tt0103207': ['vieille marchait mer'],
#  'tt0116040': ['daylight'],
#  'tt0116365': ['frighteners'],
#  'tt0116905': ['lone star'],
#  'tt0116493': ['harriet spy'],
#  'tt0117333': ['phenomenon'],
#  'tt0118113': ['walking talking'],
#  'tt0117628': [''],
#  'tt0117913': ['time kill'],
#  'tt0115530': ['american buffalo'],
#  'tt0114266': ['rendez paris'],
#  'tt0115493': ['alaska'],
#  'tt0116320': ['fled'],
#  'tt0116756': ['kazaam'],
#  'tt0109356': ['bűvös vadász'],
#  'tt0116823': ['larger life'],
#  'tt0112568': ['boy called hate'],
#  'tt0114170': ['power 98'],
#  'tt0117999': ['two deaths'],
#  'tt0118073': ['brady sequel'],
#  'tt0108220': ['stefano quantestorie'],
#  'tt0049521': ['mort jardin'],
#  'tt0104403': ['hedd wyn'],
#  'tt0061495': ['collectionneuse'],
#  'tt0110246': ['kaspar hauser'],
#  'tt0116164': ['echte kerle'],
#  'tt0112865': ['diebinnen'],
#  'tt0112716': ['convento'],
#  'tt0115472': ['adventures pinocchio'],
#  'tt0116707': ['joe apartment'],
#  'tt0116313': ['first wives club'],
#  'tt0114550': ['stonewall'],
#  'tt0117438': ['ransom'],
#  'tt0116531': ['high school high'],
#  'tt0117332': ['phat beach'],
#  'tt0116353': ['foxfire'],
#  'tt0115857': ['chain reaction'],
#  'tt0117008': ['matilda'],
#  'tt0116191': ['emma'],
#  'tt0115986': ['crow city angels'],
#  'tt0116571': ['house arrest'],
#  'tt0053459': ['yeux sans visage'],
#  'tt0117826': ['bordello blood'],
#  'tt0113695': ['lotto land'],
#  'tt0108227': ['story xinghua'],
#  'tt0111424': ['天國逆子'],
#  'tt0113080': ['flirt'],
#  'tt0115680': ['big squeeze'],
#  'tt0117718': ['spitfire grill'],
#  'tt0116225': ['escape'],
#  'tt0112767': ['xích lô'],
#  'tt0115632': ['basquiat'],
#  'tt0117918': ['tin cup'],
#  'tt0104109': ['dingo'],
#  'tt0051980': ['楢山節考'],
#  'tt0100840': ['week deux'],
#  'tt0107575': ['bolle blu'],
#  'tt0042054': ['wuya yu maque'],
#  'tt0068646': ['godfather'],
#  'tt0109255': ['bewegte mann'],
#  'tt0104558': ['警察故事 iii 超級警察'],
#  'tt0116985': ['manny'],
#  'tt0046468': ['tsuma'],
#  'tt0114474': ['small faces'],
#  'tt0115736': ['bound'],
#  'tt0115836': ['carpool'],
#  'tt0101692': ['death brunswick'],
#  'tt0116745': ['kansas city'],
#  'tt0119214': ['gone fishin'],
#  'tt0116934': ['lover knot'],
#  'tt0109066': ['愛情萬歲'],
#  'tt0075169': ['schatten engel'],
#  'tt0113542': ['killer journal murder'],
#  'tt0110693': ['nothing lose'],
#  'tt0106544': ['超级计划'],
#  'tt0116418': ['girls town'],
#  'tt0112607': ['bye bye'],
#  'tt0120004': ['relic'],
#  'tt0116654': ['island dr moreau'],
#  'tt0116311': ['first kid'],
#  'tt0117965': ['trigger effect'],
#  'tt0114592': ['sweet nothing'],
#  'tt0115725': ['bogus'],
#  'tt0115783': ['bulletproof'],
#  'tt0120271': ['talk angels'],
#  'tt0113596': ['land time iii time great giving'],
#  'tt0109001': ['06'],
#  'tt0094822': ['baton rouge'],
#  'tt0113253': ['halloween curse michael myers'],
#  'tt0117991': ['twelfth night'],
#  'tt0117093': ['mother night'],
#  'tt0024252': ['liebelei'],
#  'tt1684935': ['wenecja'],
#  'tt0111019': ['roseaux sauvages'],
#  'tt0035896': ['bell tolls'],
#  'tt0032904': ['philadelphia story'],
#  'tt0045152': ['singin rain'],
#  'tt0043278': ['american paris'],
#  'tt0050419': ['funny'],
#  'tt0054698': ['breakfast tiffany'],
#  'tt0052357': ['vertigo'],
#  'tt0047396': ['rear window'],
#  'tt0025316': ['happened night'],
#  'tt0036855': ['gaslight'],
#  'tt0025164': ['gay divorcee'],
#  'tt0053125': ['north northwest'],
#  'tt0053604': ['apartment'],
#  'tt0053291': ['like hot'],
#  'tt0056923': ['charade'],
#  'tt0034583': ['casablanca'],
#  'tt0033870': ['maltese falcon'],
#  'tt0058385': ['fair lady'],
#  'tt0047437': ['sabrina'],
#  'tt0046250': ['roman holiday'],
#  'tt0031580': ['little princess'],
#  'tt0037059': ['meet st louis'],
#  'tt0032138': ['wizard oz'],
#  'tt0031381': ['gone wind'],
#  'tt0084370': ['favorite year'],
#  'tt0043014': ['sunset boulevard'],
#  'tt0033467': ['citizen kane'],
#  'tt0062622': ['2001 space odyssey'],
#  'tt0039428': ['golden earrings'],
#  'tt0042192': ['eve'],
#  'tt0032143': ['women'],
#  'tt0032976': ['rebecca'],
#  'tt0032484': ['foreign correspondent'],
#  'tt0038787': ['notorious'],
#  'tt0038109': ['spellbound'],
#  'tt0050105': ['affair remember'],
#  'tt0048728': ['catch thief'],
#  'tt0042451': ['father bride'],
#  'tt0045537': ['band wagon'],
#  'tt0031725': ['ninotchka'],
#  'tt0050658': ['love afternoon'],
#  'tt0051658': ['gigi'],
#  'tt0052126': ['reluctant debutante'],
#  'tt0029843': ['adventures robin hood'],
#  'tt0032762': ['mark zorro'],
#  'tt0037008': ['laura'],
#  'tt0039420': ['ghost mrs muir'],
#  'tt0029162': ['lost horizon'],
#  'tt0027125': ['top'],
#  'tt0035446': [''],
#  'tt0028010': ['godfrey'],
#  'tt0049261': ['giant'],
#  'tt0048028': ['east'],
#  'tt0025878': ['thin'],
#  'tt0032599': ['girl friday'],
#  'tt0048960': ['around world eighty days'],
#  'tt0038650': ['wonderful life'],
#  'tt0031679': ['mr smith goes washington'],
#  'tt0029947': ['bringing baby'],
#  'tt0034012': ['penny serenade'],
#  'tt0017350': ['scarlet letter'],
#  'tt0036094': ['lady burlesque'],
#  'tt0025586': ['human bondage'],
#  'tt0038300': ['angel shoulder'],
#  'tt0027893': ['little lord fauntleroy'],
#  'tt0032022': ['made criminal'],
#  'tt0041509': ['inspector general'],
#  'tt0039152': ['angel badman'],
#  'tt0026029': ['39 steps'],
#  'tt0038235': ['walk sun'],
#  'tt0036241': ['outlaw'],
#  'tt0063350': ['night living dead'],
#  'tt0043265': ['african queen'],
#  'tt0046414': ['beat devil'],
#  'tt0051459': ['hot tin roof'],
#  'tt0047162': ['last time saw paris'],
#  'tt0033891': ['meet john doe'],
#  'tt0029855': ['algiers'],
#  'tt0029588': ['something sing'],
#  'tt0022879': ['farewell arms'],
#  'tt0027980': ['moonlight murder'],
#  'tt0114007': ['nothing personal'],
#  'tt0093229': ['huang jia shi jie'],
#  'tt0118927': ['dangerous ground'],
#  'tt0048491': ['picnic'],
#  'tt0113730': ['madagascar skin'],
#  'tt0117357': ['pompatus love'],
#  'tt0117669': ['small wonders'],
#  'tt0116329': ['fly away home'],
#  'tt0118742': ['bliss'],
#  'tt0116442': ['grace heart'],
#  'tt0114354': ['schlafes bruder'],
#  'tt0117011': ['maximum risk'],
#  'tt0117039': ['michael collins'],
#  'tt0117473': ['rich wife'],
#  'tt0116635': ['infinity'],
#  'tt0115678': ['big night'],
#  'tt0116830': ['last standing'],
#  'tt0115847': ['caught'],
#  'tt0117603': ['set'],
#  'tt0115438': ['2 days valley'],
#  'tt0115994': ['curdled'],
#  'tt0083587': ['associé'],
#  'tt0116167': ['next move'],
#  'tt0116259': ['extreme measures'],
#  'tt0116421': ['glimmer'],
#  'tt0116000': ['d3 mighty ducks'],
#  'tt0115862': ['chamber'],
#  'tt0072653': ['apple dumpling gang'],
#  'tt0047977': ['davy crockett king wild frontier'],
#  'tt0072951': ['escape witch mountain'],
#  'tt0064603': ['love bug'],
#  'tt0071607': ['herbie rides'],
#  'tt0050798': ['old yeller'],
#  'tt0055277': ['parent trap'],
#  'tt0054195': ['pollyanna'],
#  'tt0107131': ['homeward bound incredible journey'],
#  'tt0053271': ['shaggy'],
#  'tt0054357': ['swiss family robinson'],
#  'tt0059793': ['darn'],
#  'tt0046672': ['20 000 leagues'],
#  'tt0106611': ['cool runnings'],
#  'tt0109127': ['angels outfield'],
#  'tt0042332': ['cinderella'],
#  'tt0063819': ['winnie pooh blustery day'],
#  'tt0038166': ['three caballeros'],
#  'tt0057546': ['sword stone'],
#  'tt0041890': ['dear heart'],
#  'tt0102798': ['robin hood prince thieves'],
#  'tt0058331': ['mary poppins'],
#  ...}

# %%
STEAM_DATA = '/Users/susan/Development/cs4300/cs4300sp2020-cw887-qh75-rz92-yc687-yl698/data/steam_data/steam_data.csv'
AVAILABLE_GAMES = '/Users/susan/Development/cs4300/cs4300sp2020-cw887-qh75-rz92-yc687-yl698/data/steamData/80k_data/available_games.json'
available_game_ids = json.load(open(AVAILABLE_GAMES, 'r'))

with open(STEAM_DATA, 'r') as f:
    steam_data_df = pd.read_csv(f)
    fn = lambda x: x.url.split('/')[4]
    steam_data_df['app_id'] = steam_data_df.apply(fn, axis=1)

# %%
def get_filtered_game_name(row):
    name = row['name']
    if type(name) is not str or pd.isnull(name) or name == '0':
        return ""
    name = re.sub('\W+',' ', name.lower())
    text_tokens = nltk.tokenize.word_tokenize(name)
#     print(f'text_tokens = {text_tokens}')
    tokens_without_sw = [word for word in text_tokens if not word in my_stop_words]
    filtered_name  = (" ").join(tokens_without_sw)
    return filtered_name

steam_data_df['filtered_name'] = steam_data_df.apply(lambda x: get_filtered_game_name(x), axis=1)

# %%
steam_data_df_filtered = steam_data_df[{'app_id', 'name', 'filtered_name'}]

# %%
steam_data_df_filtered.head()
# Out:
#     app_id                              name                    filtered_name
# 0   945360                          Among Us                            among
# 1      730  Counter-Strike: Global Offensive  counter strike global offensive
# 2  1097150      Fall Guys: Ultimate Knockout           guys ultimate knockout
# 3  1158310                Crusader Kings III                   crusader kings
# 4  1085660                         Destiny 2                        destiny 2

# %%
available_game_ids_set = set(map(str, available_game_ids))
steam_data_df_filtered = steam_data_df_filtered[steam_data_df_filtered['app_id'].isin(available_game_ids_set)]
# steam_data_df_filtered = steam_data_df_filtered[steam_data_df['app_id'].isin(available_game_ids_set)]

# %%
len(steam_data_df_filtered)
# Out:
# 3163

# %%
steam_data_df_filtered.head()
# Out:
#     app_id                              name                    filtered_name
# 0   945360                          Among Us                            among
# 1      730  Counter-Strike: Global Offensive  counter strike global offensive
# 2  1097150      Fall Guys: Ultimate Knockout           guys ultimate knockout
# 3  1158310                Crusader Kings III                   crusader kings
# 4  1085660                         Destiny 2                        destiny 2

# %%
steam_data_df_filtered.to_csv(os.path.join('steamData', 'available_games', 'available_game_filtered_title.csv'))

# %%
os.path.abspath(os.path.join('steamData', 'available_games', 'available_game_filtered_title.csv'))
# Out:
# '/Users/susan/Development/cs4300sp2021-cw887-qh75-rz92-yc687-yl698/data/steamData/available_games/available_game_filtered_title.csv'

# %% [markdown]
# ## Draft

# %%
sorted_pair = np.argsort(title_sim_mat_df.iloc[0])[::-1]

# %%
print(f'value is: {title_sim_mat_df.index[0]}') 

for match_idx in sorted_pair[:10]:
    score = title_sim_mat_df.iloc[0][match_idx]
    print(f'{score}: {title_sim_mat_df.columns[match_idx]}')
# Out:
# value is: !women art revolution
# 0.7567567567567568: worms revolution
# 0.723404255319149: homefront®: the revolution
# 0.5882352941176471: war selection
# 0.5714285714285714: revolution ace
# 0.55: hitman: absolution™
# 0.5405405405405406: the repopulation
# 0.5333333333333333: survival zombies the inverted evolution
# 0.5333333333333333: jurassic world evolution
# 0.5217391304347826: resident evil revelations
# 0.52: rome: total war™ - collection

# %%
list(sorted(list(title_sim_mat_df.iloc[0])))[::-1].index(0)
# Out:
# 2727

# %%
from sqlalchemy import create_engine

heroku_db = 'postgres://lfykwexqkamxmh:fddd2b2526b3de064af5a3c471fe466da70ffa1b773bb43669fcd067590037b1@ec2-3-211-37-117.compute-1.amazonaws.com:5432/d54e2cpo1gk8jf'
engine = create_engine(heroku_db)

# %%
ten_keys = list(title_top_100_similar_map.keys())[:10]

# %%
ten_keys[0]
# Out:
# '55245'

# %%
movie_data_df[movie_data_df['id'] == '55245']['original_title']
# Out:
# 18757    !Women Art Revolution
# Name: original_title, dtype: object

# %%
top5_match = title_top_100_similar_map.get('55245')[:5]

# %%
top5_match
# Out:
# [[200170, 0.7567567567567568],
#  [223100, 0.723404255319149],
#  [1022450, 0.5882352941176471],
#  [274560, 0.5714285714285714],
#  [203140, 0.55]]

# %%
steam_data_df[steam_data_df['app_id'] == '200170']
# Out:
#                                                     url              name  \
# 2596  https://store.steampowered.com/app/200170/Worm...  Worms Revolution
#
#                                              categories  \
# 2596  Single-playerSteam AchievementsSteam Trading C...
#
#                                                 img_url  \
# 2596  https://steamcdn-a.akamaihd.net/steam/apps/200...
#
#                                            user_reviews  \
# 2596  Very Positive(54)- 83% of the 54 user reviews ...
#
#                                             all_reviews          date  \
# 2596  Very Positive(3,687)- 84% of the 3,687 user re...  Oct 10, 2012
#
#                developer           publisher  \
# 2596  Team17 Digital Ltd  Team17 Digital Ltd
#
#                                       price  \
# 2596  Buy Worms Revolution$14.99Add to Cart
#
#                                                   pegi  \
# 2596  Cartoon Violence, Comic Mischief, Mild Language.
#
#                                                pegi_url  app_id
# 2596  https://steamstore-a.akamaihd.net/public/share...  200170

# %%
movie_title_filtered_df_path = '/Users/susan/Development/cs4300sp2021-cw887-qh75-rz92-yc687-yl698/data/movie_data/movie_title_filtered_df_3.csv'


with open(movie_title_filtered_df_path, 'r') as f:
    movie_title_filtered_df = pd.read_csv(f)

# %%
steam_title_filtered_df_path = '/Users/susan/Development/cs4300sp2021-cw887-qh75-rz92-yc687-yl698/data/steamData/available_games/available_game_filtered_title.csv'
with open(steam_title_filtered_df_path, 'r') as f:
    steam_title_filtered_df = pd.read_csv(f)

# %%
movie_title_filtered_df[movie_title_filtered_df['original_title'] == 'The Lego Movie']
# Out:
#        Unnamed: 0      id    imdb_id  original_title filtered_name
# 17517       22718  137106  tt1490017  The Lego Movie          lego

# %%
steam_title_filtered_df.head()
# Out:
#    Unnamed: 0   app_id                              name  \
# 0           0   945360                          Among Us
# 1           1      730  Counter-Strike: Global Offensive
# 2           2  1097150      Fall Guys: Ultimate Knockout
# 3           3  1158310                Crusader Kings III
# 4           4  1085660                         Destiny 2
#
#                      filtered_name
# 0                            among
# 1  counter strike global offensive
# 2           guys ultimate knockout
# 3                   crusader kings
# 4                        destiny 2

# %%
games_name_list = list(sorted(list(set(steam_data_df['filtered_name']))))

# %%
# from difflib import SequenceMatcher
# games_name_sim_score_list = []
# for name in games_name_list:
#     games_name_sim_score_list.append(SequenceMatcher(None, 'lego', name).ratio())

# %%
def print_top_k(names, scores, k=10):
    top_k_scores = np.argsort(scores)[::-1][:k]
    for idx in top_k_scores:
        print(names[idx], scores[idx])

# %%
print_top_k(games_name_list, games_name_sim_score_list)
# Out:
# ego 0.8571428571428571
# legion 0.8
# legions 0.7272727272727273
# legie 0.6666666666666666
# fuego 0.6666666666666666
# egony 0.6666666666666666
# liege 0.6666666666666666
# logos 0.6666666666666666
# lemon 0.6666666666666666
# blueglow 0.6666666666666666

# %%
steam_title_filtered_df[steam_title_filtered_df['app_id'] == '812140']
# Out:
#      Unnamed: 0  app_id                       name             filtered_name
# 201         201  812140  Assassin's Creed® Odyssey  assassin s creed odyssey

# %%
SequenceMatcher(None, 'lego', 'lego worlds').ratio()
# Out:
# 0.5333333333333333

# %%
my_stop_words.index('lego')
# Out:
# 560

# %% [markdown]
# ## Title Keywords Match

# %%
from collections import Counter

def get_similarity_score(val1, val2):
    val_lst1 = val1.split(' ')
    val_lst2 = val2.split(' ')
    
    val_count1 = dict(Counter(val_lst1))
    val_count2 = dict(Counter(val_lst2))
    
    common_keys = set(val_count1.keys()).intersection(set(val_count2.keys()))
    denom = 0
    for k in common_keys:
        denom += min(val_count1[k], val_count2[k]) * 2
    return denom / (len(val_lst1) + len(val_lst2))


print(get_similarity_score('lego', 'lego world'))
# Out:
# 0.6666666666666666

# %%
games_name_sim_score_list = []
for name in games_name_list:
    games_name_sim_score_list.append(get_similarity_score('assassin s creed odyssey', name))

# %%
print_top_k(games_name_list, games_name_sim_score_list)
# Out:
# assassin s creed odyssey 1.0
# assassin s creed odyssey legacy blade 0.8
# assassin s creed odyssey season pass 0.8
# assassin s creed odyssey fate atlantis 0.8
# assassin s creed unity 0.75
# assassin s creed rogue 0.75
# assassin s creed origins 0.75
# assassin s creed revelations 0.75
# assassin s creed syndicate 0.75
# assassin s creed brotherhood 0.75

# %%
steam_title_filtered_df[steam_title_filtered_df['app_id'] == '12150']
# Out:
#       Unnamed: 0 app_id                                name  \
# 4284        4284  12150  Max Payne 2: The Fall of Max Payne
#
#               filtered_name
# 4284  max payne 2 max payne

# %%
games_name_sim_score_list = []
for name in games_name_list:
    games_name_sim_score_list.append(get_similarity_score('max payne 2 max payne', name))
print_top_k(games_name_list, games_name_sim_score_list)
# Out:
# max payne 2 max payne 1.0
# max payne 3 classic max payne character 0.6666666666666666
# max payne 0.5714285714285714
# max payne ru 0.5
# max payne 3 0.5
# max payne 3 burst 0.4444444444444444
# max payne 3 deathmatch pack 0.4
# max payne 3 cemetery map 0.4
# max payne 3 local pack 0.4
# max payne 3 loadout pack 0.4

# %%
games_name_vec.toarray().shape
# Out:
# (59848, 33289)

# %%
name_count_vec = vectorizer.fit_transform(games_name_list, )

# %%
movie_title_filtered_df_path = '/Users/susan/Development/cs4300sp2021-cw887-qh75-rz92-yc687-yl698/data/movie_data/movie_title_filtered_df_3.csv'


with open(movie_title_filtered_df_path, 'r') as f:
    movie_title_filtered_df = pd.read_csv(f)
    
steam_title_filtered_df_path = '/Users/susan/Development/cs4300sp2021-cw887-qh75-rz92-yc687-yl698/data/steamData/available_games/available_game_filtered_title.csv'
with open(steam_title_filtered_df_path, 'r') as f:
    steam_title_filtered_df = pd.read_csv(f)
    
# title_sim_mat = np.zeros((len(movie_titles_list), len(steam_titles_list)))

# start = time.time()
# for i in range(len(movie_titles_list)):
#     for j in range(len(steam_titles_list)):
#         title_sim_mat[i,j] = SequenceMatcher(None, movie_titles_list[i], steam_titles_list[j]).ratio()
#     cur_time = time.time()
#     if (i % 1000 == 0):
#         print(f'i = {i}')
#         print(f'passed: {cur_time - start}')

# %%
len(steam_title_filtered_df)
# Out:
# 3163

# %%
movie_title_list = list(sorted(filter(lambda x: type(x) is str and x != '', list(set(movie_title_filtered_df['filtered_name'])))))
game_title_list = list(sorted(filter(lambda x: type(x) is str and x != '', list(set(steam_title_filtered_df['filtered_name'])))))

# %%
def get_top_movie_info(score_lst, k=10):
    res = []
    sorted_idx = np.argsort(score_lst)[::-1][:k]
#     print(f"mov_name: {mov_name}")
    for i in sorted_idx:
        res.append([game_title_list[i], score_lst[i]])
#     print(res)
    return res
#         print(game_title_list[i], score_lst[i])
#     print('====')

# %%
import time
sim_json = dict()

count = 0
start = time.time()
for mov_name in movie_title_list:
    if count % 1000 == 0:
        print(f'{count}: {time.time() - start}')
    score_lst = []
    for game_name in game_title_list:
        score_lst.append(get_similarity_score(mov_name, game_name))
    sim_json[mov_name] = get_top_movie_info(score_lst, 50)
    count += 1
# Out:
# 0: 0.00010609626770019531
# 1000: 19.845879793167114
# 2000: 38.897156953811646
# 3000: 58.17651414871216
# 4000: 78.63789010047913
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-541-d2983cd1b00a> in <module>
#       9     score_lst = []
#      10     for game_name in game_title_list:
# ---> 11         score_lst.append(get_similarity_score(mov_name, game_name))
#      12     sim_json[mov_name] = get_top_movie_info(score_lst, 50)
#      13     count += 1
#
# <ipython-input-462-48a70fb4dee3> in get_similarity_score(val1, val2)
#       5     val_lst2 = val2.split(' ')
#       6
# ----> 7     val_count1 = dict(Counter(val_lst1))
#       8     val_count2 = dict(Counter(val_lst2))
#       9
#
# ~/Development/cs4300/cs4300sp2020-cw887-qh75-rz92-yc687-yl698/tutorial_venv/lib/python3.7/collections/__init__.py in __init__(*args, **kwds)
#     566             raise TypeError('expected at most 1 arguments, got %d' % len(args))
#     567         super(Counter, self).__init__()
# --> 568         self.update(*args, **kwds)
#     569
#     570     def __missing__(self, key):
#
# ~/Development/cs4300/cs4300sp2020-cw887-qh75-rz92-yc687-yl698/tutorial_venv/lib/python3.7/collections/__init__.py in update(*args, **kwds)
#     645         iterable = args[0] if args else None
#     646         if iterable is not None:
# --> 647             if isinstance(iterable, _collections_abc.Mapping):
#     648                 if self:
#     649                     self_get = self.get
#
# KeyboardInterrupt:

# %%
# Out:
# {'0 earthquake': [['0', 0.3333333333333333],
#   ['1 0', 0.25],
#   ['resident 0', 0.25],
#   ['6 0', 0.25],
#   ['drop 0', 0.25],
#   ['5 0', 0.25],
#   ['event 0', 0.25],
#   ['64 0', 0.25],
#   ['yakuza 0', 0.25],
#   ['bizarre earthquake', 0.25],
#   ['vectromirror 0', 0.25],
#   ['chapter 0 dlc', 0.2],
#   ['tron 2 0', 0.2],
#   ['falcon 4 0', 0.2],
#   ['infinipicross 2 0', 0.2],
#   ['event 0 soundtrack', 0.2],
#   ['steins gate 0', 0.2],
#   ['shell 2 0', 0.2],
#   ['cafe 0 sleeping', 0.2],
#   ['data mining 0', 0.2],
#   ['1 0 soundtrack', 0.2],
#   ['laika 2 0', 0.2],
#   ['cowpocalypse episode 0', 0.2],
#   ['platform 2 0', 0.2],
#   ['kovaak 2 0', 0.2],
#   ['alpha version 0', 0.2],
#   ['nekopara vol 0', 0.2],
#   ['countershots 1 0', 0.2],
#   ['respite 2 0', 0.2],
#   ['khet 2 0', 0.2],
#   ['earthquake simulator vr', 0.2],
#   ['forgotten v1 0', 0.2],
#   ['bee aware 2 0', 0.16666666666666666],
#   ['dungeon swords 0 001', 0.16666666666666666],
#   ['cafe 0 drowned mermaid', 0.16666666666666666],
#   ['cafe 0 sleeping theme', 0.16666666666666666],
#   ['apocalypse 2 0 edition', 0.16666666666666666],
#   ['infinite works episode 0', 0.16666666666666666],
#   ['rc racing 2 0', 0.16666666666666666],
#   ['forgotten v1 0 premium', 0.16666666666666666],
#   ['welcome chichester episode 0', 0.16666666666666666],
#   ['fantasy type 0 hd', 0.16666666666666666],
#   ['renegades orion 2 0', 0.16666666666666666],
#   ['rc simulation 2 0', 0.16666666666666666],
#   ['dirt rally 2 0', 0.16666666666666666],
#   ['sol 0 mars colonization', 0.16666666666666666],
#   ['fasaria version 2 0', 0.16666666666666666],
#   ['gi racing 2 0', 0.16666666666666666],
#   ['0 n 0 w', 0.16666666666666666],
#   ['daisenryaku 4 0 大戦略パーフェクト4 0', 0.14285714285714285]],
#  '000': [['23 000', 0.3333333333333333],
#   ['000 000', 0.3333333333333333],
#   ['130 000', 0.3333333333333333],
#   ['20 000 miles', 0.25],
#   ['warhammer 40 000', 0.25],
#   ['orbs 300 000', 0.25],
#   ['field 3 000 golds', 0.2],
#   ['gladiabots 28 000 credits', 0.2],
#   ['warhammer 40 000 team', 0.2],
#   ['warhammer 40 000 retribution', 0.2],
#   ['warhammer 40 000 regicide', 0.2],
#   ['proud souls 200 000', 0.2],
#   ['warhammer 40 000 mechanicus', 0.2],
#   ['warhammer 40 000 armageddon', 0.2],
#   ['gladiabots 12 000 credits', 0.2],
#   ['gladiabots 2 000 credits', 0.2],
#   ['warhammer 40 000 crusade', 0.2],
#   ['warhammer 40 000 darktide', 0.2],
#   ['gladiabots 64 000 credits', 0.2],
#   ['warhammer 40 000 edition', 0.2],
#   ['150 000 b c', 0.2],
#   ['20 000 leagues nemo', 0.2],
#   ['20 000 miles soundtrack', 0.2],
#   ['warhammer 40 000 kanak', 0.2],
#   ['warhammer 40 000 marine', 0.2],
#   ['warhammer 40 000 soulstorm', 0.2],
#   ['warhammer 40 000 sigurd ironside', 0.16666666666666666],
#   ['lovehammer 400 000 buttlerian crusade', 0.16666666666666666],
#   ['warhammer 40 000 wrath damned', 0.16666666666666666],
#   ['warhammer 40 000 winter assault', 0.16666666666666666],
#   ['warhammer 40 000 ultramarines pack', 0.16666666666666666],
#   ['warhammer 40 000 inquisitor martyr', 0.16666666666666666],
#   ['warhammer 40 000 sentry pack', 0.16666666666666666],
#   ['warhammer 40 000 sanctus reach', 0.16666666666666666],
#   ['warhammer 40 000 saga awakening', 0.16666666666666666],
#   ['warhammer 40 000 retribution pack', 0.16666666666666666],
#   ['warhammer 40 000 regicide soundtrack', 0.16666666666666666],
#   ['field 3 100 000 golds', 0.16666666666666666],
#   ['warhammer 40 000 armageddon golgotha', 0.16666666666666666],
#   ['warhammer 40 000 armageddon macragge', 0.16666666666666666],
#   ['warhammer 40 000 armageddon soundtrack', 0.16666666666666666],
#   ['warhammer 40 000 chaos rising', 0.16666666666666666],
#   ['warhammer 40 000 drenn redblade', 0.16666666666666666],
#   ['warhammer 40 000 eternal crusade', 0.16666666666666666],
#   ['warhammer 40 000 gladius relics', 0.16666666666666666],
#   ['warhammer 40 000 gladius tyranids', 0.16666666666666666],
#   ['warhammer 40 000 inquisitor prophecy', 0.16666666666666666],
#   ['warhammer 40 000 mechanicus heretek', 0.16666666666666666],
#   ['warhammer 40 000 marine sword', 0.16666666666666666],
#   ['creature clicker 000 ingame credits', 0.16666666666666666]],
#  '000 bc': [['23 000', 0.25],
#   ['bc kings', 0.25],
#   ['000 000', 0.25],
#   ['130 000', 0.25],
#   ['warhammer 40 000', 0.2],
#   ['20 000 miles', 0.2],
#   ['orbs 300 000', 0.2],
#   ['warhammer 40 000 darktide', 0.16666666666666666],
#   ['warhammer 40 000 crusade', 0.16666666666666666],
#   ['warhammer 40 000 armageddon', 0.16666666666666666],
#   ['proud souls 200 000', 0.16666666666666666],
#   ['warhammer 40 000 team', 0.16666666666666666],
#   ['warhammer 40 000 regicide', 0.16666666666666666],
#   ['warhammer 40 000 mechanicus', 0.16666666666666666],
#   ['warhammer 40 000 retribution', 0.16666666666666666],
#   ['field 3 000 golds', 0.16666666666666666],
#   ['warhammer 40 000 soulstorm', 0.16666666666666666],
#   ['warhammer 40 000 edition', 0.16666666666666666],
#   ['20 000 miles soundtrack', 0.16666666666666666],
#   ['warhammer 40 000 marine', 0.16666666666666666],
#   ['150 000 b c', 0.16666666666666666],
#   ['gladiabots 12 000 credits', 0.16666666666666666],
#   ['gladiabots 2 000 credits', 0.16666666666666666],
#   ['gladiabots 28 000 credits', 0.16666666666666666],
#   ['20 000 leagues nemo', 0.16666666666666666],
#   ['gladiabots 64 000 credits', 0.16666666666666666],
#   ['warhammer 40 000 kanak', 0.16666666666666666],
#   ['warhammer 40 000 drenn redblade', 0.14285714285714285],
#   ['lovehammer 400 000 buttlerian crusade', 0.14285714285714285],
#   ['warhammer 40 000 chaos rising', 0.14285714285714285],
#   ['warhammer 40 000 armageddon soundtrack', 0.14285714285714285],
#   ['warhammer 40 000 armageddon macragge', 0.14285714285714285],
#   ['warhammer 40 000 armageddon golgotha', 0.14285714285714285],
#   ['warhammer 40 000 ultramarines pack', 0.14285714285714285],
#   ['warhammer 40 000 mechanicus heretek', 0.14285714285714285],
#   ['warhammer 40 000 winter assault', 0.14285714285714285],
#   ['warhammer 40 000 regicide soundtrack', 0.14285714285714285],
#   ['warhammer 40 000 retribution pack', 0.14285714285714285],
#   ['warhammer 40 000 saga awakening', 0.14285714285714285],
#   ['warhammer 40 000 sanctus reach', 0.14285714285714285],
#   ['field 3 100 000 golds', 0.14285714285714285],
#   ['warhammer 40 000 sigurd ironside', 0.14285714285714285],
#   ['warhammer 40 000 wrath damned', 0.14285714285714285],
#   ['warhammer 40 000 sentry pack', 0.14285714285714285],
#   ['warhammer 40 000 inquisitor martyr', 0.14285714285714285],
#   ['warhammer 40 000 eternal crusade', 0.14285714285714285],
#   ['warhammer 40 000 inquisitor prophecy', 0.14285714285714285],
#   ['warhammer 40 000 gladius relics', 0.14285714285714285],
#   ['1 000 heads among trees', 0.14285714285714285],
#   ['warhammer 40 000 gladius tyranids', 0.14285714285714285]],
#  '000 km': [['23 000', 0.25],
#   ['000 000', 0.25],
#   ['130 000', 0.25],
#   ['20 000 miles', 0.2],
#   ['warhammer 40 000', 0.2],
#   ['orbs 300 000', 0.2],
#   ['field 3 000 golds', 0.16666666666666666],
#   ['gladiabots 28 000 credits', 0.16666666666666666],
#   ['warhammer 40 000 team', 0.16666666666666666],
#   ['warhammer 40 000 retribution', 0.16666666666666666],
#   ['warhammer 40 000 regicide', 0.16666666666666666],
#   ['proud souls 200 000', 0.16666666666666666],
#   ['warhammer 40 000 mechanicus', 0.16666666666666666],
#   ['warhammer 40 000 armageddon', 0.16666666666666666],
#   ['gladiabots 12 000 credits', 0.16666666666666666],
#   ['gladiabots 2 000 credits', 0.16666666666666666],
#   ['warhammer 40 000 crusade', 0.16666666666666666],
#   ['warhammer 40 000 darktide', 0.16666666666666666],
#   ['gladiabots 64 000 credits', 0.16666666666666666],
#   ['warhammer 40 000 edition', 0.16666666666666666],
#   ['150 000 b c', 0.16666666666666666],
#   ['20 000 leagues nemo', 0.16666666666666666],
#   ['20 000 miles soundtrack', 0.16666666666666666],
#   ['warhammer 40 000 kanak', 0.16666666666666666],
#   ['warhammer 40 000 marine', 0.16666666666666666],
#   ['warhammer 40 000 soulstorm', 0.16666666666666666],
#   ['warhammer 40 000 sigurd ironside', 0.14285714285714285],
#   ['lovehammer 400 000 buttlerian crusade', 0.14285714285714285],
#   ['warhammer 40 000 wrath damned', 0.14285714285714285],
#   ['warhammer 40 000 winter assault', 0.14285714285714285],
#   ['warhammer 40 000 ultramarines pack', 0.14285714285714285],
#   ['warhammer 40 000 inquisitor martyr', 0.14285714285714285],
#   ['warhammer 40 000 sentry pack', 0.14285714285714285],
#   ['warhammer 40 000 sanctus reach', 0.14285714285714285],
#   ['warhammer 40 000 saga awakening', 0.14285714285714285],
#   ['warhammer 40 000 retribution pack', 0.14285714285714285],
#   ['warhammer 40 000 regicide soundtrack', 0.14285714285714285],
#   ['field 3 100 000 golds', 0.14285714285714285],
#   ['warhammer 40 000 armageddon golgotha', 0.14285714285714285],
#   ['warhammer 40 000 armageddon macragge', 0.14285714285714285],
#   ['warhammer 40 000 armageddon soundtrack', 0.14285714285714285],
#   ['warhammer 40 000 chaos rising', 0.14285714285714285],
#   ['warhammer 40 000 drenn redblade', 0.14285714285714285],
#   ['warhammer 40 000 eternal crusade', 0.14285714285714285],
#   ['warhammer 40 000 gladius relics', 0.14285714285714285],
#   ['warhammer 40 000 gladius tyranids', 0.14285714285714285],
#   ['warhammer 40 000 inquisitor prophecy', 0.14285714285714285],
#   ['warhammer 40 000 mechanicus heretek', 0.14285714285714285],
#   ['warhammer 40 000 marine sword', 0.14285714285714285],
#   ['creature clicker 000 ingame credits', 0.14285714285714285]],
#  '000 named': [['000 000', 0.25],
#   ['23 000', 0.25],
#   ['130 000', 0.25],
#   ['named fred', 0.25],
#   ['20 000 miles', 0.2],
#   ['warhammer 40 000', 0.2],
#   ['orbs 300 000', 0.2],
#   ['enigma illusion named', 0.2],
#   ['a virus named', 0.2],
#   ['a labyrinth named', 0.2],
#   ['gladiabots 64 000 credits', 0.16666666666666666],
#   ['warhammer 40 000 retribution', 0.16666666666666666],
#   ['warhammer 40 000 darktide', 0.16666666666666666],
#   ['warhammer 40 000 crusade', 0.16666666666666666],
#   ['warhammer 40 000 armageddon', 0.16666666666666666],
#   ['warhammer 40 000 regicide', 0.16666666666666666],
#   ['proud souls 200 000', 0.16666666666666666],
#   ['field 3 000 golds', 0.16666666666666666],
#   ['gladiabots 28 000 credits', 0.16666666666666666],
#   ['warhammer 40 000 soulstorm', 0.16666666666666666],
#   ['warhammer 40 000 team', 0.16666666666666666],
#   ['150 000 b c', 0.16666666666666666],
#   ['warhammer 40 000 mechanicus', 0.16666666666666666],
#   ['gladiabots 12 000 credits', 0.16666666666666666],
#   ['gladiabots 2 000 credits', 0.16666666666666666],
#   ['warhammer 40 000 edition', 0.16666666666666666],
#   ['a robot named fight', 0.16666666666666666],
#   ['warhammer 40 000 marine', 0.16666666666666666],
#   ['warhammer 40 000 kanak', 0.16666666666666666],
#   ['20 000 miles soundtrack', 0.16666666666666666],
#   ['20 000 leagues nemo', 0.16666666666666666],
#   ['warhammer 40 000 sentry pack', 0.14285714285714285],
#   ['warhammer 40 000 regicide soundtrack', 0.14285714285714285],
#   ['warhammer 40 000 armageddon macragge', 0.14285714285714285],
#   ['warhammer 40 000 chaos rising', 0.14285714285714285],
#   ['lovehammer 400 000 buttlerian crusade', 0.14285714285714285],
#   ['warhammer 40 000 sigurd ironside', 0.14285714285714285],
#   ['warhammer 40 000 armageddon golgotha', 0.14285714285714285],
#   ['warhammer 40 000 drenn redblade', 0.14285714285714285],
#   ['warhammer 40 000 eternal crusade', 0.14285714285714285],
#   ['warhammer 40 000 inquisitor prophecy', 0.14285714285714285],
#   ['warhammer 40 000 mechanicus heretek', 0.14285714285714285],
#   ['warhammer 40 000 wrath damned', 0.14285714285714285],
#   ['warhammer 40 000 winter assault', 0.14285714285714285],
#   ['warhammer 40 000 marine sword', 0.14285714285714285],
#   ['warhammer 40 000 ultramarines pack', 0.14285714285714285],
#   ['warhammer 40 000 inquisitor martyr', 0.14285714285714285],
#   ['warhammer 40 000 gladius tyranids', 0.14285714285714285],
#   ['1 000 heads among trees', 0.14285714285714285],
#   ['creature clicker 000 ingame credits', 0.14285714285714285]],
#  '1': [['1', 0.5],
#   ['endless 1', 0.3333333333333333],
#   ['coloring 1', 0.3333333333333333],
#   ['zarya 1', 0.3333333333333333],
#   ['spermula 1', 0.3333333333333333],
#   ['fighter 1', 0.3333333333333333],
#   ['episode 1', 0.3333333333333333],
#   ['1 0', 0.3333333333333333],
#   ['tier 1', 0.3333333333333333],
#   ['remains 1', 0.3333333333333333],
#   ['velez 1', 0.3333333333333333],
#   ['insecticide 1', 0.3333333333333333],
#   ['1 orb', 0.3333333333333333],
#   ['megarace 1', 0.3333333333333333],
#   ['round 1', 0.3333333333333333],
#   ['prog 1', 0.3333333333333333],
#   ['piratado 1', 0.3333333333333333],
#   ['gothic 1', 0.3333333333333333],
#   ['perseverance 1', 0.3333333333333333],
#   ['trooper 1', 0.3333333333333333],
#   ['kingdom 1', 0.3333333333333333],
#   ['battlefield 1', 0.3333333333333333],
#   ['shrub 1', 0.3333333333333333],
#   ['godorevil 1', 0.3333333333333333],
#   ['forgotten 1', 0.3333333333333333],
#   ['chapter 1', 0.3333333333333333],
#   ['ensign 1', 0.3333333333333333],
#   ['geneforge 1', 0.3333333333333333],
#   ['catacombs 1 demon', 0.25],
#   ['nekopara vol 1', 0.25],
#   ['hiveswap act 1', 0.25],
#   ['trespass episode 1', 0.25],
#   ['3 pack 1', 0.25],
#   ['opus 1 social', 0.25],
#   ['android 2 1', 0.25],
#   ['glowcoma chapter 1', 0.25],
#   ['loading chapter 1', 0.25],
#   ['machines 1 5', 0.25],
#   ['freya alpha 1', 0.25],
#   ['president level 1', 0.25],
#   ['bonasera episode 1', 0.25],
#   ['subways 1 path', 0.25],
#   ['proxyah v3 1', 0.25],
#   ['technolites episode 1', 0.25],
#   ['aldroy chapter 1', 0.25],
#   ['rwby volume 1', 0.25],
#   ['kaboom 1 1', 0.25],
#   ['flatland vol 1', 0.25],
#   ['hellseed chapter 1', 0.25],
#   ['pilgrim academy 1', 0.25]],
#  '1 2 3 4 ou collants noirs': [['1 2 3 bruegel', 0.2727272727272727],
#   ['3 2 1 grenades', 0.2727272727272727],
#   ['3 2 1 survive', 0.2727272727272727],
#   ['chusingura46 1 s chapter 2 3', 0.23076923076923078],
#   ['1 2 3 kick drop beat ugly', 0.21428571428571427],
#   ['3 pack 1', 0.2],
#   ['4 soldier 1', 0.2],
#   ['apple 1 2', 0.2],
#   ['android 2 1', 0.2],
#   ['2 episode 3', 0.2],
#   ['chapter 1 2', 0.2],
#   ['left 4 2', 0.2],
#   ['trap 2 3', 0.2],
#   ['2 episode 4', 0.2],
#   ['dirt rally 2 0 season 4 stage 1 liveries', 0.1875],
#   ['fantasy grounds 3 5e pfrpg 1 1 2 olinder', 0.1875],
#   ['agarest 2 bundle 3', 0.18181818181818182],
#   ['agarest 2 bundle 1', 0.18181818181818182],
#   ['agarest 2 bundle 4', 0.18181818181818182],
#   ['3 map pack 2', 0.18181818181818182],
#   ['1 screen platformer 2', 0.18181818181818182],
#   ['2 bikes pack 4', 0.18181818181818182],
#   ['3 map pack 1', 0.18181818181818182],
#   ['2 ninjas 1 cup', 0.18181818181818182],
#   ['3 2018 pack 2', 0.18181818181818182],
#   ['3 2018 pack 1', 0.18181818181818182],
#   ['3 2 strokes pack', 0.18181818181818182],
#   ['aveyond 3 2 gates', 0.18181818181818182],
#   ['coloring 3 video 1', 0.18181818181818182],
#   ['2 bikes pack 3', 0.18181818181818182],
#   ['solitaire 2 chapter 1', 0.18181818181818182],
#   ['unlimited 3 4 pack', 0.18181818181818182],
#   ['defense 4 1 despair', 0.18181818181818182],
#   ['solitaire 2 chapter 3', 0.18181818181818182],
#   ['lego potter 1 4', 0.18181818181818182],
#   ['sorcery parts 1 2', 0.18181818181818182],
#   ['borderlands 2 headhunter 4', 0.18181818181818182],
#   ['fantasy grounds 1 1 4 sixth cavalier pfrpg 3 5e', 0.17647058823529413],
#   ['funfair simulator 3 pack 2', 0.16666666666666666],
#   ['funfair simulator 3 pack 1', 0.16666666666666666],
#   ['mushroom 2 episode 3 furious', 0.16666666666666666],
#   ['hitman 2 assignments pack 1', 0.16666666666666666],
#   ['aveyond 3 4 darkthrop prophecy', 0.16666666666666666],
#   ['hidden object bundle 4 1', 0.16666666666666666],
#   ['funfair simulator 3 pack 4', 0.16666666666666666],
#   ['samurai hyuga 4 stories 1', 0.16666666666666666],
#   ['defense 4 1 wingdiver shooter', 0.16666666666666666],
#   ['season pass episodes 2 4', 0.16666666666666666],
#   ['fantastic 4 a row 2', 0.16666666666666666],
#   ['fantastic contraption classic 1 2', 0.16666666666666666]],
#  '1 chance 2': [['android 2 1', 0.3333333333333333],
#   ['apple 1 2', 0.3333333333333333],
#   ['chapter 1 2', 0.3333333333333333],
#   ['sorcery parts 1 2', 0.2857142857142857],
#   ['1 2 3 bruegel', 0.2857142857142857],
#   ['solitaire 2 chapter 1', 0.2857142857142857],
#   ['2 ninjas 1 cup', 0.2857142857142857],
#   ['3 2 1 grenades', 0.2857142857142857],
#   ['1 screen platformer 2', 0.2857142857142857],
#   ['3 2 1 survive', 0.2857142857142857],
#   ['agarest 2 bundle 1', 0.2857142857142857],
#   ['fantastic contraption classic 1 2', 0.25],
#   ['2', 0.25],
#   ['dungeons 2 a chance dragons', 0.25],
#   ['hitman 2 assignments pack 1', 0.25],
#   ['chance', 0.25],
#   ['injustice 2 fighter pack 1', 0.25],
#   ['1', 0.25],
#   ['ball xenoverse 2 pack 1', 0.25],
#   ['payday 2 tailor pack 1', 0.25],
#   ['hello neighbor 2 alpha 1', 0.25],
#   ['reversion chapters 1 2 soundtrack', 0.25],
#   ['ball xenoverse 2 anime pack 1', 0.2222222222222222],
#   ['omsi 2 add vienna 1 24a', 0.2222222222222222],
#   ['ball xenoverse 2 ultra pack 1', 0.2222222222222222],
#   ['s 2 dlc pack 1 hawks', 0.2222222222222222],
#   ['farnham fables tape 1 episode 2', 0.2222222222222222],
#   ['payday 2 weapon color pack 1', 0.2222222222222222],
#   ['borderlands 2 headhunter 1 bloody harvest', 0.2222222222222222],
#   ['squad original soundtrack vol 1 2', 0.2222222222222222],
#   ['touhou blooming chaos 2 soundtrack 1', 0.2222222222222222],
#   ['toukiden 2 mission collection set 1', 0.2222222222222222],
#   ['renegades orion 2 0 dlc 1', 0.2222222222222222],
#   ['chusingura46 1 s chapter 2 3', 0.2222222222222222],
#   ['capital 2', 0.2],
#   ['vitatio 2', 0.2],
#   ['draw 2', 0.2],
#   ['grunts 2', 0.2],
#   ['gal 2', 0.2],
#   ['cars 2', 0.2],
#   ['tekling 2', 0.2],
#   ['ensign 1', 0.2],
#   ['dota 2', 0.2],
#   ['entertainment 2', 0.2],
#   ['stronghold 2', 0.2],
#   ['flotilla 2', 0.2],
#   ['slavistan 2', 0.2],
#   ['blair 2', 0.2],
#   ['cloudlands 2', 0.2],
#   ['hitman 2', 0.2]],
#  '1 cheerleader': [['1', 0.3333333333333333],
#   ['forgotten 1', 0.25],
#   ['tier 1', 0.25],
#   ['1 orb', 0.25],
#   ['round 1', 0.25],
#   ['battlefield 1', 0.25],
#   ['remains 1', 0.25],
#   ['insecticide 1', 0.25],
#   ['ensign 1', 0.25],
#   ['1 0', 0.25],
#   ['endless 1', 0.25],
#   ['chapter 1', 0.25],
#   ['piratado 1', 0.25],
#   ['zarya 1', 0.25],
#   ['coloring 1', 0.25],
#   ['geneforge 1', 0.25],
#   ['fighter 1', 0.25],
#   ['velez 1', 0.25],
#   ['gothic 1', 0.25],
#   ['perseverance 1', 0.25],
#   ['shrub 1', 0.25],
#   ['kingdom 1', 0.25],
#   ['megarace 1', 0.25],
#   ['episode 1', 0.25],
#   ['spermula 1', 0.25],
#   ['trooper 1', 0.25],
#   ['godorevil 1', 0.25],
#   ['prog 1', 0.25],
#   ['subways 1 path', 0.2],
#   ['vapour 1 soundtrack', 0.2],
#   ['iraq 1 pandemic', 0.2],
#   ['android 2 1', 0.2],
#   ['countershots 1 0', 0.2],
#   ['hellseed chapter 1', 0.2],
#   ['professor chemistry 1', 0.2],
#   ['rwby volume 1', 0.2],
#   ['karma incarnation 1', 0.2],
#   ['esports ep 1', 0.2],
#   ['whitelily 1 丽丽公主', 0.2],
#   ['robot female 1', 0.2],
#   ['grave prosperity 1', 0.2],
#   ['mu ost 1', 0.2],
#   ['ping 1 5', 0.2],
#   ['chusingura46 1 s', 0.2],
#   ['hector episode 1', 0.2],
#   ['mirrored chapter 1', 0.2],
#   ['null episode 1', 0.2],
#   ['mcosu donation 1', 0.2],
#   ['pilgrim academy 1', 0.2],
#   ['harvester episode 1', 0.2]],
#  '1 mile': [['1', 0.3333333333333333],
#   ['episode 1', 0.25],
#   ['kingdom 1', 0.25],
#   ['1 0', 0.25],
#   ['ensign 1', 0.25],
#   ['1 orb', 0.25],
#   ['piratado 1', 0.25],
#   ['trooper 1', 0.25],
#   ['shrub 1', 0.25],
#   ['godorevil 1', 0.25],
#   ['remains 1', 0.25],
#   ['tier 1', 0.25],
#   ['chapter 1', 0.25],
#   ['fighter 1', 0.25],
#   ['insecticide 1', 0.25],
#   ['spermula 1', 0.25],
#   ['perseverance 1', 0.25],
#   ['megarace 1', 0.25],
#   ['velez 1', 0.25],
#   ['forgotten 1', 0.25],
#   ['coloring 1', 0.25],
#   ['round 1', 0.25],
#   ['battlefield 1', 0.25],
#   ['endless 1', 0.25],
#   ['zarya 1', 0.25],
#   ['prog 1', 0.25],
#   ['gothic 1', 0.25],
#   ['geneforge 1', 0.25],
#   ['chapter 1 solution', 0.2],
#   ['donation level 1', 0.2],
#   ['flowers reward 1', 0.2],
#   ['reset 1 1', 0.2],
#   ['countershots 1 0', 0.2],
#   ['urban episode 1', 0.2],
#   ['chapter 1 2', 0.2],
#   ['chapter 1 soundtrack', 0.2],
#   ['fighter alpha 1', 0.2],
#   ['hellseed chapter 1', 0.2],
#   ['agency chapter 1', 0.2],
#   ['mcosu donation 1', 0.2],
#   ['deathbloom chapter 1', 0.2],
#   ['karma incarnation 1', 0.2],
#   ['professor chemistry 1', 0.2],
#   ['machines 1 5', 0.2],
#   ['glowcoma chapter 1', 0.2],
#   ['esports ep 1', 0.2],
#   ['harvester episode 1', 0.2],
#   ['flatland vol 1', 0.2],
#   ['insectophobia episode 1', 0.2],
#   ['kokurase episode 1', 0.2]]}

# %%
from sklearn.feature_extraction.text import CountVectorizer

movie_game_names = movie_title_list + game_title_list
vectorizer = CountVectorizer()
name_vec = vectorizer.fit_transform(movie_game_names).toarray()

# %%
def get_similarity(mat):
    res = {}
    num_mov = len(movie_title_list)
    for i in range(num_mov):
        score_lst = []
        for j in range(len(game_title_list)):
            score = (np.minimum(mat[i], game_title_list[num_mov+j]))
            score_lst.append(score)
        sim_json[movie_title_list[i]] = get_top_movie_info(score_lst, 50)

# %%
movie_title_list.index('lego')
# Out:
# 12073

# %%
i = 12073
num_mov = len(movie_title_list)
mov_vec = name_vec[i]

for j in range(len(game_title_list)):
    game_vec = name_vec[num_mov+j]
    numer = sum(np.minimum(mov_vec, game_vec))
#     print(numer)
    denom = np.dot(mov_vec, game_vec)
#     print(denom)
    score_lst.append(numer/denom)
print(score_lst)
# print(get_top_movie_info(score_lst, 50))
# Out:
# /Users/susan/Development/cs4300/cs4300sp2020-cw887-qh75-rz92-yc687-yl698/tutorial_venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in long_scalars
#   # This is added back by InteractiveShellApp.init_path()

# %%
sum(np.minimum([1, 2, 3], [4, 5,6]))
# Out:
# 6

# %%
name_vec.toarray().shape
# Out:
# (25832, 19873)

# %%
len(movie_title_list)
# Out:
# 23221

# %%
len(game_title_list)
# Out:
# 2611
