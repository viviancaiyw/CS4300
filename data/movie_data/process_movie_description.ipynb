# %%
import os
import pandas as pd
import json
import re

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from rake_nltk import Rake 
import yake
import spacy
import gensim
from gensim.parsing.preprocessing import STOPWORDS
from gensim.summarization import keywords

# %% [markdown]
# # Process movie description keywords

# %%
data_dir = os.getcwd()

with open(os.path.join(data_dir, 'movie_id_to_info.json')) as f:
    movie_id_to_info = json.load(f)
with open(os.path.join(data_dir, 'movie_id_ranked_by_audience_number.json')) as f:
    ranked_movies_lst = json.load(f)

# %%
movie_id_to_info
# Out:
# {'0814255': {'name': 'Percy Jackson & the Olympians: The Lightning Thief',
#   'simplified_name': 'Percy Jackson & the Olympians',
#   'description': "Always trouble-prone, the life of teenager Percy Jackson (Logan Lerman) gets a lot more complicated when he learns he's the son of the Greek god Poseidon. At a training ground for the children of deities, Percy learns to harness his divine powers and prepare for the adventure of a lifetime: he must prevent a feud among the Olympians from erupting into a devastating war on Earth, and rescue his mother from the clutches of Hades, god of the underworld.",
#   'genre': ['drama',
#    'action & adventure',
#    'comedy',
#    'science fiction & fantasy'],
#   'critics_consensus': 'Though it may seem like just another Harry Potter knockoff, Percy Jackson benefits from a strong supporting cast, a speedy plot, and plenty of fun with Greek mythology.',
#   'content_rating': 'PG',
#   'audience_count': 254421.0},
#  '0878835': {'name': 'Please Give',
#   'simplified_name': 'Please Give',
#   'description': "Kate (Catherine Keener) and her husband Alex (Oliver Platt) are wealthy New Yorkers who prowl estate sales and make a tidy profit reselling items they bought cheaply. They buy the apartment next door and plan to remodel just as soon as its current occupant, a cranky old woman, dies. Kate is troubled by the way she and her husband earn a living, and tries to assuage her guilt by befriending her tenant and the woman's granddaughters, but her overtures lead to unexpected consequences.",
#   'genre': ['comedy'],
#   'critics_consensus': "Nicole Holofcener's newest might seem slight in places, but its rendering of complex characters in a conflicted economic landscape is varied, natural, and touching all the same.",
#   'content_rating': 'R',
#   'audience_count': 11574.0},
#  '10': {'name': '10',
#   'simplified_name': '10',
#   'description': 'A successful, middle-aged Hollywood songwriter falls hopelessly in love with the woman of his dreams, and even follows the girl and her new husband to their Mexican honeymoon resort. While his behavior seems sure to land him in trouble, out of the blue fate plays into his hands.',
#   'genre': ['comedy', 'romance'],
#   'critics_consensus': "Blake Edwards' bawdy comedy may not score a perfect 10, but Dudley Moore's self-deprecating performance makes this midlife crisis persistently funny.",
#   'content_rating': 'R',
#   'audience_count': 14684.0},
#  '1000013-12_angry_men': {'name': '12 Angry Men (Twelve Angry Men)',
#   'simplified_name': '12 Angry Men (Twelve Angry Men)',
#   'description': "Following the closing arguments in a murder trial, the 12 members of the jury must deliberate, with a guilty verdict meaning death for the accused, an inner-city teen. As the dozen men try to reach a unanimous decision while sequestered in a room, one juror (Henry Fonda) casts considerable doubt on elements of the case. Personal issues soon rise to the surface, and conflict threatens to derail the delicate process that will decide one boy's fate.",
#   'genre': ['drama', 'classics'],
#   'critics_consensus': "Sidney Lumet's feature debut is a superbly written, dramatically effective courtroom thriller that rightfully stands as a modern classic.",
#   'content_rating': 'NR',
#   'audience_count': 105386.0},
#  '1000079-20000_leagues_under_the_sea': {'name': '20,000 Leagues Under The Sea',
#   'simplified_name': '20,000 Leagues Under The Sea',
#   'description': 'In 1866, Professor Pierre M. Aronnax (Paul Lukas) and his assistant Conseil (Peter Lorre), stranded in San Francisco by reports of a giant sea monster attacking ships in the Pacific Ocean, are invited to join an expedition to search for the creature. During the search, they and harpooner Ned Land (Kirk Douglas) are thrown overboard during an attack, eventually discovering that the supposed monster is actually a submarine piloted by the brilliant but haunted Captain Nemo (James Mason).',
#   'genre': ['drama', 'action & adventure', 'kids & family'],
#   'critics_consensus': "One of Disney's finest live-action adventures, 20,000 Leagues Under the Sea brings Jules Verne's classic sci-fi tale to vivid life, and features an awesome giant squid.",
#   'content_rating': 'G',
#   'audience_count': 68918.0},
#  '10000_bc': {'name': '10,000 B.C.',
#   'simplified_name': '10,000 B.C.',
#   'description': "Mammoth hunter D'Leh (Steven Strait) has long been in love with a beautiful, blue-eyed tribeswoman named Evolet (Camilla Belle). After horseback-riding raiders kidnap most of his D'Leh's fellow tribesmen as well as Evolet, he sets out on a dangerous trek to rescue her from her captors.",
#   'genre': ['drama', 'action & adventure', 'classics'],
#   'critics_consensus': 'With attention strictly paid to style instead of substance, or historical accuracy, 10,000 B.C. is a visually impressive but narratively flimsy epic.',
#   'content_rating': 'PG-13',
#   'audience_count': 411140.0},
#  '1000121-39_steps': {'name': 'The 39 Steps',
#   'simplified_name': 'The 39 Steps',
#   'description': 'While on vacation in London, Canadian Richard Hannay (Robert Donat) becomes embroiled in an international spy ring related to the mysterious "39 steps." Then he meets agent Annabella Smith (Lucie Mannheim), who is soon killed in his apartment. He must elude the police, who are hunting him for murder, while he tries to stop Professor Jordan (Godfrey Tearle) from sending secrets out of the country. Hannay is assisted by Pamela (Madeleine Carroll), an unwilling accomplice who discovers the truth.',
#   'genre': ['mystery & suspense', 'action & adventure', 'classics'],
#   'critics_consensus': "Packed with twists and turns, this essential early Alfred Hitchcock feature hints at the dazzling heights he'd reach later in his career.",
#   'content_rating': 'NR',
#   'audience_count': 23890.0},
#  '1000123-310_to_yuma': {'name': '3:10 to Yuma',
#   'simplified_name': '3',
#   'description': "Dan Evans (Van Heflin), a drought-plagued Arizona rancher, volunteers to take captured stagecoach robber and murderer Ben Wade (Glenn Ford) from Bisbee to Contention City, where the criminal will be put aboard the 3:10 train to Yuma for his trial. Accompanied only by the town drunk, Alex Potter (Henry Jones), Dan battles Wade's henchman (Richard Jaeckel), the murder victim's revenge-minded brother, and the temptation of the large bribe Wade offers in exchange for his freedom.",
#   'genre': ['drama', 'classics', 'western'],
#   'critics_consensus': nan,
#   'content_rating': 'NR',
#   'audience_count': 9243.0},
#  '10002008-charly': {'name': 'Charly (A Heartbeat Away)',
#   'simplified_name': 'Charly (A Heartbeat Away)',
#   'description': 'Cultural differences, past loves and personal crises threaten the emerging romance between a free spirit (Heather Beers) and her conventional beau (Jeremy Elliott).',
#   'genre': ['drama', 'comedy', 'romance'],
#   'critics_consensus': nan,
#   'content_rating': 'PG',
#   'audience_count': 4819.0},
#  '1000204-abraham_lincoln': {'name': 'Abraham Lincoln',
#   'simplified_name': 'Abraham Lincoln',
#   'description': 'The 16th U.S. president (Walter Huston) is portrayed as a lawyer, orator, husband and Civil War commander.',
#   'genre': ['drama', 'classics'],
#   'critics_consensus': nan,
#   'content_rating': 'NR',
#   'audience_count': 457.0},
#  '10002114-dark_water': {'name': 'Dark Water',
#   'simplified_name': 'Dark Water',
#   'description': "In this moody Japanese horror film, newly-single mom Yoshimi Matsubara (Hitomi Kuroki) is enduring a bitter divorce and struggling to keep custody of her young daughter, Ikuko (Rio Kanno). As the unstable Yoshimi tries to make a fresh start in a new apartment, strange occurrences in the building gradually begin to take their toll. When Yoshimi and Ikuko both start seeing unsettling visions of a ghostly little girl, it's clear that they're being drawn toward the supernatural.",
#   'genre': ['horror', 'art house & international', 'mystery & suspense'],
#   'critics_consensus': nan,
#   'content_rating': 'PG-13',
#   'audience_count': 21475.0},
#  '1000224-accused': {'name': 'The Accused',
#   'simplified_name': 'The Accused',
#   'description': 'Out drinking one night after a fight with her boyfriend, Sarah Tobias (Jodie Foster) is brutally raped by three men in a bar while people watch and cheer. District Attorney Kathryn Murphy (Kelly McGillis) takes the case, however allows the rapists to receive a mild sentence. A distraught Sarah decides to seek punishment for the men who witnessed and encouraged the rape. To get justice, Sarah must take the stand and revisit the night of her attack in this drama based on true events.',
#   'genre': ['drama', 'mystery & suspense'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 20821.0},
#  '10002516-lost_city': {'name': 'The Lost City',
#   'simplified_name': 'The Lost City',
#   'description': "Fico Fellove (Andy Garcia), an apolitical Havana club owner, gets caught in the middle when Fidel Castro's Communist Revolution sweeps through Cuba. He tries to keep the strife outside the walls of his popular establishment, but his family becomes divided when his brothers (Nestor Carbonell, Enrique Murciano) join the fight against Batista.",
#   'genre': ['drama'],
#   'critics_consensus': 'Its heart is in the right place, but what starts as a promising exercise devolves into an overlong, unevenly directed disappointment.',
#   'content_rating': 'R',
#   'audience_count': 25944.0},
#  '10002519-breaking_point': {'name': 'The Breaking Point',
#   'simplified_name': 'The Breaking Point',
#   'description': 'A charter-boat captain winds up in the middle of a syndicate shootout after transporting illegal immigrants.',
#   'genre': ['drama'],
#   'critics_consensus': nan,
#   'content_rating': 'NR',
#   'audience_count': 335.0},
#  '1000253-adams_rib': {'name': "Adam's Rib",
#   'simplified_name': "Adam's Rib",
#   'description': 'A courtroom rivalry finds its way into the household when prosecuting lawyer Adam Bonner (Spencer Tracy) faces off against his wife, Amanda (Katharine Hepburn), who happens to be a defense attorney. Working on opposite sides of a lawsuit where a woman (Judy Holliday) has shot her cheating husband (Tom Ewell), Adam and Amanda are both determined to win the case, and their home becomes the setting for comical showdowns, with neither spouse willing to relent.',
#   'genre': ['comedy', 'classics', 'romance'],
#   'critics_consensus': "Matched by Garson Kanin's witty, sophisticated screenplay, George Cukor, Spencer Tracy, and Katherine Hepburn are all in top form in the classic comedy Adam's Rib.",
#   'content_rating': 'NR',
#   'audience_count': 10563.0},
#  '10002635-bridge_of_san_luis_rey': {'name': 'The Bridge of San Luis Rey',
#   'simplified_name': 'The Bridge of San Luis Rey',
#   'description': "During the Spanish Inquisition, Franciscan monk Brother Juniper (Gabriel Byrne) witnesses the collapse of a bridge in Lima, Peru, and wonders why God has chosen to let five people perish. At a tribunal led by the imperious archbishop of Peru (Robert De Niro), the monk gives evidence about the tragedy's victims, including a marquesa (Kathy Bates) rejected by her daughter (Émilie Dequenne) and the beautiful mistress (Pilar López de Ayala) of a local nobleman (F. Murray Abraham).",
#   'genre': ['drama', 'faith & spirituality', 'art house & international'],
#   'critics_consensus': "Despite an all-star cast and some impressive visuals, The Bridge of San Luis Rey is a lifeless, slow-going adaptation of Thornton Wilder's classic novel.",
#   'content_rating': 'PG',
#   'audience_count': 1935.0},
#  '10002673-prowler': {'name': 'The Prowler (Cost of Living )',
#   'simplified_name': 'The Prowler (Cost of Living )',
#   'description': "After being frightened by a peeping Tom at her mansion in the suburbs, the beautiful Susan Gilvray (Evelyn Keyes) calls the police for help. When a policeman, Webb Garwood (Van Heflin), arrives, he becomes infatuated with Susan, and the two engage in an affair. Susan soon ends their relationship, choosing to remain with her husband, John (Sherry Hall). However, Webb's obsession with her continues to grow, until he begins plotting to kill John and cash in on his life insurance policy.",
#   'genre': ['drama', 'mystery & suspense'],
#   'critics_consensus': nan,
#   'content_rating': 'PG',
#   'audience_count': 286.0},
#  '10003276-criminal': {'name': 'Criminal',
#   'simplified_name': 'Criminal',
#   'description': "Needing a new partner capable of intricate cons, Richard Gaddis (John C. Reilly), recruits Rodrigo (Diego Luna), a crook with a perfect poker face. The two plan a big-time scam: selling a fake Silver Certificate to currency collector William Hannigan (Peter Mullan). Rodrigo distrusts his new associate, but needs money to help out his ill father. The situation becomes more complicated when Rodrigo falls for Gaddis' sister, Valerie (Maggie Gyllenhaal), drawing another player into the game.",
#   'genre': ['drama', 'mystery & suspense'],
#   'critics_consensus': 'If you saw Nine Queens, it may feel redundant, but the snappy performances make it fun to watch.',
#   'content_rating': 'R',
#   'audience_count': 6711.0},
#  '1000334-adventures_of_mark_twain': {'name': 'The Adventures of Mark Twain',
#   'simplified_name': 'The Adventures of Mark Twain',
#   'description': "In this claymation film, celebrated author Mark Twain (James Whitmore), displeased with the state of humanity, sets off in a hot-air balloon to meet his celestial destiny: Halley's Comet. Stowed away on the craft are beloved characters from Twain's stories -- Tom Sawyer (Chris Ritchie), Becky Thatcher (Michele Mariana) and Huckleberry Finn (Gary Krug). As Twain's balloon ascends ever higher to its ultimate goal, his literary creations try to persuade him of the essential goodness of man.",
#   'genre': ['action & adventure', 'animation', 'kids & family'],
#   'critics_consensus': nan,
#   'content_rating': 'G',
#   'audience_count': 1046.0},
#  '10003437-deep_blue': {'name': 'Deep Blue',
#   'simplified_name': 'Deep Blue',
#   'description': "This nature documentary shows the lives of different animals in and near the oceans that make up two-thirds of the planet's surface. Gray whales make their migratory journeys despite being menaced by killer whiles, while smaller fish struggle to stay alive. In the Arctic, penguins and polar bears endure the winter, while on beaches crabs emerge to feed. Meanwhile, five miles under the water, unusual forms of life thrive -- many of them in places less explored than the moon.",
#   'genre': ['documentary', 'special interest'],
#   'critics_consensus': 'Full of visually striking footage, Deep Blue may be too intense for younger viewers, but fans of nature documentaries will find much to enjoy.',
#   'content_rating': 'G',
#   'audience_count': 4692.0},
#  '1000355-adventures_of_robin_hood': {'name': 'The Adventures of Robin Hood',
#   'simplified_name': 'The Adventures of Robin Hood',
#   'description': 'When King Richard the Lionheart is captured, his scheming brother Prince John (Claude Rains) plots to reach the throne, to the outrage of Sir Robin of Locksley (Errol Flynn), the bandit king of Sherwood Forest. Rounding up his band of men and eventually winning the support of the lovely Maid Marian (Olivia de Havilland), Robin accuses Prince John of treachery and, when the escaped Richard returns covertly to England, joins forces with the king to prevent Prince John from taking the crown.',
#   'genre': ['action & adventure', 'classics', 'romance'],
#   'critics_consensus': 'Errol Flynn thrills as the legendary title character, and the film embodies the type of imaginative family adventure tailor-made for the silver screen.',
#   'content_rating': 'PG',
#   'audience_count': 33946.0},
#  '10003876-man_hunt': {'name': 'Man Hunt',
#   'simplified_name': 'Man Hunt',
#   'description': "Renowned big-game hunter Captain Thorndike (Walter Pidgeon) is hunting in the Bavarian forest when he stumbles upon Adolf Hitler's vacation residence. Tempted by the idea of assassinating the dictator, he's apprehended and beaten before escaping and stowing away on a steamship back to England. Onboard, Thorndike has his identity stolen by the smooth-talking con man Mr. Jones (John Carradine). Both men soon discover that Gestapo agents are swarming London, looking for the would-be assassin.",
#   'genre': ['drama', 'classics', 'mystery & suspense'],
#   'critics_consensus': nan,
#   'content_rating': 'NR',
#   'audience_count': 554.0},
#  '10003925-dead_end': {'name': 'Dead End',
#   'simplified_name': 'Dead End',
#   'description': "When a family en route to a Christmas Eve gathering decides to takes a shortcut down a wooded road, an eerie sequence of events signals trouble ahead. After nearly colliding with an oncoming car, father Frank (Ray Wise) picks up a ghostly hitchhiker (Amber Smith) and her infant child. With the sudden appearance of their new passengers, the route becomes dark and treacherous -- and the family's numbers rapidly begin to dwindle in a series of seemingly connected, grisly roadside accidents.",
#   'genre': ['horror', 'comedy', 'mystery & suspense'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 10373.0},
#  '10004050-bandwagon': {'name': 'Bandwagon',
#   'simplified_name': 'Bandwagon',
#   'description': "When Tony (Lee Holmes) loses his job, he decides to focus on singing and writing songs. He then starts a band with his friends: Wynn (Kevin Corrigan) plays guitar, Eric (Steve Parlavecchio) is on bass and Charlie (Matthew Hennessey) mans the drums. Though an encounter with a loan shark almost ends the group's career before it starts, they soon team up with manager Chester (Doug MacMillan) and hit the road, where they learn that the rock 'n' roll lifestyle isn't everything it's cracked up to be.",
#   'genre': ['comedy'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 386.0},
#  '10004069-whore': {'name': 'Whore',
#   'simplified_name': 'Whore',
#   'description': 'Encouraged by her neighbor (Daryl Hannah), a financially strapped graduate student (Denise Richards) turns to prostitution to make ends meet.',
#   'genre': ['drama', 'art house & international'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 914.0},
#  '10004209-tristan_and_isolde': {'name': 'Tristan & Isolde',
#   'simplified_name': 'Tristan & Isolde',
#   'description': 'After the fall of the Roman Empire, English orphan Tristan meets and falls in love with Irish princess Isolde, however she is set to marry Lord Marke, who raised Tristan. While unaware of her identity, he has won her hand in marriage for his lord and future king of the two countries, but now the passion of the two young people causes a rift leading to a devastating battle.',
#   'genre': ['drama', 'science fiction & fantasy', 'romance'],
#   'critics_consensus': "Competent but somewhat static, Tristan & Isolde doesn't achieve the sweeping romanticism that it aims for.",
#   'content_rating': 'PG-13',
#   'audience_count': 220956.0},
#  '10004226-wild_side': {'name': 'Wild Side',
#   'simplified_name': 'Wild Side',
#   'description': 'Along with one (Edouard Nikitine) of her live-in lovers, a woman (Stéphanie Michelini) returns to her home village to visit her dying mother.',
#   'genre': ['drama', 'art house & international'],
#   'critics_consensus': nan,
#   'content_rating': 'NR',
#   'audience_count': 867.0},
#  '10004232-10004232-tale_of_two_pizzas': {'name': 'A Tale of Two Pizzas',
#   'simplified_name': 'A Tale of Two Pizzas',
#   'description': 'The offspring of rival pizzeria owners (Vincent Pastore, Frank Vincent) fall in love as their fathers battle over who makes the best pie.',
#   'genre': ['comedy'],
#   'critics_consensus': nan,
#   'content_rating': 'PG',
#   'audience_count': nan},
#  '10004288-running_scared': {'name': 'Running Scared',
#   'simplified_name': 'Running Scared',
#   'description': "Mafia flunky Joey Gazelle (Paul Walker) is ordered to dispose of the guns that killed a pair of policemen. He hides them in his basement, where they are found by Oleg (Cameron Bright), the kid from next door, who uses one to shoot his brutal stepfather, a Russian mobster. The boy runs off, and Joey pursues him into the criminal underworld, desperate to retrieve the incriminating weapon. Meanwhile, corrupt detective Rydell (Chazz Palminteri) is following Joey's trail with his own agenda.",
#   'genre': ['drama', 'action & adventure', 'mystery & suspense'],
#   'critics_consensus': 'This film runs with frenetic energy punctuated by gratuitous violence but sorely lacks in plot, character development and stylistic flair.',
#   'content_rating': 'R',
#   'audience_count': 135400.0},
#  '10004352-going_the_distance': {'name': 'Going the Distance',
#   'simplified_name': 'Going the Distance',
#   'description': "Nick (Christopher Jacot) is a successful young man whose comfortable West Coast life couldn't be better. However, when his girlfriend falls under the influence of lecherous music producer Lenny Swackhammer (Jason Priestley), Nick impulsively decides to travel to Toronto to intervene. Nick's buddies Tyler (Shawn Roberts) and Dime (Ryan Belleville) opt to turn the quest into a cross-country road trip that's complete with wacky antics and encounters with beautiful women.",
#   'genre': ['comedy'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 13033.0},
#  '10004504-ultraviolet': {'name': 'Ultraviolet',
#   'simplified_name': 'Ultraviolet',
#   'description': 'In the late 21st-century, a vampiric disease modifies some people, imbuing each of them with superhuman strength, intelligence and speed. Worldwide civil war looms as normal people, feeling threatened by their enhanced brethren, demand the extermination of the group. One such transformed female (Milla Jovovich) finds herself caught in the crossfire when she becomes the protector of a boy who is perceived to be a threat to humanity.',
#   'genre': ['drama',
#    'action & adventure',
#    'horror',
#    'science fiction & fantasy'],
#   'critics_consensus': 'An incomprehensible and forgettable sci-fi thriller, Ultraviolet is inept in every regard.',
#   'content_rating': 'PG-13',
#   'audience_count': 279994.0},
#  '10004635-home_of_the_brave': {'name': 'Home of the Brave',
#   'simplified_name': 'Home of the Brave',
#   'description': 'In 1965, Klansmen murder a civil-rights worker named Viola Liuzzo who was driving with a black passenger.',
#   'genre': ['documentary', 'action & adventure', 'special interest', 'drama'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 866.0},
#  '10004659-arthur': {'name': 'Arthur and the Invisibles (Arthur and the Minimoys)',
#   'simplified_name': 'Arthur and the Invisibles (Arthur and the Minimoys)',
#   'description': "Ten-year-old Arthur must find a way to keep the home of his beloved grandmother from being destroyed by a developer with other plans. Remembering his grandfather's story of a treasure, he enters the world of tiny beings who live in perfect harmony with nature. Together with Princess Selenia and her young brother, Betameche, Arthur goes in search of the treasure and -- along the way -- discovers that his long-absent grandfather may not be missing after all.",
#   'genre': ['kids & family', 'animation', 'science fiction & fantasy'],
#   'critics_consensus': 'Arthur wastes its big-name voice talent on a predictable script and substandard CG animation.',
#   'content_rating': 'PG',
#   'audience_count': 134483.0},
#  '10004684-malevolence': {'name': 'Malevolence',
#   'simplified_name': 'Malevolence',
#   'description': 'Bank robbers (Brandon Johnson, Heather Magee) take two hostages to a rural farmhouse where a serial killer lurks.',
#   'genre': ['horror'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 2622.0},
#  '10004697-eternal': {'name': 'Eternal',
#   'simplified_name': 'Eternal',
#   'description': "A detective's (Conrad Pla) search for his missing wife leads him to a wealthy woman (Caroline Néron) who may have supernatural powers.",
#   'genre': ['horror', 'mystery & suspense'],
#   'critics_consensus': 'Even by the standards of camp, Eternal fails to entertain.',
#   'content_rating': 'R',
#   'audience_count': 1295.0},
#  '10004835-farewell_to_arms': {'name': 'A Farewell To Arms',
#   'simplified_name': 'A Farewell To Arms',
#   'description': "Based on the Ernest Hemingway novel, this World War I drama follows American soldier Lt. Frederick Henry (Rock Hudson) and his romance with a nurse, Catherine Barkley (Jennifer Jones). While fighting alongside the Italian army, Frederick is separated from Catherine, who is pregnant with his child. After helping locals escape to freedom, Frederick searches for Catherine while enemy forces hunt him across Italy. But Catherine's poor health may prevent Frederick from reaching her in time.",
#   'genre': ['drama', 'classics', 'romance'],
#   'critics_consensus': nan,
#   'content_rating': 'NR',
#   'audience_count': 1460.0},
#  '10004890-narrow_margin': {'name': 'The Narrow Margin',
#   'simplified_name': 'The Narrow Margin',
#   'description': "Tense story of a tough cop attempting to transport the widow of a gangster to the trial in which she'll testify. They undertake a rail journey from Chicago to Los Angeles with their lives constantly under threat from hit men on the train, who will stop at nothing to prevent her from testifying.",
#   'genre': ['drama', 'classics', 'mystery & suspense'],
#   'critics_consensus': nan,
#   'content_rating': 'NR',
#   'audience_count': 1135.0},
#  '10004925-matador': {'name': 'The Matador',
#   'simplified_name': 'The Matador',
#   'description': "Salesman Danny Wright (Greg Kinnear) is working through his shaky marriage and the untimely death of his child when he bumps into the similarly dispirited Julian Noble (Pierce Brosnan) in a Mexican dive bar. After they develop an unusual but meaningful bond, the brash Julian reveals that he is a contract killer, which doesn't bother Danny. Months later, a desperate Julian shows up at Danny's home and asks for a life-changing favor that truly puts their friendship to the test.",
#   'genre': ['drama', 'action & adventure', 'comedy', 'mystery & suspense'],
#   'critics_consensus': 'This humorously amoral, oddball comic thriller features strong performances by Pierce Brosnan and Greg Kinnear as a flamboyant, aging hit-man and an out of work suburban businessman, respectively.',
#   'content_rating': 'R',
#   'audience_count': 73701.0},
#  '10005057-smile': {'name': 'Smile',
#   'simplified_name': 'Smile',
#   'description': 'While visiting China, an American high-school student (Mika Boorem) befriends a teenager (Yi Ding) who has a facial deformity.',
#   'genre': ['drama', 'comedy', 'art house & international'],
#   'critics_consensus': nan,
#   'content_rating': 'PG-13',
#   'audience_count': 2059.0},
#  '10005104-intruder': {'name': "The Intruder (L'Intrus)",
#   'simplified_name': "The Intruder (L'Intrus)",
#   'description': 'After receiving a heart transplant, an enigmatic loner (Michel Subor) journeys to Tahiti to reconnect with the son he fathered many years earlier.',
#   'genre': ['drama', 'art house & international'],
#   'critics_consensus': 'The impressionistic narrative may confound the viewer, but Denis crafts wonderfully poetic, dreamlike imagery.',
#   'content_rating': 'G',
#   'audience_count': 9701.0},
#  '10005178-saint_ralph': {'name': 'Saint Ralph',
#   'simplified_name': 'Saint Ralph',
#   'description': "The year 1954 finds teen outcast Ralph Walker (Adam Butcher) getting in trouble at the Catholic school he attends in Ontario, Canada. When the headmaster (Gordon Pinsent) catches Ralph smoking, he puts the boy on the school's cross-county team to force him to put his time to better use. When Ralph discovers that his hospitalized mother has slipped into a coma, he decides to run in the Boston Marathon, hoping that, if he wins, God will grant him a miracle and make his mother well again.",
#   'genre': ['drama', 'comedy'],
#   'critics_consensus': 'Saint Ralph is an amiable tear-jerker that walks a fine line between being inspirational and being hokum.',
#   'content_rating': 'PG-13',
#   'audience_count': 6203.0},
#  '10005403-the_baxter': {'name': 'The Baxter',
#   'simplified_name': 'The Baxter',
#   'description': 'Elliot Sherman (Michael Showalter) has had terrible luck with women during his life, losing three of them to ex-boyfriends in outlandish situations. Now, a week before he is to marry Caroline (Elizabeth Banks), she mentions an old high-school boyfriend, Bradley (Justin Theroux), and Elliot worries that the curse is about to strike again. A co-worker named Cecil (Michelle Williams) attempts to reassure him, but trying not to give in to anxiety only makes things worse.',
#   'genre': ['comedy', 'romance'],
#   'critics_consensus': 'The Baxter is good-natured, but there are simply not enough laughs to fuel this comedy.',
#   'content_rating': 'PG-13',
#   'audience_count': 7436.0},
#  '10005499-oliver_twist': {'name': 'Oliver Twist',
#   'simplified_name': 'Oliver Twist',
#   'description': 'An orphan (Barney Clark) in 19th-century London falls in with a gang of young pickpockets who steal for their villainous master (Ben Kingsley).',
#   'genre': ['drama', 'kids & family'],
#   'critics_consensus': "Polanski's version of Dickens' classic won't have audiences asking for more because while polished and directed with skill, the movie's a very impersonal experience.",
#   'content_rating': 'PG-13',
#   'audience_count': 23294.0},
#  '1000560-alamo': {'name': 'The Alamo',
#   'simplified_name': 'The Alamo',
#   'description': "In 1836, the Mexican army, led by General Santa Anna, is invading Texas. Hoping to create a diversion for Santa Anna's forces, General Sam Houston (Richard Boone) orders Colonel William B. Travis (Laurence Harvey), joined by Colonels Jim Bowie (Richard Widmark) and Davy Crockett (John Wayne), to lead a small, heroic band of American and Texican fighters in a resistance battle at the Alamo mission. The carnage at the Alamo further spurs the Republic of Texas toward freedom.",
#   'genre': ['drama', 'action & adventure', 'classics', 'western'],
#   'critics_consensus': "John Wayne proves to be less compelling behind the camera than he is before it in The Alamo, a blustery dramatization of the fort's last stand that feels more like a first draft.",
#   'content_rating': 'NR',
#   'audience_count': 7337.0},
#  '10005755-g': {'name': 'G',
#   'simplified_name': 'G',
#   'description': "Summer G (Richard T. Jones), an aspiring rapper, finds himself enamored with a young woman named Sky Hightower (Chenoa Maxwell), an ambitious social climber who is wary of Summer's low-class status. Although she rejects him for Chip (Blair Underwood), who works in the lucrative world of finance, that only pushes Summer to work even harder to make himself a wealthy and important man -- someone Sky will love. However, he encounters problems from both the old money guard and from Sky herself.",
#   'genre': ['drama', 'romance'],
#   'critics_consensus': 'Race and class struggles come to the Hamptons in this reworking of The Great Gatsby with a hip-hop flavor. Unfortunately, too many subplots and a lack of believable characters spoil an otherwise novel concept.',
#   'content_rating': 'R',
#   'audience_count': 1143.0},
#  '1000580-alexander_the_great': {'name': 'Alexander the Great',
#   'simplified_name': 'Alexander the Great',
#   'description': 'The son of Philip of Macedonia (Fredric March) and Olympias (Danielle Darrieux), Alexander the Great (Richard Burton) is one of the most legendary leaders throughout history. As the Macedonian king, Alexander successfully unites all the ancient Greek tribes and leads them to defeat the imposing Persian Empire. With the fall of Babylon, Alexander continues to conquer most of the known world. Eventually, he achieves the status of unparalleled ruler atop his newly formed Greek empire.',
#   'genre': ['classics'],
#   'critics_consensus': nan,
#   'content_rating': 'G',
#   'audience_count': 5383.0},
#  '1000581-alfie': {'name': 'Alfie',
#   'simplified_name': 'Alfie',
#   'description': 'Set in postwar London, "Alfie" features Michael Caine as a chauffeur bent on promiscuity. After impregnating his girlfriend he takes off on vacation. He continues his life of womanizing, but he can\'t hide forever. A misfortune strikes and Alfie is forced to face the product of his ways.',
#   'genre': ['drama', 'comedy', 'classics', 'romance'],
#   'critics_consensus': "Anchored by Michael Caine's charmingly droll performance, Alfie is an equally raucous and heart-rending portrait of romance in the Swinging '60s.",
#   'content_rating': 'PG',
#   'audience_count': 14669.0},
#  '10005819-10005819-neverwas': {'name': 'Neverwas',
#   'simplified_name': 'Neverwas',
#   'description': 'Dr. Zach Riley (Aaron Eckhart) begins practicing at the Millwood Psychiatric Clinic -- a mental health retreat where his deceased father, renowned children\'s book author T.L. Pierson (Nick Nolte), was once interned. Riley finds an unlikely friend in Gabriel Finch (Ian McKellen), a disarming patient who forces him to examine himself. When Finch suggests that the fantastic land in Pierson\'s classic book "Neverwas" is real, Riley begins a spellbinding investigation into his father\'s work.',
#   'genre': ['drama', 'mystery & suspense'],
#   'critics_consensus': nan,
#   'content_rating': 'PG-13',
#   'audience_count': 4059.0},
#  '10006007-the_second_chance': {'name': 'The Second Chance',
#   'simplified_name': 'The Second Chance',
#   'description': "Two pastors, one from a wealthy parish in a predominantly white suburb, the other, the head of an inner-city church, must learn to bridge the gap between their different philosophies and their individual prejudices. Together they look for common ground through faith and fight to save one's struggling urban church and the people it serves.",
#   'genre': ['drama', 'faith & spirituality'],
#   'critics_consensus': nan,
#   'content_rating': 'PG-13',
#   'audience_count': 79542.0},
#  '10006057-moonlight': {'name': 'Moonlight',
#   'simplified_name': 'Moonlight',
#   'description': "Claire, a Dutch girl, discovers a wounded boy hiding in the garden shed behind her adoptive parents' luxurious home. The boy is a narcotics courier from Afghanistan, who was left for dead after being shot by drug dealers once his services were no longer needed. Claire nurses the boy back to health and develops deep feelings for him as their relationship grows. The drug dealers discover the boy is still alive, prompting Claire to leave her family and run away with the boy she now loves.",
#   'genre': ['drama', 'mystery & suspense'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 1430.0},
#  '1000617-aliens': {'name': 'Aliens',
#   'simplified_name': 'Aliens',
#   'description': "After floating in space for 57 years, Lt. Ripley's (Sigourney Weaver) shuttle is found by a deep space salvage team. Upon arriving at LV-426, the marines find only one survivor, a nine year old girl named Newt (Carrie Henn). But even these battle-hardened marines with all the latest weaponry are no match for the hundreds of aliens that have invaded the colony.",
#   'genre': ['horror', 'action & adventure', 'science fiction & fantasy'],
#   'critics_consensus': 'While Alien was a marvel of slow-building, atmospheric tension, Aliens packs a much more visceral punch, and features a typically strong performance from Sigourney Weaver.',
#   'content_rating': 'R',
#   'audience_count': 429674.0},
#  '10006188-rise': {'name': 'Rise: Blood Hunter',
#   'simplified_name': 'Rise',
#   'description': "Sadie (Lucy Liu), a reporter, investigates an underground cult in Los Angeles which seems to be responsible for a series of grisly murders. While trying to discover the cult's secrets, she becomes a victim herself. Sadie awakes in the morgue with an insatiable craving for blood and revenge, so she joins forces with a grieving detective (Michael Chiklis) to destroy the undead creatures once and for all.",
#   'genre': ['horror', 'mystery & suspense'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 8239.0},
#  '1000626-all_about_eve': {'name': 'All About Eve',
#   'simplified_name': 'All About Eve',
#   'description': 'Backstage story revolving around aspiring actress Eve Harrington. Tattered and forlorn, Eve shows up in the dressing room of Broadway mega-star Margo Channing, telling a melancholy life story to Margo and her friends. Margo takes Eve under her wing, and it appears that Eve is a conniver that uses Margo.',
#   'genre': ['drama', 'classics'],
#   'critics_consensus': 'Smart, sophisticated, and devastatingly funny, All About Eve is a Hollywood classic that only improves with age.',
#   'content_rating': 'PG',
#   'audience_count': 45248.0},
#  '10006270': {'name': 'When Do We Eat?',
#   'simplified_name': 'When Do We Eat',
#   'description': "Members of the Stuckman family gather for Seder with patriarch Ira (Michael Lerner), an old-fashioned man who pushes his sons as hard as his own father (Jack Klugman) pushed him. Chaos erupts when one of Ira's sons slips him a hit of Ecstasy, turning him into a modern Moses.",
#   'genre': ['comedy'],
#   'critics_consensus': 'A crass, sitcom-ish holiday comedy, When Do We Eat? presents all the over-the-top dysfunctional family hijinks one would expect from the genre.',
#   'content_rating': 'R',
#   'audience_count': 1121.0},
#  '10006324': {'name': 'The Mostly Unfabulous Social Life of Ethan Green',
#   'simplified_name': 'The Mostly Unfabulous Social Life of Ethan Green',
#   'description': "A young man named Ethan (Daniel Letterle) is head-over-heels in love with an ex-baseball player (Diego Serrano) who has just revealed in a new book that he is gay. Meanwhile, a former lover (David Monahan) plots to sell Ethan's house, prompting him to enlist the aid of a hot guy (Dean Shelton) and a real-estate agent (Rebecca Lowman) to prevent the sale from going through.",
#   'genre': ['drama', 'comedy'],
#   'critics_consensus': "Ethan Green makes for an annoying protagonist, the jokes aren't funny, and everyone is as flat as the paper the comic is printed on.",
#   'content_rating': 'R',
#   'audience_count': 2394.0},
#  '10006343-dirty': {'name': 'Dirty',
#   'simplified_name': 'Dirty',
#   'description': 'Armando Sancho (Clifton Collins Jr.) is a former Los Angeles gang member who has transitioned into law enforcement. Sancho, however, who is surrounded by corruption, finds that life as a police officer is just as morally bankrupt as life as a gangster. After being implicated in the shooting of an innocent man himself, Sancho is then pressured to testify against his loose-cannon friend and partner, Salim Adel (Cuba Gooding Jr.), who has a history of abusing citizens.',
#   'genre': ['drama'],
#   'critics_consensus': 'Dirty is an unoriginal L.A. cop drama that wears its tired influences on its sleeves.',
#   'content_rating': 'R',
#   'audience_count': 7326.0},
#  '10006370-stay_alive': {'name': 'Stay Alive',
#   'simplified_name': 'Stay Alive',
#   'description': "Teenagers decide to pass idle time by playing an online game that has a horror theme. But the action taking place on their computer screens becomes a terrifying reality when they realize that each time a character dies during the game, the figure's human overseer dies as well.",
#   'genre': ['horror', 'mystery & suspense'],
#   'critics_consensus': 'A by-the-numbers teen horror flick, Stay Alive fails to exploit its premise for any real scares.',
#   'content_rating': 'PG-13',
#   'audience_count': 113424.0},
#  '1000640-all_of_me': {'name': 'All of Me',
#   'simplified_name': 'All of Me',
#   'description': "While on her deathbed, the rich Edwina Cutwater (Lily Tomlin) has her lawyer Roger Cobb (Steve Martin) add the odd stipulation to her will that her soul will be inherited by the young Terry Hoskins (Victoria Tennant). The plan backfires when Edwina dies. She ends up inhabiting Roger's body and controlling only its right side. Edwina and Roger are forced to work together to find a way to get her soul out his body and into the body she originally intended.",
#   'genre': ['comedy', 'science fiction & fantasy'],
#   'critics_consensus': "A high-concept farce carried by Carl Reiner's deft direction and the precise timing of its leads, All of Me is a body-swap comedy worth holding onto.",
#   'content_rating': 'PG',
#   'audience_count': 14346.0},
#  '1000643-all_quiet_on_the_western_front': {'name': 'All Quiet on the Western Front',
#   'simplified_name': 'All Quiet on the Western Front',
#   'description': 'At the start of World War I, Paul Baumer (Richard Thomas) is a young German patriot, eager to fight. Indoctrinated with propaganda at school, he and his friends eagerly sign up for the army soon after graduation. But when the horrors of war soon become too much to bear, and as his friends die or become gravely wounded, Paul questions the sanity of fighting over a few hundreds yards of war-torn countryside. The film is based on the classic novel of the same name by Erich Maria Remarque.',
#   'genre': ['drama'],
#   'critics_consensus': nan,
#   'content_rating': 'NR',
#   'audience_count': 7588.0},
#  '10006434-dreamland': {'name': 'Dreamland',
#   'simplified_name': 'Dreamland',
#   'description': "Teenage Aubrey (Agnes Bruckner) is always there for everyone, including her father, Henry (John Corbett), who has not left the house since her mother died, and her friend Calista (Kelli Garner), who has multiple sclerosis. Her longing to experience life for herself begins to awaken, however, with the arrival of new neighbors, including a young man named Mookie (Justin Long). After setting Mookie up with Calista, Aubrey begins to feel jealous, but struggles to put her own needs above others'.",
#   'genre': ['drama', 'art house & international'],
#   'critics_consensus': nan,
#   'content_rating': 'PG-13',
#   'audience_count': 5650.0},
#  '10006485-black_gold': {'name': 'Independent Lens',
#   'simplified_name': 'Independent Lens',
#   'description': "Fifteen million Ethiopians make a living related to coffee, which accounts for 67 percent of the country's foreign exports. Yet as profits soar for coffee sales, the farmers producing the beans continue to receive minimal payments, anywhere from 12 to 25 cents for every kilo picked. Businessman Tadesse Meskela tries to help raise the impoverished standard of living by negotiating, on behalf of 70,000 farmers, with coffee roasters willing to pay a fairer price for their labor.",
#   'genre': ['documentary', 'special interest'],
#   'critics_consensus': 'Black Gold is an eye-opening account of the winners and losers in the global coffee trade.',
#   'content_rating': 'NR',
#   'audience_count': 1854.0},
#  '1000654-all_the_kings_men': {'name': "All the King's Men",
#   'simplified_name': "All the King's Men",
#   'description': 'Drama about the rise and fall of a corrupt southern governor who promises his way to power. Broderick Crawford portrays Willie Stark, who, once he is elected, finds that his vanity and power lust prove to be his downfall. The film is based on the 1946 Pulitzer Prize-winning novel by Robert Penn Warren.',
#   'genre': ['drama', 'classics'],
#   'critics_consensus': "Broderick Crawford is spellbinding as politician Willie Stark in director Robert Rossen's adaptation of the Robert Penn Warren novel about the corrosive effects of power on the human soul.",
#   'content_rating': 'PG',
#   'audience_count': 4866.0},
#  '10006588-street_fight': {'name': 'Street Fight',
#   'simplified_name': 'Street Fight',
#   'description': "Documentarian Marshall Curry chronicles the 2002 mayoral race in Newark, New Jersey. The election involves Sharpe James, who has held the seat for 16 years, and his challenger, attorney Cory Booker. Curry investigates the legality and ethics of the veteran mayor's tactics, and captures James' staff engaging in illicit behavior and threatening their competition with violence. James' vicious smear campaign is also documented. Spike Lee and Cornel West appear in the film on Booker's behalf.",
#   'genre': ['documentary', 'special interest'],
#   'critics_consensus': 'Street Fight takes an immersive ground-level look at a pivotal political race that proves illuminating, entertaining, and inspiring in equal measure.',
#   'content_rating': 'NR',
#   'audience_count': 2989.0},
#  '10006780-lost_horizon': {'name': 'Lost Horizon',
#   'simplified_name': 'Lost Horizon',
#   'description': 'An airplane hijacking leaves a diplomat (Peter Finch) and other Westerners in the Tibetan utopia Shangri-La.',
#   'genre': ['drama',
#    'action & adventure',
#    'musical & performing arts',
#    'science fiction & fantasy'],
#   'critics_consensus': nan,
#   'content_rating': 'G',
#   'audience_count': 455.0},
#  '10006848-the_motel': {'name': 'The Motel',
#   'simplified_name': 'The Motel',
#   'description': "While shouldering the burden of cleaning his family's sleazy motor inn, 13-year-old Ernest (Jeffrey Chyau) dreams of being a writer. A ne'er-do-well named Sam (Sung Kang) arrives for a night but stays longer, and the fatherless boy sees in him a male figure to emulate.",
#   'genre': ['drama', 'comedy'],
#   'critics_consensus': 'A coming-of-age dramedy whose familiar outline is filled in with rewarding empathy and character detail, The Motel marks an impressive feature debut for writer-director Michael Kang.',
#   'content_rating': 'NR',
#   'audience_count': 4038.0},
#  '10006849-once_in_a_lifetime': {'name': 'Once in a Lifetime: The Extraordinary Story of the New York Cosmos',
#   'simplified_name': 'Once in a Lifetime',
#   'description': "This documentary looks back on a time when soccer briefly captured America's attention. The film profiles the North American Soccer League franchise the New York Cosmos and the sensation it created back in the 1970s. Using archival footage, old photos and anecdotes from former players and businessmen, it tells the story -- or several conflicting stories -- of a team starring Brazilian soccer legend Pele, formed by non-sports people and ultimately submarined by the league's excessive expansion.",
#   'genre': ['documentary', 'sports & fitness'],
#   'critics_consensus': "You don't have to be a soccer fan to enjoy this stylish, breezy slice of 1970s sports history.",
#   'content_rating': 'PG-13',
#   'audience_count': 1416.0},
#  '10006856-requiem': {'name': 'Requiem',
#   'simplified_name': 'Requiem',
#   'description': 'Michaela, an epileptic, enrolls in college to study education. She goes off her medication and soon begins hearing voices and seeing apparitions that tell her to avoid religious objects, although she is devoutly Roman Catholic. One priest scoffs at the idea that Michaela could be possessed by demons, but a younger pastor arranges an exorcism for the young woman.',
#   'genre': ['drama',
#    'horror',
#    'art house & international',
#    'mystery & suspense'],
#   'critics_consensus': "This harrowing, naturalistic drama holds you in its grip through Huller's intense performance.",
#   'content_rating': 'NR',
#   'audience_count': 4728.0},
#  '10006940-silk': {'name': 'Gui si (Silk)',
#   'simplified_name': 'Gui si (Silk)',
#   'description': "Aiming to harness the energy found in some supernatural spirits, scientist Hashimoto (Yosuke Eguchi) and colleagues catch the ghost of a young boy. Hashimoto plans to use the energy to fuel an anti-gravity device he's invented. But, in order to tap into the ghost's essence, he must understand the silent words coming from its mouth. The scientists call in police officer Tung (Chen Chang), who can read lips, but, as they learn that the boy was murdered, the experiment goes in a scary direction.",
#   'genre': ['horror', 'art house & international', 'mystery & suspense'],
#   'critics_consensus': nan,
#   'content_rating': 'PG-13',
#   'audience_count': 2531.0},
#  '10007139-park': {'name': 'Park',
#   'simplified_name': 'Park',
# ...
#   'critics_consensus': 'Exhilarating and intense, this high-impact chase thriller is a model of taut and efficient formula filmmaking, and it features Harrison Ford at his frantic best.',
#   'content_rating': 'PG-13',
#   'audience_count': 267812.0},
#  '1046151-fearless': {'name': 'Fearless',
#   'simplified_name': 'Fearless',
#   'description': 'When Max Klein (Jeff Bridges) survives a plane crash that kills many others, his last-minute epiphanies bring him a sense of invulnerability, leading to radical behavior. Instead of contacting his wife (Isabella Rossellini) after the crash, he sets off on a trip to see his old girlfriend, eats foods he was allergic to previously, and is strangely unafraid to fly again. Can a psychologist (John Turturro) and a fellow guilt-ridden survivor (Rosie Perez) help bring him down to earth?',
#   'genre': ['drama'],
#   'critics_consensus': 'This underrated gem from director Peter Weir features an outstanding performance from Jeff Bridges as a man dealing with profound grief.',
#   'content_rating': 'R',
#   'audience_count': 12368.0},
#  '1046180-trauma': {'name': "Trauma (Dario Argento's Trauma)",
#   'simplified_name': "Trauma (Dario Argento's Trauma)",
#   'description': 'Two mixed-up young lovers (Christopher Rydell, Asia Argento) try to hunt down a decapitator called Head Hunter by the media.',
#   'genre': ['horror', 'mystery & suspense'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 4026.0},
#  '1046227-cool_runnings': {'name': 'Cool Runnings',
#   'simplified_name': 'Cool Runnings',
#   'description': 'Four Jamaican bobsledders dream of competing in the Winter Olympics, despite never having seen snow. With the help of a disgraced former champion desperate to redeem himself, the Jamaicans set out to become worthy of Olympic selection, and go all out for glory.',
#   'genre': ['comedy'],
#   'critics_consensus': 'Cool Runnings rises above its formulaic sports-movie themes with charming performances, light humor, and uplifting tone.',
#   'content_rating': 'PG',
#   'audience_count': 532977.0},
#  '1046655-skin_game': {'name': 'The Skin Game',
#   'simplified_name': 'The Skin Game',
#   'description': "An English aristocrat's wife (Helen Haye) blackmails a progressive (Edmund Gwenn) over a land deal.",
#   'genre': ['drama', 'comedy', 'classics'],
#   'critics_consensus': nan,
#   'content_rating': 'NR',
#   'audience_count': 345.0},
#  '1046723-man_who_loved_women': {'name': 'The Man Who Loved Women',
#   'simplified_name': 'The Man Who Loved Women',
#   'description': 'A psychiatrist (Julie Andrews) recalls the fate of her late patient, a sculptor (Burt Reynolds) infatuated with women.',
#   'genre': ['comedy', 'romance'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 1591.0},
#  '1046724-impact': {'name': 'Impact',
#   'simplified_name': 'Impact',
#   'description': 'A declared-dead man (Brian Donlevy) hides out with a widow (Ella Raines) after his wife and her lover botch his murder.',
#   'genre': ['drama', 'classics', 'mystery & suspense'],
#   'critics_consensus': nan,
#   'content_rating': 'NR',
#   'audience_count': 700.0},
#  '1046771-into_the_west': {'name': 'Into the West',
#   'simplified_name': 'Into the West',
#   'description': 'Impoverished in Dublin, youngsters Ossie (Ciaran Fitzgerald) and Tito (Ruaidhri Conroy) live with their widowed father (Gabriel Byrne), who drowns his grief in drink. Their grim existence is uplifted by the arrival of their itinerant grandfather (David Kelly), who has brought with him a magical horse from legend -- Tir na nOg. But when crooked cops discover the prized animal, they commandeer it, intending to sell it as a racing horse. Furious, the boys resolve to rescue the mythical creature.',
#   'genre': ['drama',
#    'action & adventure',
#    'kids & family',
#    'science fiction & fantasy'],
#   'critics_consensus': nan,
#   'content_rating': 'PG',
#   'audience_count': 4348.0},
#  '1046772-three_musketeers': {'name': 'The Three Musketeers',
#   'simplified_name': 'The Three Musketeers',
#   'description': "D'Artagnan (Chris O'Donnell) travels to Paris hoping to become a musketeer, one of the French king's elite bodyguards, only to discover that the corps has been disbanded by conniving Cardinal Richelieu (Tim Curry), who secretly hopes to usurp the throne. Fortunately, Athos (Kiefer Sutherland), Porthos (Oliver Platt) and Aramis (Charlie Sheen) have refused to lay down their weapons and continue to protect their king. D'Artagnan joins with the rogues to expose Richelieu's plot against the crown.",
#   'genre': ['action & adventure', 'comedy', 'kids & family', 'romance'],
#   'critics_consensus': 'Its starry trio of do-gooders may promise to fight "one for all, all for one," but this Three Musketeers is a slickly unmemorable update bound to satisfy very few.',
#   'content_rating': 'PG',
#   'audience_count': 169772.0},
#  '1046873-alice_in_wonderland': {'name': 'Alice in Wonderland',
#   'simplified_name': 'Alice in Wonderland',
#   'description': "Lewis Carroll's young heroine (Tina Majorino) explores a fantasy land of odd characters (Whoopi Goldberg, Martin Short) and notions.",
#   'genre': ['action & adventure', 'comedy', 'kids & family', 'television'],
#   'critics_consensus': nan,
#   'content_rating': 'G',
#   'audience_count': 24497.0},
#  '1047550-scared_stiff': {'name': 'Scared Stiff',
#   'simplified_name': 'Scared Stiff',
#   'description': 'Accident-prone busboy Myron Mertz (Jerry Lewis) and his suave nightclub-crooner pal, Larry Todd (Dean Martin), get caught up in both a gangland slaying and a mystery involving the comely Mary Carroll (Lizabeth Scott). She has just inherited an island castle off the coast of Cuba that her lawyer, Cortega (George Dolenz), insists is overrun with ghosts and zombies. Attempting to save Mary from a mysterious stranger who wants her dead, Myron and Larry sail with her to Cuba.',
#   'genre': ['mystery & suspense', 'comedy', 'classics'],
#   'critics_consensus': nan,
#   'content_rating': 'NR',
#   'audience_count': 2512.0},
#  '1047928-gunmen': {'name': 'Gunmen',
#   'simplified_name': 'Gunmen',
#   'description': 'A New York agent (Mario Van Peebles) with the DEA breaks an outlaw (Christopher Lambert) from jail to lead him to stolen money in South America.',
#   'genre': ['action & adventure'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 2103.0},
#  '1047940-dangerous_game': {'name': 'Dangerous Game',
#   'simplified_name': 'Dangerous Game',
#   'description': "As his marriage rapidly deteriorates, respected New York City director Eddie Israel (Harvey Keitel) leaves his family on the East Coast and journeys to Los Angeles to make a film about a decadent husband and wife in a souring relationship. But Israel begins a love-hate affair with leading lady Sarah Jennings (Madonna), who's also sleeping with starring actor Francis Burns (James Russo). Amidst the drugs, alcohol, tears and promiscuity, reality and filmmaking become dangerously intermingled.",
#   'genre': ['drama'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 2561.0},
#  '1047985-getaway': {'name': 'The Getaway',
#   'simplified_name': 'The Getaway',
#   'description': "Doc (Alec Baldwin) and Carol (Kim Basinger) McCoy are married criminals looking for a high-paying score. When Doc ends up in a Mexican prison, Carol tells mob boss Jack Benyon (James Woods) that Doc will work for him if Benyon can free him from prison. Benyon hires Doc to rob a dog track, but after the heist goes terribly wrong, Doc and Carol escape with the cash. With a bitter thief (Michael Madsen) and Benyon's hired help on their trail, Doc and Carol must fight to survive.",
#   'genre': ['drama', 'action & adventure', 'mystery & suspense'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 8800.0},
#  '1048301-angels_in_the_outfield': {'name': 'Angels in the Outfield',
#   'simplified_name': 'Angels in the Outfield',
#   'description': "A newspaper reporter, Jennifer Paige (Janet Leigh), is investigating the Pittsburgh Pirates' losing streak. The team is led by manager Guffy McGovern (Paul Douglas), whose swearing and fighting hinder his team's progress. Meanwhile, an orphan named Bridget White (Donna Corcoran) has been praying for the team, and her pleas are answered by an angelic voice. The angel begins urging Guffy to be kinder in return for helping the Pirates win, but the playoffs test the manager's temper.",
#   'genre': ['comedy', 'classics', 'science fiction & fantasy'],
#   'critics_consensus': nan,
#   'content_rating': 'NR',
#   'audience_count': 9425.0},
#  '1048333-heaven_and_earth': {'name': 'Heaven & Earth',
#   'simplified_name': 'Heaven & Earth',
#   'description': 'Le Ly (Hiep Thi Le) lives in a small Vietnamese village whose serenity is shattered when war breaks out. Caught between the Viet Cong and the South Vietnamese army, the village is all but destroyed. After being both brutalized and raped, Le Ly resolves to flee. She leaves for the city, surviving desperate situations, but surviving nonetheless. Eventually she meets a U.S. Marine named Steve Butler (Tommy Lee Jones) who treats her kindly and tells her he would like to be married -- maybe to her.',
#   'genre': ['drama'],
#   'critics_consensus': "Heaven & Earth is a well-intentioned glimpse into an underrepresented perspective on Vietnam, but Oliver Stone's solemn storytelling keeps audiences at a fatal distance from Hiep Thi Le's enigmatic heroine.",
#   'content_rating': 'R',
#   'audience_count': 5512.0},
#  '1048445-snow_white_and_the_seven_dwarfs': {'name': 'Snow White and the Seven Dwarfs',
#   'simplified_name': 'Snow White and the Seven Dwarfs',
#   'description': "The Grimm fairy tale gets a Technicolor treatment in Disney's first animated feature. Jealous of Snow White's beauty, the wicked queen orders the murder of her innocent stepdaughter, but later discovers that Snow White is still alive and hiding in a cottage with seven friendly little miners. Disguising herself as a hag, the queen brings a poisoned apple to Snow White, who falls into a death-like sleep that can be broken only by a kiss from the prince.",
#   'genre': ['kids & family',
#    'animation',
#    'classics',
#    'science fiction & fantasy'],
#   'critics_consensus': 'With its involving story and characters, vibrant art, and memorable songs, Snow White and the Seven Dwarfs set the animation standard for decades to come.',
#   'content_rating': 'G',
#   'audience_count': 470351.0},
#  '1048585-sugar_hill': {'name': 'Sugar Hill',
#   'simplified_name': 'Sugar Hill',
#   'description': "Roemello Skuggs (Wesley Snipes) and his brother, Raynathan (Michael Wright), grew up surrounded by crime. As an adult, Roemello becomes a high-ranking drug dealer. Roemello's girlfriend, Melissa (Theresa Randle), however, does not approve of his lifestyle, and, after some violent altercations, Roemello begins questioning his choices also. Roemello and Melissa decide to start over in North Carolina, but Raynathan does everything he can to keep his brother from leaving.",
#   'genre': ['drama', 'mystery & suspense'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 6711.0},
#  '1048880-thumbelina': {'name': 'Thumbelina',
#   'simplified_name': 'Thumbelina',
#   'description': "Born of a flower and growing to only a couple of inches tall, poor Thumbelina (Jodi Benson) is worried she'll never meet someone her own size, until she happens to catch the eye of Prince Cornelius of the Fairies (Gary Imhoff). Just as soon as she finds love, however, it's torn away from her when she is kidnapped by Ms. Toad (Charo). Now Thumbelina has to escape Ms. Toad's grasp and search for Prince Cornelius. Luckily, there's a whole city of animals willing to help her.",
#   'genre': ['kids & family', 'animation'],
#   'critics_consensus': nan,
#   'content_rating': 'G',
#   'audience_count': 60052.0},
#  '1049512-young_americans': {'name': 'The Young Americans',
#   'simplified_name': 'The Young Americans',
#   'description': "New York City drug enforcement officer John Harris (Harvey Keitel) travels to London to help ineffective local policemen battle a powerful drug cartel. Harris needs to put behind bars American ex-pat Carl Frazer (Viggo Mortensen), who recruits rebellious young teens as foot soldiers in his enterprise. With help from British officer Edward Foster (Iain Glen), Harris must navigate London's seedy, drug-fueled underworld in order to take down Frazer's criminal operation.",
#   'genre': ['drama', 'action & adventure', 'mystery & suspense'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 797.0},
#  '1049883-alice': {'name': 'Alice (Neco z Alenky)',
#   'simplified_name': 'Alice (Neco z Alenky)',
#   'description': "In Czech director Jan Svankmajer's surreal adaptation of Lewis Carroll's classic children's book, Alice (Kristyna Kohoutova) follows her stuffed rabbit through a portal inside her dresser to be whisked away to Wonderland. While the White Rabbit, Mad Hatter and Cheshire Cat are still present, the familiar magical world and bizarre characters have undergone an unsettling transformation in the director's vision through the stop-motion animation of dead animals, puppets and other assorted objects.",
#   'genre': ['horror',
#    'animation',
#    'art house & international',
#    'special interest',
#    'science fiction & fantasy'],
#   'critics_consensus': nan,
#   'content_rating': 'NR',
#   'audience_count': 11937.0},
#  '1050388-last_man_on_earth': {'name': 'The Last Man on Earth',
#   'simplified_name': 'The Last Man on Earth',
#   'description': 'The survivor (Vincent Price) of a global epidemic battles a race of zombie vampires in an adaptation of Richard Matheson\'s "I Am Legend."',
#   'genre': ['drama', 'horror', 'science fiction & fantasy'],
#   'critics_consensus': nan,
#   'content_rating': 'NR',
#   'audience_count': 11612.0},
#  '1050454-1050454-shermans_march': {'name': "Sherman's March",
#   'simplified_name': "Sherman's March",
#   'description': "Documentarian Ross McElwee originally set out to make a travelogue of sorts tracing General William T. Sherman's infamous scorched-earth march through the Confederacy in the latter stages of the Civil War. Instead, haunted by a recent breakup with a girlfriend, McElwee ends up documenting his progress -- or lack thereof -- in starting a new relationship. His journey then becomes one of self-reflection and self-discovery rather than a historical/sociological exploration.",
#   'genre': ['documentary', 'special interest'],
#   'critics_consensus': nan,
#   'content_rating': 'NR',
#   'audience_count': 1276.0},
#  '1051219-bad_girls': {'name': 'Bad Girls',
#   'simplified_name': 'Bad Girls',
#   'description': "Prostitutes Cody (Madeleine Stowe), Anita (Mary Stuart Masterson), Eileen (Andie MacDowell) and Lily (Drew Barrymore), work a saloon in the Old West. They decide to flee the bordello for a better life elsewhere, but trouble follows close behind. They're tailed by Pinkerton detectives, Cody's savings are stolen by a bandit (James Russo), and Eileen is wrongfully jailed for bank robbery. Now the remaining three girls must decide whether to liberate their friend or their funds first.",
#   'genre': ['western', 'action & adventure'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 50675.0},
#  '1052200-dream_lover': {'name': 'Dream Lover',
#   'simplified_name': 'Dream Lover',
#   'description': 'Not long after they cross paths at an art gallery, Ray Reardon (James Spader), an architect, and hypnotically sensual Lena (Madchen Amick) are married with children. Only then does Ray catch his wife in escalating lies, which lead him to find out that Lena\'s past is invented and that she has been manipulating him ever since their first "chance" meeting. In the ensuing turmoil, Lena ends up with Ray\'s money, and he winds up in an institution -- from which he plots his return and revenge.',
#   'genre': ['drama', 'mystery & suspense'],
#   'critics_consensus': nan,
#   'content_rating': 'R',
#   'audience_count': 928.0},
#  ...}

# %% [markdown]
# ### Basic cleaning, filtering, lemmatization

# %%
stop_words = stopwords.words('english')
stop_words.extend(STOPWORDS)
stop_words.extend('lot')

lemmatizer = WordNetLemmatizer()

"""
Cleans the description string
Returns: string of cleaned description in lower case
"""
def clean_description(description):
    description = re.sub('[^A-Za-z0-9\-\']+', ' ', description)
    description = description.replace('--', '-')
    description = ''.join(description)
    return description.lower()

"""
Lemmatizes and filters given description string
Returns: tokenized list of filtered words
"""
def lemmatize_and_filter(description):
    tokenized = description.split()
    lemmatized_lst = [lemmatizer.lemmatize(w) for w in tokenized]
    filtered = list(filter(lambda x: x not in stop_words, lemmatized_lst))
    return filtered

"""
Extracts all 2-word keyphrases from a list of tokenized words in the form of noun-adj
Returns: the set of noun-adj keyphrases
"""
def create_noun_adj_list(word_lst):
    lemmatized_lst = [lemmatizer.lemmatize(w) for w in word_lst]
    pos = nltk.pos_tag(lemmatized_lst)
    noun_adj_set = set()
    for i in range(len(pos) - 1):
        if (pos[i][1] == 'JJ' and pos[i+1][1] == 'NN'):
            noun_adj_phrase = ' '.join([pos[i][0], pos[i+1][0]])
            noun_adj_set.add(noun_adj_phrase)
    return noun_adj_set

# %% [markdown]
# ### Extraction functions for other libraries
# - Yake
# - Rake
# - Gensim

# %%
"""
Extracts keywords and phrases using YAKE library
"""
def yake_extraction(description):       
    language = "en"
    deduplication_threshold = 0.9

    custom_kw_extractor_3gram = yake.KeywordExtractor(lan=language, n=3,dedupLim=deduplication_threshold, 
                                                      top=5, features=None)
    custom_kw_extractor_2gram = yake.KeywordExtractor(lan=language, n=2,dedupLim=deduplication_threshold, 
                                                      top=5, features=None)
    custom_kw_extractor_single = yake.KeywordExtractor(lan=language, n=1,dedupLim=deduplication_threshold, 
                                                      top=10, features=None)
    
    keyphrase_3 = custom_kw_extractor_3gram.extract_keywords(description)
    keyphrase_2 = custom_kw_extractor_2gram.extract_keywords(description)
    keywords = custom_kw_extractor_single.extract_keywords(description)
    
    all_keywords = keyphrase_3 + keyphrase_2 + keywords
    all_keywords = sorted(all_keywords, key=lambda item:(item[1]))
    keywords_only = [x[0] for x in all_keywords]
    
    return set(keywords_only) 

"""
Extracts keywords and phrases using rake library
"""
def rake_extraction(description):
    rake_nltk_var = Rake()  
    rake_nltk_var.extract_keywords_from_text(description)  
    keyword_extracted = rake_nltk_var.get_ranked_phrases()
    return set(keyword_extracted)

"""
Extracts keywords and phrases using gensim summarize library
"""
def gensim_keyword_extraction(description):
    result = gensim.summarization.keywords(description, ratio=1, words=None, 
                                           split=False, scores=True, pos_filter=None, 
                                           lemmatize=True, deacc=True)
    keywords = [x[0] for x in result]
    return keywords

# %% [markdown]
# This example shows that the library extractor work better when description is not cleaned or filtered

# %%
ex = "Always trouble-prone, the life of teenager Percy Jackson (Logan Lerman) gets a lot more complicated when he learns he's the son of the Greek god Poseidon. At a training ground for the children of deities, Percy learns to harness his divine powers and prepare for the adventure of a lifetime: he must prevent a feud among the Olympians from erupting into a devastating war on Earth, and rescue his mother from the clutches of Hades, god of the underworld."
ex_cleaned = clean_description(ex)

# %%
print(gensim_keyword_extraction(ex))
print(rake_extraction(ex))
print(yake_extraction(ex))
# Out:
# ['percy', 'greek god', 'logan', 'jackson', 'training ground', 'trouble', 'devastating war', 'divine powers', 'lerman gets', 'hades', 'poseidon', 'teenager', 'deities', 'learns']
# {'prepare', 'son', 'lot', 'harness', 'erupting', 'life', 'devastating war', 'adventure', 'olympians', 'logan lerman', 'must prevent', 'teenager percy jackson', 'clutches', 'feud among', 'prone', 'lifetime', 'god', 'earth', 'underworld', 'hades', 'percy learns', 'always trouble', 'deities', 'learns', 'children', 'gets', 'greek god poseidon', 'mother', 'divine powers', 'rescue', 'training ground', 'complicated'}
# {'god', 'god poseidon', 'lerman', 'greek god', 'learns', 'teenager percy', 'logan lerman', 'greek god poseidon', 'greek', 'percy jackson', 'trouble-prone', 'teenager percy jackson', 'jackson', 'poseidon', 'life', 'logan', 'percy'}

# %%
print(gensim_keyword_extraction(ex_cleaned))
print(rake_extraction(ex_cleaned))
print(yake_extraction(ex_cleaned))
# Out:
# ['teenager percy jackson logan lerman gets', 'greek god poseidon', 'trouble', 'devastating war', 'divine powers', 'training ground', 'hades', 'learns', 'deities']
# {'prepare', 'son', 'lot', 'harness', 'erupting', 'teenager percy jackson logan lerman gets', 'life', 'devastating war', 'adventure', 'olympians', 'must prevent', 'clutches', 'feud among', 'prone', 'lifetime', 'earth', 'deities percy learns', 'hades god', 'underworld', 'always trouble', 'learns', 'children', 'greek god poseidon', 'mother', 'divine powers', 'rescue', 'training ground', 'complicated'}
# {'lerman', 'jackson', 'life', 'teenager', 'devastating war', 'logan', 'logan lerman', 'teenager percy jackson', 'god', 'deities percy learns', 'trouble-prone', 'underworld', 'percy', 'learns', 'greek god poseidon', 'jackson logan lerman', 'divine powers', 'training ground', 'jackson logan', 'percy jackson logan'}

# %% [markdown]
# ### Extract keywords
# - Uses combined results from of Yake, Rake and Gensim extractions

# %%
def create_movie_tf_idf(movie_id_list):
    tf = dict()
    idf = dict()
    for movie in movie_id_list:
        raw_desc = movie_id_to_info[movie]['description']
        if not type(raw_desc) == str:
            continue
        description = clean_description(raw_desc)
        filtered_lst = lemmatize_and_filter(description)
        filtered_desc = ' '.join(filtered_lst)
        
        # noun_adj_keyphrase = create_noun_adj_list(filtered_lst)
        yake_keywords = yake_extraction(raw_desc)
        rake_keywords = rake_extraction(raw_desc)
        gensim_keyword = gensim_keyword_extraction(raw_desc)
        
        all_keywords = yake_keywords.union(rake_keywords).union(gensim_keyword)
                
        for word in all_keywords:
            if len(word.split()) <= 4 and not set(word.split()).intersection(stop_words):
#                 word = re.sub('[^A-Za-z0-9\-_&$\']+', ' ', word)
                lst = list(filter(lambda x: (len(x) > 2), word.split())) 
                word = ' '.join(lst)
                if len(re.sub('[^A-Za-z]+', '', word)) > 2:
                    tf.setdefault(movie, []).append(word)
                    idf.setdefault(word,[]).append(movie)  
                
    return tf, idf

# %%
all_movies = ranked_movies_lst
top_5000_movies = ranked_movies_lst[:5000]
top_500_movies = ranked_movies_lst[:500]

movie_tf, movie_idf = create_movie_tf_idf(all_movies)

# %%
sorted(movie_idf.keys(), key = lambda item:(len(item.split())), reverse = True)
# Out:
# ['reigning world heavyweight champion',
#  'nfl coach nate scarborough',
#  'island theme park populated',
#  'ferocious predators break free',
#  'angers junior crime lord',
#  'supernatural playboy exuding charm',
#  'day strange phenomena surface',
#  'means braving giant bugs',
#  'magical board game unleashes',
#  'themed game called jumanji',
#  'town called radiator springs',
#  'fbi agent carl hanratty',
#  'eating tiger shere khan',
#  'dade detectives mike lowrey',
#  'game writer roger meet',
#  'skunk kit named flower',
#  'young rabbit named thumper',
#  'young doe named faline',
#  'fawn named bambi joins',
#  'superhero adventure finds batman',
#  'rescues explorer ursula stanhope',
#  'gentle farmer arthur hoggett',
#  'motherly border collie fly',
#  'seven friendly little miners',
#  'grimm fairy tale gets',
#  'deep space salvage team',
#  'year old girl named',
#  'eyed tribeswoman named evolet',
#  'roald dahl work tells',
#  'image adorns magazine covers',
#  'grace strips randy daytona',
#  'fbi chemical warfare expert',
#  'cannon enforcer nicky santoro',
#  'children stay perpetually young',
#  'sensitive artist patience philips',
#  'amiable rooster called alan',
#  'company leads street cop',
#  'master criminal neil mccauley',
#  'english orphan tristan meets',
#  'worldwide civil war looms',
#  'dying native american tribe',
#  'peace alongside british colonists',
#  'slacker friends joe cooper',
#  'park ranger terry carmichael',
#  'supersoldier called captain america',
#  'spirits turn unexpectedly menacing',
#  'carol ann goes missing',
#  'fiery molten rock runs',
#  'bounty hunter jonah hex',
#  'private detective tom welles',
#  'mafia flunky joey gazelle',
#  'cruel family adopts amanda',
#  'street punk named kong',
#  'crime boss called surat',
#  'seemingly connected deaths occur',
#  'homicide detective nick curran',
#  'beautiful young woman catches',
#  'disney adventure follows disfigured',
#  'new york city underworld',
#  'shifty gangster benny blanco',
#  'fellow brothel workers post',
#  'loan sharks come calling',
#  'airline owner tom mullen',
#  'ransom drop goes awry',
#  'complex sociological themes run',
#  'glowing nose saves christmas',
#  'personal issues soon rise',
#  'fonda casts considerable doubt',
#  'guilty verdict meaning death',
#  'criminals including serial killer',
#  'deadly monsters hunt members',
#  'march sisters confront growing',
#  'rich socialite julia sturges',
#  'cell phone goes dead',
#  'accidentally reaches college student',
#  'drug kingpin frank colton',
#  'moses accidentally shoots carter',
#  'undercover police officer named',
#  'similarly dispirited julian noble',
#  'saving medicine located hundreds',
#  'life medicine located hundreds',
#  'deadly diphtheria epidemic strikes',
#  'small girl musicians determined',
#  'town girl musicians determined',
#  'joel hires gorgeous lana',
#  'days high school senior',
#  'prostitute goes slightly awry',
#  'italian director franco zeffirelli',
#  'pretty socialite emma woodhouse',
#  'cutthroat local big shot',
#  'gibson undergoes suspended animation',
#  'test pilot daniel mccormick',
#  'starts dumping toxic waste',
#  'spurned bluto kidnaps olive',
#  'broadway trades sexual favors',
#  'new accountant leo bloom',
#  'commons member william wilberforce',
#  'includes brilliant eddie kasalivich',
#  'end job stocking shelves',
#  'dead job stocking shelves',
#  'wall street trader john',
#  'art gallery assistant elizabeth',
#  'western lawman wyatt earp',
#  'sandbagged new york soprano',
#  'best friend gets left',
#  'rescues cheerleader cindy mancini',
#  'tip waitress yvonne biasi',
#  'attempted carjacking goes awry',
#  'advertising executive nick beame',
#  'harriet records suspicious activity',
#  'rugby team respond differently',
#  'available food stuffs run',
#  'hamilton diligently treats cases',
#  'vermont aging book editor',
#  'shady businessman named sanderson',
#  'begins obsessively tracking rayburn',
#  'jock superstar howard stern',
#  'quinlan experience car trouble',
#  'federal agent susan verner',
#  'local doctor alan chaffee',
#  'new job working security',
#  'cia agent joshua foss',
#  'aging outlaw pike bishop',
#  'remaining gang takes refuge',
#  'scheming brother prince john',
#  'escaped richard returns covertly',
#  'impress beautiful student stella',
#  'literal witch hunt gets',
#  'married man john proctor',
#  'felix drives oscar crazy',
#  'stephen king tales follow',
#  '1950s manhattan department store',
#  'apolitical black south african',
#  'stages daring solo attacks',
#  'furious director tells executive',
#  'sellers unwittingly triggers explosives',
#  'bakshi instead mistakenly receives',
#  'legendary lighting mcqueen finds',
#  'insurance agent tim lippe',
#  'apolitical havana club owner',
#  'unusually skilled painting based',
#  'local criminal frank miller',
#  'earthly desires immediately fulfilled',
#  'meets agent annabella smith',
#  'international spy ring related',
#  'school counselor bob wolverton',
#  'little red riding hood',
#  'old boys named zachary',
#  'callous senior officer orders',
#  'bad boy musician cliff',
#  'single mom yoshimi matsubara',
#  'moody japanese horror film',
#  'start seeing unsettling visions',
#  'recently executed rival mobsters',
#  'treehouse creating comic books',
#  'mischievous boys accidentally hypnotize',
#  'petty thief chris dubois',
#  'outbound freight ship leaving',
#  'district attorney kathryn murphy',
#  'defense secretary david brice',
#  'meets pretty single mother',
#  'magician assistant falls prey',
#  'opera holds christine captive',
#  'boyfriend mercenary combat specialist',
#  'helps save injured passengers',
#  'handsome vagrant john bubber',
#  'serial swindler bernie laplante',
#  'barney unexpectedly confronts jeff',
#  'fbi agent zeke kelso',
#  'quiet suburban massachusetts town',
#  'hollywood songwriter falls hopelessly',
#  'bored young men living',
#  'loudmouth cab driver brunhilde',
#  'art scholars conducting research',
#  'single mother claudia larson',
#  'handsome friend leo fish',
#  'mccarthy mutant fish near',
#  'czech director jan svankmajer',
#  'powerful lobbyist jack abramoff',
#  'business partner michael scanlon',
#  'tidy profit reselling items',
#  'cynical circus owner gus',
#  'behavioral researcher margaret heller',
#  'hefty donations flow freely',
#  'high school girls turn',
#  'prosecuting lawyer adam bonner',
#  'scathing war satire follows',
#  'christmas eve gathering decides',
#  'events signals trouble ahead',
#  'lee sees mafia gangster',
#  'honest policeman mace ryan',
#  'longtime friend illinois gordon',
#  'mafia boss lucky luciano',
#  'strange woman named beloved',
#  'meets devastating femme fatale',
#  'itinerant troublemaker frank chambers',
#  'profile 1980s criminal trial',
#  'professional clown david friedman',
#  'filmmaker andrew jarecki learned',
#  'loved deputy buddy deeds',
#  'guerrilla production crew invade',
#  'angel begins urging guffy',
#  'orphan named bridget white',
#  'global money laundering scheme',
#  'large bribe wade offers',
#  'hired gun tim strawn',
#  'handsome bandit clay boone',
#  'new recruit ace jefferson',
#  'deadly autonomous mobile swords',
#  'attractive young couple gets',
#  'car thief grover muldoon',
#  'true villains kidnap hilly',
#  'ride overworked book editor',
#  'steal secret government information',
#  'filmmaker matthew heineman examines',
#  'company man daniel miller',
#  'rescue comes franklin laszlo',
#  'american ballet dancer working',
#  'dance sensation linda keene',
#  'heist goes terribly wrong',
#  'doctor offer differing explanations',
#  'drug kingpin julio gonzales',
#  'chicago police detectives hot',
#  'cracking politically incorrect jokes',
#  'life cult comedy focuses',
#  'day cult comedy focuses',
#  'intelligent investment banker struggling',
#  'film fake mission footage',
#  'winning screenwriter steven peros',
#  'aged roadside diner owner',
#  'local prosecutor kyle sackett',
#  'walker returns years later',
#  'perform everyday menial duties',
#  'local rich girl josie',
#  'budget filmmaker lawrence woolsey',
#  'cuban missile crisis occurs',
#  'night experiencing small crises',
#  'london society girl orphaned',
#  'clumsy high wire escapades',
#  'currency collector william hannigan',
#  'car crash leaves wife',
#  'fiction scribe john henderson',
#  'young man named mookie',
#  'triple indemnity life insurance',
#  'misogynistic jonathan finally tries',
#  'marine named steve butler',
#  'roguish gambler gaylord ravenal',
#  'execution date draws closer',
#  'newly formed greek empire',
#  'kind movie theater owner',
#  'scotland yard detective sgt',
#  'australia apartment complex look',
#  'lost demo tape led',
#  'long demo tape led',
#  'lifelong friends roy darpinian',
#  'corrupt police inspector chun',
#  'british authorities know chun',
#  'powerful law enforcement officer',
#  'store manager frank doel',
#  'british privateer geoffrey thorpe',
#  'soon begins hearing voices',
#  'killer terrorizing local blond',
#  'somewhat callow white musician',
#  'new star rebelliously elopes',
#  'hearted agent herbie sommers',
#  'multiple fishing lines hooks',
#  'himalayas seeking inner peace',
#  'issues addressed include secrecy',
#  'decapitator called head hunter',
#  'vicious staff sergeant williams',
#  'including sergeant major roberts',
#  'merciless crime boss losado',
#  'mysterious cellphone signal transforms',
#  'small south american town',
#  'strangely mutated wildlife roaming',
#  'nearby native american tribe',
#  'jewish soldier stan shutzer',
#  'arthur faces relationship problems',
#  'military man ralph partridge',
#  'vampiric doctoral student tries',
#  'easily extractable oil reserves',
#  'simpson searches new york',
#  'fashion model samantha simpson',
#  'election involves sharpe james',
#  'documentarian marshall curry chronicles',
#  'flight transporting dangerous convicts',
#  'flight attendant teri halloran',
#  'drinking novelist zach hutton',
#  'clients start dying mysteriously',
#  'leading lady sarah jennings',
#  'starring actor francis burns',
#  'meets police cadet tony',
#  'precocious high school senior',
#  'romantic sparks soon fly',
#  'prone busboy myron mertz',
#  'young man named ethan',
#  'eventually meets james jarvis',
#  'growing real estate speculation',
#  'samson suddenly acquires god',
#  'british pirate william kidd',
#  'franciscan monk brother juniper',
#  'businessman tadesse meskela tries',
#  'instant noodles sitting outside',
#  'singer celine dion performs',
#  'opening act tom caltabiano',
#  'ieuan feels deep regret',
#  'soccer briefly captured america',
#  'talented young physics student',
#  'war veteran major pollack',
#  'corners daily life proceeds',
#  'sorts tracing general william',
#  'animals begin inexplicably dying',
#  'befriends beautiful concubine shireen',
#  'treacherous transatlantic mission near',
#  'profoundly changed world cinema',
#  'french colonist annette cosway',
#  'alcohol makes irrational claims',
#  'old actress karen stone',
#  'celebrated author mark twain',
#  'titanic etch deep scars',
#  'cowboy movie star nevada',
#  'byck presents possible solutions',
#  'newly ordained catholic priest',
#  'financially strapped graduate student',
#  'successful selling fried morsels',
#  'city drug enforcement officer',
#  'british officer edward foster',
#  'recruits rebellious young teens',
#  'young gabriel drummond joins',
#  'beloved lady marian fitzwalter',
#  'quiet los angeles park',
#  'american hedge fund tries',
#  'case involving car theft',
#  'keeper named captain january',
#  'shipwrecked orphan girl growing',
#  'bitter truant officer believes',
#  'high school senior nikki',
#  'game hunter captain thorndike',
#  'corner feels tremendous pressure',
#  'connecticut prosecutor henry harvey',
#  'beautiful young carrie meeber',
#  'traveling salesman charles drouet',
#  'university alongside fellow beats',
#  'unnamed eastern european country',
#  'mike goldwing stows away',
#  'boxing manager nick donati',
#  'filmmaker brent hodge gives',
#  'world pianist receives transplanted',
#  'passionate suffragette gosh boyle',
#  'elusive bandit proves politically',
#  'texas marshal howard nightingale',
#  'guinea pig named darwin',
#  'painfully slow creatures called',
#  'space vortex sucks scientist',
#  'career woman joy mcnally',
#  'violent inexplicable deaths spreading',
#  'unknown prompting science teacher',
#  'terrifying phenomenon remains unknown',
#  'casino enforcer cole williams',
#  'unorthodox professor mickey rosa',
#  'concert violinist sydney wells',
#  'terrifying alternate world exists',
#  'ben sees ghostly images',
#  'special agent jennifer marsh',
#  'particularly sadistic criminal arises',
#  'scrappy street dogs delgado',
#  'struggling photographer leon kaufman',
#  'cia agent roger ferris',
#  'vale feels sufficiently sorry',
#  'dustin takes drastic measures',
#  'colombian drug lords turned',
#  'relatively quiet florida city',
#  'magazine editor sylvie fowler',
#  'clothing designer mary haines',
#  'malevolent rancher randall bragg',
#  'medical student ted grey',
#  '80s hair band vesuvius',
#  'pretty teen girl nell',
#  'iconic singer johnny favorite',
#  'frank begins digging tunnels',
#  'rescue party comes face',
#  'mockumentary cameras follow smyth',
#  'meets charming prostitute gulabji',
#  'wandering singer ranbir raj',
#  'collateral gains financial backing',
#  'chronic underachiever jerry ferro',
#  'recent college graduates travel',
#  'dysfunctional american food industry',
#  'generate sufficient humanitarian aid',
#  'guerrilla defends war criminals',
#  'prosperous real estate tycoon',
#  'filmmaker orson welles plunges',
#  'wedding plan despite numerous',
#  'spiritual adviser named sendak',
#  'san francisco pet store',
#  'game developer kevin flynn',
#  'strange signal draws sam',
#  'dying cardinal orders behman',
#  'pro bono case puts',
#  'gifted pitcher amanda whurlitzer',
#  'league hopeful morris buttermaker',
#  'recently disappeared family friend',
#  'private investigator philip marlowe',
#  'veteran officer tony stone',
#  'behavior gets increasingly wild',
#  'let nadia drink alcohol',
#  'friends begin going missing',
#  'virtuous doctor alec harvey',
#  'casual friendship soon develops',
#  'town bored suburban housewife',
#  'baron manfred von richthofen',
#  'faithful crew members embark',
#  'struggling songwriter albert peterson',
#  'school senior henry burke',
#  'beautiful cafe singer cherie',
#  'things head south quickly',
#  'times closeted sexual orientation',
#  'high school football game',
#  'married banker jack dundee',
#  'students ogling racy photos',
#  'cabaret performer lola lola',
#  'prim educator immanuel rath',
#  'size brute called kiss',
#  'unscrupulous millionaire sugar daddy',
#  'blimp pilot michael lander',
#  'israeli military agent kabakov',
#  'federal agent alexandra barnes',
#  'finds battered lucy burrows',
#  'chinese immigrant cheng huan',
#  'hotshot pitcher henry wiggen',
#  'confident ways quickly win',
#  'middle east region following',
#  'border patrol agent alongside',
#  'murder uncovering striking similarities',
#  'petr begins tutoring lada',
#  'massive legal case associated',
#  'director joe berlinger looks',
#  'private eye philip marlowe',
#  'noble birth wash ashore',
#  'apache territory seeking peace',
#  'retired sea captains zeb',
#  'portrait artist gaston morrell',
#  'department sends inexperienced agent',
#  'new york city attempting',
#  'writer humphrey van weyden',
#  'conservative blogger greg letiecq',
#  'misadventures involving armed soldiers',
#  'human rights legal advocate',
#  'chris mburu finishes elementary',
#  'amber helped richard secure',
#  'publicity man hank meyers',
#  'wilson wife falls victim',
#  'extraordinary son named sailboat',
#  'process strange events begin',
#  'affable canadian richard wehlner',
#  'ozark teenager ree dolly',
#  'decorated firefighter caleb holt',
#  'filmmaker thomas balmès criss',
#  'era englishman phileas fogg',
#  'news spreads like wildfire',
#  'steely french matriarch junon',
#  'jaa uses martial arts',
#  'perrineau encourages gladiatorial combat',
#  'rent crooks dennis farell',
#  'amazing martial arts skills',
#  'tickell explores alternate energy',
#  'massive wall street crash',
#  'famed alexei alexandrovitch karenin',
#  'soon beth goes missing',
#  'old demons come roaring',
#  'filmmaker kimberly reed left',
#  'financial officer jimmy stevens',
#  'rising matador david fandila',
#  'los angeles strip club',
#  'carroll beloved fantasy tale',
#  'restless young british girl',
#  'psychic oda mae brown',
#  'patriarch soon feels displaced',
#  'mother died giving birth',
#  'classic spencer tracy comedy',
#  'strange occurrences start happening',
#  'sensitive teen carrie white',
#  'old michael myers steals',
#  'beloved holiday movie follows',
#  'defiant teen ariel moore',
#  'young farm pig wilbur',
#  'american drug lord offers',
#  'meek flower shop assistant',
#  'young mexican woman carmen',
#  'devious arms manufacturing conspiracy',
#  'navy pilot topper harley',
#  'freak electrical accident brings',
#  'boiled detective dick tracy',
#  'giant maximum security prison',
#  'caine robs gold ingots',
#  'royal decree awards arrakis',
#  'nolte knowingly withholds evidence',
#  'acquit violent sex offender',
#  'stodgy british upper class',
#  'spiteful amber von tussle',
#  'highly stylized futuristic city',
#  'old pro henry gondorff',
#  'ruthless crime boss responsible',
#  '54th massachusetts volunteer infantry',
#  'junior officer cabot forbes',
#  'wise gravedigger john rawlins',
#  'navy officer frank beardsley',
#  'employee devoted family man',
#  'crotchety miser ebenezer scrooge',
#  'belle presence causes problems',
#  'renowned drama follows troubled',
#  'southern presence causes problems',
#  'audrey junior begins speaking',
#  'row flower shop owned',
#  'hire seven american gunslingers',
#  'serial murder case involving',
#  'sultry book editor named',
#  'new york law firm',
#  'opponent viciously beats eric',
#  'kaye join sister act',
#  'join sister act betty',
#  'reclusive new neighbor named',
#  'corruption involving narcotics lieutenant',
#  'young amish boy samuel',
#  'police officer john book',
#  'travel agent dale arden',
#  'actual romantic feelings begin',
#  'lonely widow charlotte haze',
#  'briefly encountered kate years',
#  'art student sue allen',
#  'new wax sculptures occurs',
#  'london wilderness tale focuses',
#  'jack encounters white fang',
#  'car dealer peter thorndyke',
#  'ineffectual government agencies sent',
#  'american prep school hostage',
#  'colombian terrorist luis cali',
#  'reformed slave trader seeking',
#  'jesuit priest father gabriel',
#  'fight commercial loggers intent',
#  'brilliant eccentric research scientist',
#  'massive berlin police manhunt',
#  'old oil tanker driven',
#  'mild mannered electronics salesman',
#  'people report similar observations',
#  'local boy court foster',
#  'heartbreaking accident later reunites',
#  'fellow soldier allen melvin',
#  'mexican drug enforcement agent',
#  'army air force base',
#  'wise cop bob hodges',
#  'hotheaded rookie danny mcgavin',
#  'old boy sandy ricks',
#  'secretly aspiring author wife',
#  'rich oddball frederick loren',
#  'word processor paul hackett',
#  'young rookie david ackerman',
#  'meets aspiring singer ricardo',
#  'marx brothers run amuck',
#  'navy special operations forces',
#  'helicopter crew taken captive',
#  'violently derail regional treaty',
#  'police detectives chris lecce',
#  'orphaned young girl named',
#  'simple tribe members hiding',
#  'old ways die hard',
#  'making sure vinnie keeps',
#  'revolutionary strike force organizes',
#  'sadistic prison warden drumgoole',
#  'fellow prisoner chink weber',
#  'temple searches army hospitals',
#  'charming scoundrel johnnie aysgarth',
#  'risky financial ventures cause',
#  'lovely teen julie richman',
#  'white russian exiles led',
#  'anastasia purported sole survivor',
#  'environmental activist betty logan',
#  'befriends elderly miss froy',
#  'reckless fellow veteran tuck',
#  'war ends enemy forces',
#  'went missing years ago',
#  'ancient egyptian prince imhotep',
#  'gossip columnist waldo lydecker',
#  'celebrated 1940s film noirs',
#  'manhattan detective mark mcpherson',
#  'dapper thief professor marcus',
#  'doomed vessel finally hits',
#  'private detective philip marlowe',
#  'old buddy terry lennox',
#  'chicago teen tommy riley',
#  'crooked texan jack benyon',
#  'tennessee schoolteacher bertram cates',
#  'prohibits public school teachers',
#  'drawing intense national attention',
#  'chicago policeman truman thinks',
#  'important viet cong commander',
#  'hollywood actor norman maine',
#  'wealthy young cathy earnshaw',
#  'loose chimpanzee mixes chemicals',
#  'rookie cop megan turner',
#  'unexpected romance complicates matters',
#  'police hold turner accountable',
#  'notorious pirate captain flint',
#  'fbi agent robert graham',
#  'german forces sends young',
#  'chinese drug ring run',
#  'american drug ring run',
#  'white grows increasingly willing',
#  'self indolent life supported',
#  'posh apartment complex slaughters',
#  'experiments involving deadly parasites',
#  'undercover cop jim raynor',
#  'capture drug lord gaines',
#  'great white whale responsible',
#  'treacherous sea voyage aboard',
#  'meek businessman named ralph',
#  'including young judy bower',
#  'captain blood crosses paths',
#  'airport mishap leaves businessman',
#  'crew members finally tire',
#  'north pole research base',
#  'marine engineer oliver reed',
#  'oliver unwittingly triggers irena',
#  'joe grows restless performing',
#  'cruel bar event called',
#  'frumpy girl named rose',
#  'nazi officer max radl',
#  'skeptical journalist blair maynard',
#  'tyrannical john david nau',
#  'highly skilled jewel thief',
#  'western pennsylvania auto plant',
#  'woman named amanda brooks',
#  'saxophone player joe ruffalo',
#  'nice teacher named clara',
#  'acclaimed romantic drama follows',
#  'tennessee sheriff buford pusser',
#  'town frake family attend',
#  'zachary family live quietly',
#  'welles acclaimed drama follows',
#  'popular gypsy rose lee',
#  'younger daughter june quits',
#  'adopted native american son',
#  'angeles police officer named',
#  'experimental drug gone wrong',
#  'american handyman homer smith',
#  'late father called home',
#  'man determination eventually wins',
#  'handsome vagabond ben quick',
#  'famous actress charlotte inwood',
#  'renowned charlotte brontë novel',
#  'donat imposes strict discipline',
#  'era english public school',
#  'earthy dance hall girl',
#  'thoughtful old alchemist faust',
#  'pursues notorious outlaw henry',
#  'stewart pursues notorious outlaw',
#  'drug enforcement administration decides',
#  'seattle kingpin marco luganni',
#  'police officer cliff garret',
#  'hit man danny grogan',
#  'dear friend julius caesar',
#  'government scientist john mathewson',
#  'ingenious adolescent paul stephens',
#  'new york science fair',
#  'loyal british knight wilfred',
#  'famous singer keith lennox',
#  'jess leaves new york',
#  'college roommates tim gerrity',
#  'moreno department store clerk',
#  'orphaned puerto rican boy',
#  'revered stage drama focuses',
#  'increasingly unstable willy dwells',
#  'handsome prince named tamino',
#  'lovelorn bird hunter papageno',
#  'museum curator mademoiselle villard',
#  'cleverly deceives von waldheim',
#  'jewish paramilitary group haganah',
#  'transport 600 jewish refugees',
#  'rival manager named gandil',
#  'cut man named poe',
#  'mary meets humphrey pengallan',
#  'humble fisherman manuel fidello',
#  'rebellious lad falls overboard',
#  'troubled student brian woods',
#  'granddaughter comely stage performer',
#  'curator places art dealer',
#  'war hero jefferson jones',
#  'neighbors act like zombies',
#  'young peasant girl cosette',
#  'actually named jack worthing',
#  'ace surgeon jack mckee',
#  'modern bounty hunter ralph',
#  'convicted murderer awaiting execution',
#  'psychotic killer michael bosworth',
#  'dall witnesses expert shooter',
#  'obsessed pacifist bart tare',
#  'men soon run afoul',
#  'newspaper editor jim gannon',
#  'odets stage drama features',
#  'innocent man wrongly accused',
#  'quiet connecticut vacation home',
#  'davison trains mansion rats',
#  'vengeful jehan frames esmeralda',
#  'friend captain john durrance',
#  'english soldier harry faversham',
#  'applegate sends temptress lola',
#  'powerful young baseball player',
#  'aging washington senators fan',
#  'dwarfs bizarrely erotic encounters',
#  'older actor norman maine',
#  'misguided hit man straight',
#  'keaton finishes high school',
#  'impresses nurse linda lee',
#  'meredith shifty advertising man',
#  'easily bored diana scott',
#  'men married television newsman',
#  'newspaper reporter eddie willis',
#  'violent murderer tommy udo',
#  'jewel thief nick bianco',
#  'udo goes free despite',
#  'hacksaw stalks college coeds',
#  'war heroes rip murdock',
#  'driving businessman stewart mcbain',
#  'assess potential security risks',
#  'big georgia bear loose',
#  'george tries heavy firepower',
#  'pirate long john silver',
#  'drug dealer turned actor',
#  'newspaper editor yancey cravat',
#  'blonde bombshell helen grayle',
#  'fellow thespian diana baring',
#  'juror sir john menier',
#  'sir john collects clues',
#  'self making little effort',
#  'england frustrated college dropout',
#  'jimmy constantly insults alison',
#  'charming gigolo chance wayne',
#  'crime boss albert mendoza',
#  'district attorney martin ferguson',
#  'winning actress margaret elliot',
#  'london schoolteacher jean rice',
#  'dangerously insane man known',
#  'current ira member frankie',
#  'investigative journalist stew smith',
#  'fellow scientist alexei dubov',
#  'hardened criminal named mortie',
#  'finds irrefutable evidence linking',
#  'patients gets progressively worse',
#  'jewish state causes conflicts',
#  'theater mogul joseph sheridan',
#  'married new york psychiatrist',
#  'veteran pilot hap smith',
#  'hothead woody jason joins',
#  'american lawyer ingrid jessner',
#  'cruel music teacher svengali',
#  'writing pulp detective stories',
#  'american novelist andrew craig',
#  'cold war kidnapping plot',
#  'film star jeanne eagels',
#  'powered diplomat clay anderson',
#  'lonely young people begin',
#  'film starlet lola burns',
#  'lola flees movie stardom',
#  'charming music hall singer',
#  'class past impedes chipping',
#  'outlawed public religious displays',
#  'american engineer walter faber',
#  'obsessive millionaire named ohlrig',
#  'terribly disfigured swedish woman',
#  'troublesome boy named donald',
#  'subsequently lulls jack asleep',
#  'government secret involving mind',
#  'women appear exactly alike',
#  'group gradually loses faith',
#  'vintage hollywood film clips',
#  'dunn considers trying heroin',
#  'documentary filmmaker jim dunn',
#  'happy day turns tragic',
#  'liberal brooklyn prison guard',
#  'bankole causes marital problems',
#  'soon kat crosses paths',
#  'raines long ago abandoned',
#  'hunters unwittingly set loose',
#  'special blood type needed',
#  'day technologically advanced vampires',
#  'routine procedure goes awry',
#  'drop dead gorgeous woman',
#  'army absconder living peacefully',
#  'small south pacific island',
#  'roman takes niebaum hostage',
#  'internal affairs investigator niebaum',
#  'best police hostage negotiator',
#  'imposing crime syndicate called',
#  'renowned comedic play finds',
#  'married fairy rulers titania',
#  'sadistic rich kids ready',
#  'police detective john shaft',
#  'aging rocker jack frost',
#  'good samaritan nurse lexie',
#  'tennessee teen novalee nation',
#  'young woman finally discovers',
#  'money ... karen sisco',
#  'terrorism expert anthony hubbard',
#  'cia agent elise kraft',
#  'small town scholarship student',
#  'loudmouth harlem grifter ray',
#  'obsessed narcotics officer burke',
#  'grocery store clerk simon',
#  'soap opera actors adam',
#  'unassuming long island enclave',
#  'bullying football team dumps',
#  'charismatic evil genius named',
#  'secret agents john steed',
#  'seemingly innocent actions start',
#  'beautiful young war widow',
#  'life forever ... malna',
#  'urbane professor humbert humbert',
#  'idyllic lakeside vacation home',
#  'deeply disturbed young men',
#  'wealthy uncle sir thomas',
#  'meadows unsuccessfully seeks employment',
#  'sole survivor nadia vinogradiya',
#  'cynical manhattanite amy benic',
#  'interviewing death row inmate',
#  'resulting power struggle leads',
#  'vituperative loose cannon joey',
#  'beleaguered japanese police officer',
#  'deep space hospital ship',
#  'old acquaintance laura cheveley',
#  'british spy steve wilson',
#  'mona hibbard steadily advances',
#  'monstrous creature named grendel',
#  'gorgeous frenchwoman named lila',
#  'wenders follows renowned guitarist',
#  'sitting vice president dies',
#  'undercover cop jeffrey cole',
#  'drug lord dwayne gittens',
#  'headed best friend rusty',
#  'attractive wealthy people led',
#  'harold befriends perry gordon',
#  'horny morally challenged specimen',
#  'faithful german shepherd partner',
#  'fellow officer wendy welles',
#  'young boy grow close',
#  'engaging english artist sean',
#  'powerful crime boss known',
#  'tenacious policeman ned kenny',
#  'way harper finally begins',
#  'good fortune cements bette',
#  'german supply steamer transporting',
#  'fortune mending old wounds',
#  'national guard unit sent',
#  'privileged teenage friends jenny',
#  'music festival cally sees',
#  'affair grow increasingly dire',
#  'barry alexander brown investigate',
#  'poor girl committed suicide',
#  'wagner pursues young heiress',
#  'desperate day laborers risk',
#  'ray poses philosophical questions',
#  'decorated police detective nora',
#  'irish henchman frankie mcgregor',
#  'luck writer jake bridges',
#  'high scheme goes horribly',
#  'bank heist goes wrong',
#  'case involving dirty money',
#  'edward recounts fantastical anecdotes',
#  'danielle helps matthew emerge',
#  'roman army defending hadrian',
#  'ruthless secret police enforcer',
#  'despotic king louis xiv',
#  'elaborate local heist puts',
#  'lapd officer jeff talley',
#  'hostage negotiations goes awry',
#  'animal instincts start taking',
#  'freeloading twin brother donald',
#  'game grows increasingly personal',
#  'marries wealthy contractor mitch',
#  'villainous gangster henry james',
#  'notoriously malicious biker gang',
#  'nerdy high school senior',
#  'amateur comedian lance barton',
#  'small california coastal town',
#  'career thief nick wells',
#  'pitt gradually learns selflessness',
#  'serial killer edgar reese',
#  'police detective john hobbes',
#  'fallen legend joe tanto',
#  'dashing executive producer ray',
#  'relationship goes terribly awry',
#  'fbi agent abby durrell',
#  'standard cosa nostra types',
#  'meets paralegal deck shifflet',
#  'thugs soon grow suspicious',
#  'government agent jack taggart',
#  'fairly typical american suburb',
#  'car accident involving jack',
#  'ambitious younger cop wrenches',
#  'winning humorist dave barry',
#  'talking womanizer jack wickham',
#  'smart athletic psychology student',
#  'rock solid emt boyfriend',
#  'comedy starring snoop dogg',
#  'perpetually unlucky david walsh',
#  'strange things begin happening',
#  'golden opportunity slip away',
#  'elderly mafia boss angelo',
#  'irish director john carney',
#  'attacks threaten remote communities',
#  'struggling actor john person',
#  'tsukamoto demands erotic acts',
#  'brutish principal wackford squeers',
#  'city skyscraper begin inexplicably',
#  'far stranger explanation looms',
#  'american olympic boxing team',
#  'documentary traces rodney bingenheimer',
#  'average guy preston tylk',
#  'fortress insane asylum located',
#  'like insane asylum located',
#  'british gentleman grant fonkyerdoder',
#  'overly reserved nature threatens',
#  'bullock dating police detectives',
#  'hotel manager lisa reisert',
#  'meets charming jackson rippner',
#  'team captain harry flournoy',
#  'irrepressible little primate named',
#  'seasoned adventurer dirk pitt',
#  'genetically altered insect gives',
#  'mysterious crime fighter known',
#  'teenage loser rick riker',
#  'senator joseph mccarthy begins',
#  'aspiring novelist harper lee',
#  'clean video store manager',
#  'video store manager tracy',
#  'hit important overseas targets',
#  'film discusses defense spending',
#  'reclusive billionaire howard hughes',
#  'filmmaker jeff feuerzeig chronicles',
#  'footed slave named kunlun',
#  'carrillo desperately looks forward',
#  'gas station owner ray',
#  'film features interviews conducted',
#  'noted performer joan baez',
#  'including poet allen ginsberg',
#  'documentary film traces musician',
#  'young girl named ebril',
#  'deeply passionate love affair',
#  'incognito travel guide critic',
#  'self reconnaissance mission looking',
#  'styled reconnaissance mission looking',
#  'vietnam veteran uncle paul',
#  'los angeles homeless shelter',
#  'color new york walls',
#  'annual edinburgh fringe festival',
#  'journalists encounters dangerous animals',
#  'kayaker gordon brown sets',
#  'marine nelson sanchez returns',
#  'small including hungry carnivores',
#  'hunting weasel named buck',
#  'dearly departed frank herlihy',
#  'hating dentist bertrum pincus',
#  'financially struggling car dealer',
#  'business proposition quickly turns',
#  'los angeles police department',
#  'single mother christine collins',
#  'authorities vehemently dispute christine',
#  'crust housewife bridget cardigan',
#  'damaging secrets come pouring',
#  'literature professor lawrence wetherhold',
#  'film uses archival footage',
#  'aspiring writer troy gable',
#  'old muslim girl falls',
#  'evil biker gang known',
#  'dear john letter awaits',
#  'filmmaker jennifer venditti follows',
#  'new partner roman pearce',
#  'life emerging secrets threaten',
#  'mysterious killings terrorizes seattle',
#  'pharmaceutical company bosses forbid',
#  'freak workplace accident clears',
#  'frank goode looks forward',
#  'nazi war criminal known',
#  'starts perpetrating sexual violence',
#  'japan local fishermen hide',
#  'attractive colleague named laura',
#  'fellow writers jack kerouac',
#  'bookstore owner lawrence ferlinghetti',
#  'cultural icon allen ginsberg',
#  'mother offers little comfort',
#  'undergoing intense cancer treatments',
#  'fighter called red mist',
#  'scheming mobster soon puts',
#  'sam unexpectedly returns home',
#  'mysterious operative named aisha',
#  'years begins discussing adopting',
#  'playboy vet henry sets',
#  'global cataclysm finally occurs',
#  'failed writer jackson curtis',
#  'world starts falling apart',
#  'love affair went sour',
#  ...]

# %%
# Output to json
out_dir = data_dir
with open(os.path.join(out_dir, 'movie_desc_keywords.json'), 'w') as json_file:
    json.dump(movie_tf, json_file)
with open(os.path.join(out_dir, 'inv_movie_desc_keywords.json'), 'w') as json_file:
    json.dump(movie_idf, json_file)
