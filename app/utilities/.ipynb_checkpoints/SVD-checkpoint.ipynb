# %%
import json
import os
import numpy as np
from nltk.corpus import wordnet as wn

# %%
G_REV_KEYWORD_VEC_FILENAME = 'game_rev_keyword_vec.json'
G_REV_WORD_TO_SYNPHRASES_FILENAME = 'game_rev_word_to_synphrase.json'
GAME_INFO_FILENAME = 'game_info.json'
DATA_DIR = "/Users/changwei/Documents/GitHub/cs4300sp2021-cw887-qh75-rz92-yc687-yl698/app/data"
MOVIE_INFO_FILENAME = 'movie_info.json'

# %%
with open(os.path.join(DATA_DIR, GAME_INFO_FILENAME), 'r', encoding='utf8') as in_json_file:
    GAME_INFO = json.load(in_json_file)
with open(os.path.join(DATA_DIR, G_REV_WORD_TO_SYNPHRASES_FILENAME), 'r', encoding='utf8') as in_json_file:
    G_REV_WORD_TO_SYNPHRASES = json.load(in_json_file)
with open(os.path.join(DATA_DIR, G_REV_KEYWORD_VEC_FILENAME), 'r', encoding='utf8') as in_json_file:
    G_REV_KEYWORD_VEC = json.load(in_json_file)
with open(os.path.join(DATA_DIR, MOVIE_INFO_FILENAME), 'r', encoding='utf8') as in_json_file:
    MOVIE_INFO = json.load(in_json_file)

# %%
token_dict = dict()
for key in GAME_INFO:
    for entry in GAME_INFO[key]['tags']:
        token_dict[entry] = token_dict.get(entry, 0) + 1
    for entry in GAME_INFO[key]['desc_keywords']:
        token_dict[entry] = token_dict.get(entry, 0) + 1
    if key in G_REV_KEYWORD_VEC:
        for entry in G_REV_KEYWORD_VEC[key]['vector'].keys():
            token_dict[entry] = token_dict.get(entry, 0) + 1  
for key in MOVIE_INFO:
    for entry in MOVIE_INFO[key]['desc_keywords']:
        token_dict[entry] = token_dict.get(entry, 0) + 1
token_lst = np.array(sorted(list(set(token_dict.keys()))))
token_count = np.array([token_dict[e] for e in token_lst])
num_token = len(token_lst)

# %%
print(len(token_lst))
print(token_lst[:10])
print(token_lst[-10:])
print(token_count)
print(np.sum(token_count>3))
# Out:
# 130148
# ['-' '0' '000 french' '000 mark payment' '000 miles'
#  '000 mischievous ghouls descend' '000 pounds' '000 sleeping passengers'
#  '000 years' '001 robo']
# ['zula' 'zuniga' 'zup' 'zurer' 'zus' 'zuwanie' 'zyon' 'zytron' 'édith'
#  'édith piaf']
# [1 1 1 ... 1 1 1]
# 9716

# %%
selected_idx = np.nonzero(token_count > 3)[0]
selected_token_lst = token_lst[selected_idx]
selected_num_token = len(selected_token_lst)
dict_selected_token_to_idx = {t:i for i,t in enumerate(selected_token_lst)}

# %%
movie_vectors = dict()
for key in MOVIE_INFO:
    vector = np.zeros(selected_num_token)
    for entry in MOVIE_INFO[key]['desc_keywords']:
        if entry in selected_token_lst:
            vector[dict_selected_token_to_idx[entry]] += 3
    movie_vectors[key] = vector.copy()
movie_ids = list(MOVIE_INFO.keys())
movie_vectors_2d = np.array([movie_vectors[i] for i in movie_ids])
print(len(movie_ids), 'movies in total')
print(movie_vectors_2d.shape)
# Out:
# 3000 movies in total
# (3000, 9716)

# %%
game_vectors = dict()
for key in GAME_INFO:
    vector = np.zeros(selected_num_token)
    for entry in GAME_INFO[key]['tags']:
        if entry in selected_token_lst:
            vector[dict_selected_token_to_idx[entry]] += 5
    for entry in GAME_INFO[key]['desc_keywords']:
        if entry in selected_token_lst:
            vector[dict_selected_token_to_idx[entry]] += 3
    if key in G_REV_KEYWORD_VEC:
        for entry in G_REV_KEYWORD_VEC[key]['vector'].keys():
            if entry in selected_token_lst:
                vector[dict_selected_token_to_idx[entry]] += G_REV_KEYWORD_VEC[key]['vector'][entry]
    game_vectors[key] = vector.copy()

# %%
game_id_lst = list(game_vectors.keys())
game_vectors_2d = list()
for i in game_id_lst:
    game_vectors_2d.append(game_vectors[i])
game_vectors_2d = np.array(game_vectors_2d)

# %%
print(game_vectors_2d.shape)
print(game_vectors_2d.shape[0], "games in total")
print(game_vectors_2d.shape[1], "tokens in total")
# Out:
# (2734, 9716)
# 2734 games in total
# 9716 tokens in total

# %%
game_movie_vectors_2d = np.vstack((game_vectors_2d, movie_vectors_2d))
game_movie_vectors_2d_normalized = game_movie_vectors_2d - np.mean(game_movie_vectors_2d, axis=0)
print(game_movie_vectors_2d.shape)
# Out:
# (5734, 9716)

# %%
u, s, vh = np.linalg.svd(game_movie_vectors_2d_normalized)

# %%
cutoff_idx = np.nonzero((np.cumsum(s)/np.sum(s)) > 0.95)[0][0] + 1
print(cutoff_idx)
print(vh.shape)
# Out:
# 4525
# (9716, 9716)

# %%
v_pca = vh[:cutoff_idx].T
print(v_pca.shape)
# Out:
# (9716, 4525)

# %%
game_movie_vectors_2d_pca = game_movie_vectors_2d_normalized.dot(v_pca)
game_vectors_2d_pca = game_movie_vectors_2d_pca[:2734]
movie_vectors_2d_pca = game_movie_vectors_2d_pca[2734:]
print(game_movie_vectors_2d_pca.shape)
print(game_vectors_2d_pca.shape)
print(movie_vectors_2d_pca.shape)
dict_game_vectors_2d_pca = {i:vec.tolist() for i, vec in zip(game_id_lst, game_vectors_2d_pca)}
dict_movie_vectors_2d_pca = {i:vec.tolist() for i, vec in zip(movie_ids, movie_vectors_2d_pca)}
# Out:
# (5734, 4525)
# (2734, 4525)
# (3000, 4525)

# %%
STORE_DIR = "/Users/changwei/Documents/GitHub/cs4300sp2021-cw887-qh75-rz92-yc687-yl698/app/data/pca_svd"
GAME_VECTORS_PCA = "dict_gameid_to_vector_pca.json"
MOVIE_VECTORS_PCA = "dict_movieid_to_vector_pca.json"
EIGENVECTORS_PCA_COLUMNS = "game_movie_eigenvectors_column.json"
TOKEN_LST_BEFORE_PCA = "token_list_before_pca.json"
DICT_TOKEN_TO_IDX_BEFORE_PCA = "dict_token_to_id_before_pca.json"

with open(os.path.join(STORE_DIR, GAME_VECTORS_PCA), 'w', encoding='utf8') as to_json:
    json.dump(dict_game_vectors_2d_pca, to_json)
with open(os.path.join(STORE_DIR, MOVIE_VECTORS_PCA), 'w', encoding='utf8') as to_json:
    json.dump(dict_movie_vectors_2d_pca, to_json)
with open(os.path.join(STORE_DIR, EIGENVECTORS_PCA_COLUMNS), 'w', encoding='utf8') as to_json:
    json.dump(v_pca.tolist(), to_json)
with open(os.path.join(STORE_DIR, TOKEN_LST_BEFORE_PCA), 'w', encoding='utf8') as to_json:
    json.dump(selected_token_lst.tolist(), to_json)
with open(os.path.join(STORE_DIR, DICT_TOKEN_TO_IDX_BEFORE_PCA), 'w', encoding='utf8') as to_json:
    json.dump(dict_selected_token_to_idx, to_json)

# %%
movie_ids
# Out:
# ['0814255',
#  '1000013-12_angry_men',
#  '1000079-20000_leagues_under_the_sea',
#  '10000_bc',
#  '10004209-tristan_and_isolde',
#  '10004288-running_scared',
#  '10004504-ultraviolet',
#  '10004659-arthur',
#  '10004925-matador',
#  '10006007-the_second_chance',
#  '1000617-aliens',
#  '10006370-stay_alive',
#  '10007415-amazing_grace',
#  '10007598-cocaine_cowboys',
#  '10007947-ten',
#  '10007985-happening',
#  '10008502-christmas_carol',
#  '10008587-beverly_hills_chihuahua',
#  '10008606-eye',
#  '10008611-my_best_friends_girl',
#  '10008617-midnight_meat_train',
#  '10008621-run_fat_boy_run',
#  '10008655-whiteout',
#  '10008760-what_happens_in_vegas',
#  '10008785-appaloosa',
#  '10008820-visitor',
#  '10008954-untraceable',
#  '10009063-perfect_holiday',
#  '10009083-land_of_the_lost',
#  '10009151-box',
#  '10009192-21',
#  '10009225-body_of_lies',
#  '10009254-shutter',
#  '10009274-priest',
#  '10009460-the_road',
#  '10009462-g_force',
#  '10009493-duchess',
#  '10009516-women',
#  '10009526-public_enemies',
#  '10009596-old_dogs',
#  '10009598-surrogates',
#  '10009624-promotion',
#  '10009632-notorious',
#  '10009635-soul_men',
#  '10009636-igor',
#  '10009926-alvin_and_the_chipmunks_2',
#  '10010066-push',
#  '10010150-unborn',
#  '10010458-proposal',
#  '10010552-gigantic',
#  '10010658-orphan',
#  '10010662-my_sisters_keeper',
#  '10010667-hangover',
#  '10010668-stepfather',
#  '10010694-season_of_the_witch',
#  '10010760-miss_march',
#  '10011235-fame',
#  '10011388-blood_the_last_vampire',
#  '10011582-TRON_legacy',
#  '10011984-last_song',
#  '10012042-going_the_distance',
#  '10012044-life_as_we_know_it',
#  '10012063-ghost_writer',
#  '10012068-repo_men',
#  '10012141-kids_are_all_right',
#  '10012256-predators',
#  '1002448-birds',
#  '1003318-butch_cassidy_and_the_sundance_kid',
#  '1003625-carrie',
#  '1003707-casablanca',
#  '1003952-charlottes_web',
#  '1004047-children_of_the_corn',
#  '1004125-christmas_carol',
#  '1004151-christmas_story',
#  '1004567-commando',
#  '1005360-day_of_the_dead',
#  '1006364-dune',
#  '1006527-elephant_man',
#  '1006717-escape_from_new_york',
#  '1007141-fatal_attraction',
#  '1007602-fly',
#  '1007657-footloose',
#  '1007839-freaky_friday',
#  '1008415-glory',
#  '1008588-gone_in_60_seconds',
#  '1009096-hairspray',
#  '1009113-halloween',
#  '1011605-king_and_i',
#  '1011615-king_kong',
#  '1011617-king_kong',
#  '1012164-legend',
#  '1012514-little_shop_of_horrors',
#  '1012515-little_shop_of_horrors',
#  '1012665-longest_yard',
#  '1013077-magnificent_seven',
#  '1013139-maltese_falcon',
#  '1013248-manhunter',
#  '1013775-metropolis',
#  '1014217-moonraker',
#  '1014294-moulin_rouge',
#  '1015052-night_of_the_living_dead',
#  '1015517-omen',
#  '1015944-parent_trap',
#  '1016213-peter_pan',
#  '1016338-pink_panther',
#  '1016397-planet_of_the_apes',
#  '1016513-poltergeist',
#  '1016534-popeye',
#  '1016819-producers',
#  '1017289-rear_window',
#  '1017488-return_to_oz',
#  '1017641-risky_business',
#  '1017666-road_house',
#  '1017699-robin_hood',
#  '1017712-robocop',
#  '1017776-rocky',
#  '1017834-romeo_and_juliet',
#  '1017962-rudolph_the_rednosed_reindeer',
#  '1018047-sabrina',
#  '1018891-short_circuit',
#  '1019187-sleeping_beauty',
#  '1019544-spartacus',
#  '101_dalmatians',
#  '1020130-sting',
#  '1020333-streetcar_named_desire',
#  '1021015-ten_commandments',
#  '1021244-thing',
#  '1021312-three_amigos',
#  '1022191-twins',
#  '1023205-warriors',
#  '1023316-weird_science',
#  '1024407-yours_mine_and_ours',
#  '1029112-alice_in_wonderland',
#  '1029314-dick_tracy',
#  '102_dalmatians',
#  '1031086-ghost',
#  '1031385-jungle_book',
#  '1032176-goodfellas',
#  '1032970-awakenings',
#  '1036179-hot_shots',
#  '1037581-cape_fear',
#  '1037649-my_girl',
#  '1037756-jfk',
#  '1037864-father_of_the_bride',
#  '1038613-italian_job',
#  '1038726-beethoven',
#  '1040378-cool_world',
#  '1040678-last_of_the_mohicans',
#  '1041862-forever_young',
#  '1041911-unforgiven',
#  '1042135-malcolm_x',
#  '1042193-scent_of_a_woman',
#  '1044214-cliffhanger',
#  '1044522-firm',
#  '1045518-secret_garden',
#  '1046129-fugitive',
#  '1046227-cool_runnings',
#  '1046772-three_musketeers',
#  '1048445-snow_white_and_the_seven_dwarfs',
#  '1048880-thumbelina',
#  '1052529-black_beauty',
#  '1053779-mask',
#  '1056130-titanic',
#  '1058426-junior',
#  '1058516-street_fighter',
#  '1058517-little_women',
#  '1059629-quick_and_the_dead',
#  '1059858-man_of_the_house',
#  '1061812-little_princess',
#  '1062483-bad_boys',
#  '1063452-pocahontas',
#  '1065598-babe',
#  '1065684-braveheart',
#  '1067137-it_takes_two',
#  '1067987-casino',
#  '1068044-jumanji',
#  '1068182-heat',
#  '1068779-dead_man_walking',
#  '1069241-broken_arrow',
#  '1069419-black_sheep',
#  '1070621-flipper',
#  '1070992-primal_fear',
#  '1071167-twister',
#  '1071258-fear',
#  '1071806-independence_day',
#  '1072011-rock',
#  '1072107-matilda',
#  '1072381-time_to_kill',
#  '1072385-kingpin',
#  '1072457-chain_reaction',
#  '1072875-jack',
#  '1073037-hunchback_of_notre_dame',
#  '1073161-bulletproof',
#  '1073316-emma',
#  '1073427-selena',
#  '1074108-101_dalmatians',
#  '1074298-ransom',
#  '1074316-scream',
#  '1074465-michael',
#  '1076267-volcano',
#  '1077027-batman_and_robin',
#  '1077847-george_of_the_jungle',
#  '1078021-contact',
#  '1078955-game',
#  '1079716-seven_years_in_tibet',
#  '1079818-anastasia',
#  '1081623-merlin',
#  '1082400-man_in_the_iron_mask',
#  '1083171-perfect_murder',
#  '1083414-parent_trap',
#  '1083436-1083436-out_of_sight',
#  '1083481-negotiator',
#  '1083484-blade',
#  '1083659-rounders',
#  '1084146-thin_red_line',
#  '1084153-elizabeth',
#  '1084398-life_is_beautiful',
#  '1084582-mighty_joe_young',
#  '1084964-psycho',
#  '1085113-siege',
#  '1087270-mummy',
#  '1087648-payback',
#  '1090089-jack_frost',
#  '1090759-deep_blue_sea',
#  '1090789-haunting',
#  '1090918-midsummer_nights_dream',
#  '1093579-man_on_the_moon',
#  '1093611-anna_and_the_king',
#  '1093614-double_jeopardy',
#  '1093641-hurricane',
#  '1093874-superstar',
#  '1093881-house_on_haunted_hill',
#  '1095420-high_fidelity',
#  '1096832-where_the_heart_is',
#  '1097046-dinosaur',
#  '1097259-road_trip',
#  '1097865-gone_in_60_seconds',
#  '1098038-shaft',
#  '1098149-patriot',
#  '10_cloverfield_lane',
#  '10_things_i_hate_about_you',
#  '1101051-bedazzled',
#  '1103281-traffic',
#  '1104385-hannibal',
#  '1104813-down_to_earth',
#  '1104841-sweet_november',
#  '1105990-heartbreakers',
#  '1107902-angel_eyes',
#  '1108185-animal',
#  '1108206-evolution',
#  '1108372-fast_and_the_furious',
#  '1108389-pearl_harbor',
#  '1108704-planet_of_the_apes',
#  '1108799-score',
#  '1109257-others',
#  '1110242-collateral_damage',
#  '1110288-count_of_monte_cristo',
#  '1111645-behind_enemy_lines',
#  '1112357-scoobydoo',
#  '1112549-crossroads',
#  '1112617-new_guy',
#  '1112951-time_machine',
#  '1112954-rookie',
#  '1113638-murder_by_numbers',
#  '1114051-enough',
#  '1114154-insomnia',
#  '1118700-adaptation',
#  '1121649-anger_management',
#  '1123000-carrie',
#  '1124859-grind',
#  '1125409-cabin_fever',
#  '1127787-big_fish',
#  '1128577-peter_pan',
#  '1129132-torque',
#  '1130343-girl_next_door',
#  '1131721-punisher',
#  '1133499-1133499-terminal',
#  '1133964-king_arthur',
#  '1139289-beauty_shop',
#  '1141099-hostage',
#  '1141102-are_we_there_yet',
#  '1141193-hide_and_seek',
#  '1142569-cursed',
#  '1142872-sky_high',
#  '1144274-sahara',
#  '1144992-crash',
#  '1146673-1146673-stealth',
#  '1149472-skeleton_key',
#  '1149496-1149496-red_eye',
#  '1151898-capote',
#  '1152019-good_night_and_good_luck',
#  '1152276-rent',
#  '1152567-jarhead',
#  '1152954-new_world',
#  '1153077-1153077-pride_and_prejudice',
#  '1153228-the_ringer',
#  '1153341-breakfast_on_pluto',
#  '1153907-football_factory',
#  '1153951-curious_george',
#  '1154157-big_mommas_house_2',
#  '1155109-hoodwinked',
#  '1155467-glory_road',
#  '1155470-date_movie',
#  '1155622-why_we_fight',
#  '1156246-casanova',
#  '1156283-doogal',
#  '1157247-london',
#  '1157387-little_fish',
#  '1158185-see_no_evil',
#  '1158195-marie_antoinette',
#  '1158528-goal',
#  '1159618-superhero',
#  '1167633-driving_lessons',
#  '1169203-invisible',
#  '1171939-perfect_stranger',
#  '1174278-definitely_maybe',
#  '1174279-wanted',
#  '1175072-license_to_wed',
#  '1175076-fred_claus',
#  '1175569-lars_and_the_real_girl',
#  '1184827-alvin_and_the_chipmunks',
#  '1185801-the_express',
#  '1188215-blindness',
#  '1188347-mad_money',
#  '1188732-haunting_in_connecticut',
#  '1189217-angels_and_demons',
#  '1189344-lovely_bones',
#  '1189844-the_bank_job',
#  '1190296-zack_and_miri_make_a_porno',
#  '1190660-over_my_dead_body',
#  '1190964-imagine_that',
#  '1190970-ghost_town',
#  '1191620-college',
#  '1191742_changeling',
#  '1192938-smart_people',
#  '1193230-state_of_play',
#  '1193743-step_brothers',
#  '1194209-elegy',
#  '1194515-ice_age_dawn_of_the_dinosaurs',
#  '1194524-high_school_musical_3_senior_year',
#  '1194949-wolfman',
#  '1195801-space_chimps',
#  '1196003-princess_and_the_frog',
#  '1196077-cloudy_with_a_chance_of_meatballs',
#  '1196215-lakeview_terrace',
#  '1196221-quarantine',
#  '1197016-mirrors',
#  '1197696-fantastic_mr_fox',
#  '1198124-shutter_island',
#  '1198524-ninja_assassin',
#  '1198658-i_love_you_beth_cooper',
#  '1200661-informant',
#  '1200731-robocop',
#  '1201402-17_again',
#  '1202110-tooth_fairy',
#  '1202804-green_zone',
#  '1205377-last_house_on_the_left',
#  '1205380-crazies',
#  '1205483_nine',
#  '1205530-three_stooges',
#  '1207149-taking_of_pelham_1_2_3',
#  '1207523-obsessed',
#  '1208173-splice',
#  '1208806-its_complicated',
#  '1209933-puss_in_boots',
#  '1210749-eclipse',
#  '1211183-extract',
#  '1211197-everybodys_fine',
#  '1211619-remember_me',
#  '1212410-get_him_to_the_greek',
#  '1212694-blind_side',
#  '1212891-furry_vengeance',
#  '1212910-warrior',
#  '1213377-homecoming',
#  '1213717-salt',
#  '1213718-did_you_hear_about_the_morgans',
#  '1213999-brothers',
#  '1214027-collector',
#  '1214097-despicable_me',
#  '1215790-carriers',
#  '1217700-kick_ass',
#  '1218217-single_man',
#  '1220551-bounty_hunter',
#  '1221547-alice_in_wonderland',
#  '1226860-losers',
#  '127_hours',
#  '12_monkeys',
#  '12_rounds',
#  '12_years_a_slave',
#  '13_ghosts',
#  '13_going_on_30',
#  '13th_warrior',
#  '1408',
#  '16_blocks',
#  '1984_1984',
#  '2001_a_space_odyssey',
#  '2012',
#  '21_and_over',
#  '21_grams',
#  '21_jump_street_2011',
#  '22_jump_street',
#  '25th_hour',
#  '27_dresses',
#  '28_days',
#  '28_days_later',
#  '28_weeks_later',
#  '2_fast_2_furious',
#  '2_guns',
#  '300',
#  '3000_miles_to_graceland',
#  '300_rise_of_an_empire',
#  '30_days_of_night',
#  '310_to_yuma',
#  '3_ninjas',
#  '3_ninjas_high_noon_at_mega_mountain',
#  '3_ninjas_kick_back',
#  '40_days_and_40_nights',
#  '42_2013',
#  '47_ronin_2013',
#  '48_hrs',
#  '500_days_of_summer',
#  '5050_2011',
#  '50_first_dates',
#  '88_minutes',
#  '8_mile',
#  '8_seconds',
#  '8mm',
#  'a_good_day_to_die_hard',
#  'a_guide_to_recognizing_your_saints',
#  'a_guy_thing',
#  'a_haunted_house',
#  'a_million_ways_to_die_in_the_west',
#  'a_nightmare_on_elm_street_2_freddys_revenge',
#  'a_nightmare_on_elm_street_3_dream_warriors',
#  'a_nightmare_on_elm_street_4_the_dream_master',
#  'a_nightmare_on_elm_street_5_the_dream_child',
#  'a_perfect_getaway',
#  'a_serious_man',
#  'a_team',
#  'a_thousand_words',
#  'a_very_long_engagement_2004',
#  'about_a_boy',
#  'about_schmidt',
#  'about_time',
#  'abraham_lincoln_vampire_hunter',
#  'accepted',
#  'accidental_husband',
#  'ace_ventura_pet_detective',
#  'ace_ventura_when_nature_calls',
#  'across_the_universe',
#  'act_of_valor',
#  'adam_sandlers_eight_crazy_nights',
#  'addams_family',
#  'addams_family_values',
#  'adjustment_bureau',
#  'adventureland',
#  'adventures_in_babysitting',
#  'aeon_flux',
#  'after_earth',
#  'after_the_wedding',
#  'agent_cody_banks',
#  'agent_cody_banks_2_destination_london',
#  'ai_artificial_intelligence',
#  'air-bud-golden-receiver',
#  'air_bud',
#  'air_force_one',
#  'airplane',
#  'airplane_2_the_sequel',
#  'akeelah_and_the_bee',
#  'akira',
#  'aladdin',
#  'aladdin-and-the-king-of-thieves',
#  'alex_and_emma',
#  'alex_rider_operation_stormbreaker',
#  'alexander',
#  'alfie',
#  'ali',
#  'ali-g-indahouse-the-movie',
#  'alien',
#  'alien3',
#  'alien_covenant',
#  'alien_resurrection',
#  'alien_vs_predator',
#  'aliens_in_the_attic',
#  'all_about_steve',
#  'all_dogs_go_to_heaven',
#  'all_dogs_go_to_heaven_2',
#  'all_the_kings_men',
#  'almost_famous',
#  'alone_in_the_dark',
#  'alone_with_her',
#  'along_came_a_spider',
#  'along_came_polly',
#  'alpha_dog',
#  'alvin_and_the_chipmunks_chipwrecked_2011',
#  'amadeus',
#  'amelia_2009',
#  'amelie',
#  'american-pie-5-the-naked-mile',
#  'american_beauty',
#  'american_dreamz',
#  'american_gangster',
#  'american_graffiti',
#  'american_haunting',
#  'american_history_x',
#  'american_hustle',
#  'american_pie',
#  'american_pie_2',
#  'american_pie_presents_band_camp',
#  'american_president',
#  'american_psycho',
#  'american_reunion_2012',
#  'american_sniper',
#  'american_tail',
#  'american_tail_fievel_goes_west',
#  'american_teen',
#  'american_wedding',
#  'american_werewolf_in_london',
#  'americas_sweethearts',
#  'amityville_horror',
#  'amores_perros',
#  'an_education',
#  'anaconda',
#  'anacondas_the_hunt_for_the_blood_orchid',
#  'analyze_that',
#  'analyze_this',
#  'anchorman',
#  'anchorman_2_the_legend_continues',
#  'and_now_for_something_completely_different',
#  'angela-2007',
#  'animatrix',
#  'anna_karenina_2012',
#  'annapolis',
#  'annie_1981',
#  'annie_2012',
#  'annie_hall',
#  'another_48_hrs',
#  'ant_bully',
#  'antman',
#  'antz',
#  'any_given_sunday',
#  'apocalypse_now',
#  'apocalypto',
#  'apollo_13',
#  'aquamarine',
#  'arachnophobia',
#  'arbitrage',
#  'argo_2012',
#  'aristocats',
#  'aristocrats',
#  'armageddon',
#  'armored',
#  'army_of_darkness',
#  'around_the_world_in_80_days',
#  'arrival_2016',
#  'as_good_as_it_gets',
#  'assassination_of_a_high_school_president',
#  'assassination_of_jesse_james_by_the_coward_robert_ford',
#  'assassins',
#  'assassins_creed',
#  'assault_on_precinct_13',
#  'astro_boy',
#  'astronaut_farmer',
#  'astronauts_wife',
#  'atl',
#  'atlantis_the_lost_empire',
#  'atonement',
#  'audition_1999',
#  'august_rush',
#  'austin_powers_in_goldmember',
#  'austin_powers_international_man_of_mystery',
#  'austin_powers_the_spy_who_shagged_me',
#  'australia',
#  'avatar',
#  'avengers_age_of_ultron',
#  'avengers_endgame',
#  'avengers_infinity_war',
#  'aviator',
#  'avp2',
#  'awake',
#  'away_from_her',
#  'away_we_go',
#  'babe_pig_in_the_city',
#  'babel',
#  'baby_boy',
#  'baby_driver',
#  'baby_geniuses',
#  'baby_mama',
#  'babylon_ad',
#  'babys_day_out',
#  'back_to_the_future',
#  'back_to_the_future_2',
#  'back_to_the_future_3',
#  'back_up_plan',
#  'bad_boys_1982',
#  'bad_boys_ii',
#  'bad_company_2002',
#  'bad_lieutenant_port_of_call_new_orleans',
#  'bad_news_bears',
#  'bad_santa',
#  'bad_teacher',
#  'balls_of_fury',
#  'balto',
#  'bambi',
#  'bambi_ii',
#  'bandits',
#  'bandslam',
#  'bangkok_dangerous',
#  'barbershop',
#  'barbershop_2_back_in_business',
#  'barnyard',
#  'baseketball',
#  'basic',
#  'basic_instinct',
#  'basic_instinct_2',
#  'batman_and_mr_freeze_subzero',
#  'batman_begins',
#  'batman_beyond_return_of_the_joker',
#  'batman_forever',
#  'batman_mask_of_the_phantasm',
#  'batman_returns',
#  'batman_the_movie',
#  'batman_v_superman_dawn_of_justice',
#  'batteries_not_included',
#  'battle-los-angeles',
#  'battle_for_terra_2009',
#  'battle_royale',
#  'battlefield_earth',
#  'battleship',
#  'be_cool',
#  'be_kind_rewind',
#  'beach',
#  'beaches',
#  'bean',
#  'beastly',
#  'beautiful_mind',
#  'beauty-and-the-beast-the-enchanted-christmas',
#  'beauty_and_the_beast_1991',
#  'beauty_and_the_beast_2017',
#  'beavis_and_butt_head_do_america',
#  'because_i_said_so',
#  'becoming_jane',
#  'bedknobs_and_broomsticks',
#  'bedtime_stories',
#  'bee_movie',
#  'beerfest',
#  'beethovens_2nd',
#  'beethovens_3rd',
#  'beethovens_4th',
#  'beetlejuice',
#  'before_sunrise',
#  'before_sunset',
#  'before_the_devil_knows_youre_dead',
#  'being_john_malkovich',
#  'belles_magical_world',
#  'benchwarmers',
#  'bend_it_like_beckham',
#  'benhur',
#  'benny_and_joon',
#  'beowulf',
#  'best_in_show',
#  'beverly_hills_cop',
#  'beverly_hills_cop_2',
#  'beverly_hills_cop_3',
#  'beverly_hills_ninja',
#  'bewitched',
#  'bicentennial_man',
#  'big',
#  'big_daddy',
#  'big_fat_liar',
#  'big_hero_6',
#  'big_mommas_house',
#  'big_mommas_like_father_like_son',
#  'big_trouble_in_little_china',
#  'bigger_stronger_faster_asterisk',
#  'biker_boyz',
#  'bill_and_teds_bogus_journey',
#  'bill_and_teds_excellent_adventure',
#  'billy_elliot',
#  'billy_madison',
#  'biodome',
#  'bird_on_a_wire',
#  'birdcage',
#  'birdman_2014',
#  'black_christmas',
#  'black_dahlia',
#  'black_hawk_down',
#  'black_knight',
#  'black_mass_2015',
#  'black_panther_2018',
#  'black_snake_moan',
#  'black_swan_2010',
#  'blade_ii',
#  'blade_runner',
#  'blade_runner_2049',
#  'blade_trinity',
#  'blades_of_glory',
#  'blair_witch_project',
#  'blank_check',
#  'blast_from_the_past',
#  'blazing_saddles',
#  'blended',
#  'block_party',
#  'blood_and_chocolate',
#  'blood_diamond',
#  'bloodrayne',
#  'bloodsport',
#  'blow',
#  'blue_collar_comedy_tour_the_movie',
#  'blue_crush',
#  'blue_lagoon',
#  'blue_streak',
#  'blue_valentine',
#  'blue_velvet',
#  'blues_brothers',
#  'blues_brothers_2000',
#  'boat_trip',
#  'bolt',
#  'bone_collector',
#  'bonnie_and_clyde',
#  'boogeyman',
#  'boogie_nights',
#  'book_of_shadows_blair_witch_2',
#  'boondock_saints',
#  'boondock_saints_ii_all_saints_day',
#  'borat',
#  'born_on_the_fourth_of_july',
#  'bottle_rocket',
#  'bourne_identity',
#  'bourne_supremacy',
#  'bourne_ultimatum',
#  'bowfinger',
#  'bowling_for_columbine',
#  'boy_in_the_striped_pajamas',
#  'boy_named_charlie_brown',
#  'boyhood',
#  'boys_dont_cry',
#  'boyz_n_the_hood',
#  'brave_2012',
#  'brave_one',
#  'breach',
#  'break_up',
#  'breakfast_at_tiffanys',
#  'breakfast_club',
#  'breaking_and_entering',
#  'brick',
#  'bride_and_prejudice',
#  'bride_of_chucky',
#  'bride_wars',
#  'bridesmaids_2011',
#  'bridge_of_spies',
#  'bridge_on_the_river_kwai',
#  'bridge_to_terabithia',
#  'bridget_jones_diary',
#  'bridget_jones_the_edge_of_reason',
#  'bring_it_on',
#  'bring_it_on_all_or_nothing',
#  'bringing_down_the_house',
#  'brokeback_mountain',
#  'broken_flowers',
#  'bronx_tale',
#  'brooklyns_finest',
#  'brother_bear',
#  'brothers_bloom',
#  'brothers_grimm',
#  'brothers_solomon',
#  'brown_sugar',
#  'bruce_almighty',
#  'bruno',
#  'bubba_ho_tep',
#  'bubble_boy',
#  'bucket_list',
#  'buffy_the_vampire_slayer',
#  'bug',
#  'bugs_life',
#  'bulletproof_monk',
#  'buried',
#  'burlesque',
#  'burn_after_reading',
#  'butterfly_effect',
#  'cable_guy',
#  'caddyshack',
#  'cadillac_records',
#  'calendar_girls',
#  'camp_rock',
#  'candyman',
#  'cant_hardly_wait',
#  'capitalism_a_love_story',
#  'captain_america_civil_war',
#  'captain_america_the_first_avenger',
#  'captain_america_the_winter_soldier_2014',
#  'captain_marvel',
#  'captain_phillips',
#  'captivity',
#  'carlitos_way',
#  'carrie',
#  'cars',
#  'cars_2',
#  'case_39',
#  'casino_royale',
#  'casper',
#  'cassandras_dream',
#  'cast_away',
#  'catch_and_release',
#  'catch_me_if_you_can',
#  'cats_and_dogs',
#  'cats_and_dogs_the_revenge_of_kitty_galore',
#  'catwoman',
#  'cave',
#  'cellular',
#  'center_stage',
#  'central_intelligence',
#  'changing_lanes',
#  'charlie_and_the_chocolate_factory',
#  'charlie_bartlett',
#  'charlie_brown_thanksgiving',
#  'charlie_st_cloud',
#  'charlie_wilsons_war',
#  'charlies_angels',
#  'charlies_angels_full_throttle',
#  'charlottes_web',
#  'chasing_amy',
#  'chasing_liberty',
#  'cheaper_by_the_dozen',
#  'cheaper_by_the_dozen_1950',
#  'cheaper_by_the_dozen_2',
#  'cheetah_girls',
#  'chef_2014',
#  'chernobyl_diaries',
#  'chicago',
#  'chicken_little',
#  'chicken_run',
#  'children_of_huang_shi',
#  'children_of_men',
#  'childs_play',
#  'childs_play_2',
#  'childs_play_3',
#  'chinatown',
#  'chitty_chitty_bang_bang',
#  'chocolat',
#  'christine',
#  'christmas_with_the_kranks',
#  'chronicle',
#  'chronicles_of_narnia_lion_witch_wardrobe',
#  'chronicles_of_narnia_prince_caspian',
#  'chronicles_of_narnia_the_voyage_of_the_dawn_treader',
#  'chronicles_of_riddick',
#  'cider_house_rules',
#  'cinderella',
#  'cinderella_2013',
#  'cinderella_ii_dreams_come_true',
#  'cinderella_man',
#  'cinderella_story',
#  'cinema_paradiso',
#  'citizen_kane',
#  'city_of_angels',
#  'city_of_ember',
#  'city_of_god',
#  'city_of_lost_children',
#  'city_slickers',
#  'city_slickers_ii_the_legend_of_curlys_gold',
#  'clash_of_the_titans',
#  'clash_of_the_titans_2',
#  'clash_of_the_titans_2010',
#  'clear_and_present_danger',
#  'clerks',
#  'clerks_2',
#  'click',
#  'client',
#  'clockstoppers',
#  'clockwork_orange',
#  'clone_wars',
#  'close_encounters_of_the_third_kind',
#  'closer',
#  'cloud_atlas_2012',
#  'cloudy_with_a_chance_of_meatballs_2_2013',
#  'cloverfield',
#  'clue',
#  'clueless',
#  'coach_carter',
#  'cocktail',
#  'cold_mountain',
#  'collateral',
#  'college_road_trip',
#  'colombiana',
#  'color_purple',
#  'comebacks',
#  'coming_to_america',
#  'con_air',
#  'conan_the_barbarian',
#  'conan_the_destroyer',
#  'condemned',
#  'coneheads',
#  'confessions_of_a_dangerous_mind',
#  'confessions_of_a_shopaholic',
#  'confessions_of_a_teenage_drama_queen',
#  'congo',
#  'conspiracy_theory',
#  'constant_gardener',
#  'constantine',
#  'contagion_2011',
#  'contraband_2012',
#  'cool_hand_luke',
#  'cop_out',
#  'coraline',
#  'core',
#  'corpse_bride',
#  'couples_retreat',
#  'covenant',
#  'cowboys_and_aliens',
#  'coyote_ugly',
#  'cradle_2_the_grave',
#  'craft',
#  'crank',
#  'crank_high_voltage',
#  'crazy-beautiful',
#  'crazy_heart',
#  'crazy_stupid_love_2011',
#  'creed_2015',
#  'crimson_tide',
#  'critters',
#  'crocodile_dundee',
#  'crocodile_dundee_2',
#  'crocodile_dundee_in_los_angeles',
#  'crossover',
#  'crouching_tiger_hidden_dragon',
#  'crow',
#  'crow_the_city_of_angels',
#  'cruel_intentions',
#  'cry-baby',
#  'cry_wolf_2005',
#  'cube',
#  'cujo',
#  'curious_case_of_benjamin_button',
#  'd2_the_mighty_ducks',
#  'd3_the_mighty_ducks',
#  'da_vinci_code',
#  'daddy_day_camp',
#  'daddy_day_care',
#  'daddys_little_girls',
#  'dallas_buyers_club_2013',
#  'damned_united',
#  'dan_in_real_life',
#  'dance_flick',
#  'dancer_in_the_dark',
#  'dances_with_wolves',
#  'dangerous_minds',
#  'danny_the_dog',
#  'dantes_peak',
#  'daredevil',
#  'darjeeling_limited',
#  'dark-shadows-2010',
#  'dark_city',
#  'dark_crystal',
#  'dark_water',
#  'darkman',
#  'darkness_falls',
#  'date_night',
#  'dawn_of_the_dead',
#  'dawn_of_the_planet_of_the_apes',
#  'day_after_tomorrow',
#  'day_the_earth_stood_still',
#  'daybreakers',
#  'daylight',
#  'days_of_thunder',
#  'dazed_and_confused',
#  'dead_alive',
#  'dead_man',
#  'dead_mans_shoes',
#  'dead_poets_society',
#  'dead_silence',
#  'deadpool',
#  'dear_john',
#  'death_at_a_funeral',
#  'death_at_a_funeral_2010',
#  'death_becomes_her',
#  'death_proof',
#  'death_race',
#  'death_sentence',
#  'death_to_smoochy',
#  'deception_2008',
#  'deck_the_halls',
#  'deep_impact',
#  'defiance_2008',
#  'deja_vu',
#  'delivery_man',
#  'delta_farce',
#  'demolition_man',
#  'dennis_the_menace',
#  'departed',
#  'derailed',
#  'descent',
#  'despicable_me_2',
#  'despicable_me_3',
#  'detroit_rock_city',
#  'deuce_bigalow_male_gigolo',
#  'deuce_bigelow_european_gigolo',
#  'devil',
#  'devils_advocate',
#  'devils_rejects',
#  ...]

# %%
free_typing = ['monster', 'geralt', 'storyline', 'touching','poignant','affecting']
for entry in free_typing:
    print(entry in selected_token_lst)
# Out:
# True
# True
# True
# False
# False
# False
